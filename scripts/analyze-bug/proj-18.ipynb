# %%
import os
import pandas as pd
import numpy as np
pd.set_option("display.max_colwidth", 2)

os.chdir("/home/coinse/Workspace/SBFL")

# %% [markdown]
# # Load bug info

# %%
from scripts.util import load_bug_data, find_covmat_func, find_covmat_idx
from functools import reduce
from typing import Set

pid, vid = "proj", 18

bug = load_bug_data(pid, vid)

print(f"{bug.buggy_files=}")
print(f"{bug.buggy_lines=}")
print("bug.coverage_df=")
display(bug.coverage_df)
print(f"{bug.failing_tests=}")
print(f"{bug.failing_tests_GT=}")
print("bug.functions={", end="")
for func in list(bug.functions)[:5]:
    print(f"{func},", end=" ")
print(", ...}")
print(f"{bug.id=}")
print(f"{bug.num_test_cases=}")
print(f"{bug.passing_tests=}")
print(f"{bug.path_to_cov_df=}")
print(f"{bug.path_to_patch=}")
print(f"{bug.path_to_test_results=}")
print("bug.source_files=", end="")
for src in list(bug.source_files)[:5]:
    print(f"{src},", end=" ")
print(", ...}")

fault_idxs = sorted(bug.buggy_lines)
# fault_idx2meth = {}
fault_meth2idx = {}
err_msg = ""
for fault_idx in fault_idxs:
    succ_func, ret_func = find_covmat_func(
        pid, bug.coverage_df, fault_idx, debug=False
    )
    if succ_func:
        succ_idx, ret_idx = find_covmat_idx(
            pid, bug.coverage_df, fault_idx, debug=False
        )
        if succ_idx:
            if ret_func in fault_meth2idx:
                fault_meth2idx[ret_func].add(ret_idx)
            else:
                fault_meth2idx[ret_func] = {ret_idx}
        else:
            print(f"{ret_idx}")
            if ret_func not in fault_meth2idx:
                fault_meth2idx[ret_func] = set()
    else:
        print(f"{ret_func}")
# fault_meths: Set = reduce(
#     lambda x, y: x | set([y]), fault_idx2meth.values(), set()
# )
# fault_meth2idx = {
#     v: {idx for idx in fault_idx2meth if fault_idx2meth[idx] == v}
#     for v in fault_meths
# }
fault_meths = set(fault_meth2idx.keys())
for meth in fault_meth2idx:
    print(f"{meth=}: {fault_meth2idx[meth]}")
# print(f"{fault_meths=}")
# Out:
# bug.buggy_files={'src/projections/tmerc.cpp'}
# bug.buggy_lines={('src/projections/tmerc.cpp', 190), ('src/projections/tmerc.cpp', 191)}
# bug.coverage_df=
#                                                                                                                                                      16  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      4  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      20  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                       6  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    8
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    8
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    16
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    16
# ...                                                                                                                                                  ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      1  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      36  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      27  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      19  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      17  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      10  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      ...  \
# file                                      function                                                                                             line  ...
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    ...
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    ...
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    ...
#                                                                                                                                                75    ...
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    ...
# ...                                                                                                                                                  ...
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    ...
#                                                                                                                                                93    ...
#                                                                                                                                                94    ...
#                                                                                                                                                95    ...
#                                                                                                                                                97    ...
#
#                                                                                                                                                      15  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      29  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      13  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      31  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    6
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    6
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    12
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    12
# ...                                                                                                                                                  ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      32  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      21  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      8  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      2  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    2
#                                                                                                                                                93    2
#                                                                                                                                                94    2
#                                                                                                                                                95    2
#                                                                                                                                                97    2
#
#                                                                                                                                                      23  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      18
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
# [34258 rows x 39 columns]
# bug.failing_tests={'2'}
# bug.failing_tests_GT={'2'}
# bug.functions={('/home/workspace/src/iso19111/factory.cpp', '_ZN5osgeo4proj2io16FactoryExceptionC2EPKc'), ('/home/workspace/include/proj/metadata.hpp', '_ZN5osgeo4proj8metadata14VerticalExtentD0Ev'), ('/home/workspace/src/iso19111/coordinateoperation.cpp', '_ZN5osgeo4proj9operation12SortFunctionC2ERKSt3mapIPNS1_19CoordinateOperationENS1_28PrecomputedOpCharacteristicsESt4lessIS5_ESaISt4pairIKS5_S6_EEE'), ('/home/workspace/src/iso19111/crs.cpp', '_ZNK5osgeo4proj3crs12ProjectedCRS15_isEquivalentToEPKNS0_4util11IComparableENS4_9CriterionE'), ('/usr/include/c++/9/bits/shared_ptr_base.h', '_ZNSt12__shared_ptrIN5osgeo4proj6common16IdentifiedObjectELN9__gnu_cxx12_Lock_policyE2EEaSEOS6_'), , ...}
# bug.id='proj-18'
# bug.num_test_cases=39
# bug.passing_tests={'33', '16', '18', '17', '24', '27', '3', '26', '6', '9', '39', '4', '32', '35', '8', '30', '20', '10', '23', '34', '31', '5', '14', '29', '1', '25', '37', '15', '22', '19', '12', '21', '7', '38', '36', '13', '28', '11'}
# bug.path_to_cov_df='/home/coinse/Workspace/defects4cpp/coverage/proj_18_buggy/coverage_df.pkl'
# bug.path_to_patch='/home/coinse/Workspace/defects4cpp/defects4cpp/taxonomy/proj/patch/0018-buggy.patch'
# bug.path_to_test_results='/home/coinse/Workspace/defects4cpp/coverage/proj_18_buggy/test_results.json'
# bug.source_files=/home/workspace/src/projections/eck2.cpp, /home/workspace/src/auth.cpp, /home/workspace/src/gridinfo.cpp, /home/workspace/src/nad_cvt.cpp, /home/workspace/src/projections/lcc.cpp, , ...}
# meth=('/home/workspace/src/projections/tmerc.cpp', '_ZL12approx_s_inv5PJ_XYP8PJconsts'): {('/home/workspace/src/projections/tmerc.cpp', '_ZL12approx_s_inv5PJ_XYP8PJconsts', 190), ('/home/workspace/src/projections/tmerc.cpp', '_ZL12approx_s_inv5PJ_XYP8PJconsts', 191)}

# %% [markdown]
# # Get spectra

# %%
covmat = bug.coverage_df
pass_tcs = bug.passing_tests
fail_tcs = bug.failing_tests

covmat_bool = covmat.astype(bool)
P = len(pass_tcs)
F = len(fail_tcs)
e_p = covmat_bool[pass_tcs].sum(axis=1)
e_f = covmat_bool[fail_tcs].sum(axis=1)
n_p = P - e_p
n_f = F - e_f
spectra = pd.DataFrame(
    {
        "line": covmat.index.to_list(),
        "e_p": e_p,
        "e_f": e_f,
        "n_p": n_p,
        "n_f": n_f,
    }
)

display(spectra)
# Out:
#                                                                                                                                                                                                                                                                                                 line  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    (/usr/include/c++/9/initializer_list, nan, 71)
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    (/usr/include/c++/9/initializer_list, _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv, 71)
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    (/usr/include/c++/9/initializer_list, _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv, 71)
#                                                                                                                                                75    (/usr/include/c++/9/initializer_list, _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv, 75)
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    (/usr/include/c++/9/initializer_list, _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv, 75)
# ...                                                                                                                                                                                                                                                                                              ...
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    (/home/workspace/src/projections/putp6.cpp, pj_putp6, 91)
#                                                                                                                                                93    (/home/workspace/src/projections/putp6.cpp, pj_putp6, 93)
#                                                                                                                                                94    (/home/workspace/src/projections/putp6.cpp, pj_putp6, 94)
#                                                                                                                                                95    (/home/workspace/src/projections/putp6.cpp, pj_putp6, 95)
#                                                                                                                                                97    (/home/workspace/src/projections/putp6.cpp, pj_putp6, 97)
#
#                                                                                                                                                      e_p  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    4
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    3
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    1
#                                                                                                                                                75    4
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    3
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
#                                                                                                                                                      e_f  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    0
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    0
#                                                                                                                                                75    0
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    0
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    1
#                                                                                                                                                93    1
#                                                                                                                                                94    1
#                                                                                                                                                95    1
#                                                                                                                                                97    1
#
#                                                                                                                                                      n_p  \
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    34
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    35
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    37
#                                                                                                                                                75    34
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    35
# ...                                                                                                                                                  ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    38
#                                                                                                                                                93    38
#                                                                                                                                                94    38
#                                                                                                                                                95    38
#                                                                                                                                                97    38
#
#                                                                                                                                                      n_f
# file                                      function                                                                                             line
# /usr/include/c++/9/initializer_list       NaN                                                                                                  71    1
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv                      71    1
#                                           _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv 71    1
#                                                                                                                                                75    1
#                                           _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv                     75    1
# ...                                                                                                                                                 ..
# /home/workspace/src/projections/putp6.cpp pj_putp6                                                                                             91    0
#                                                                                                                                                93    0
#                                                                                                                                                94    0
#                                                                                                                                                95    0
#                                                                                                                                                97    0
#
# [34258 rows x 5 columns]

# %% [markdown]
# # Compute suspiciousness scores

# %%
def ochiai(e_f, e_p, n_f, n_p):
    return e_f / np.sqrt(e_p + e_f) / np.sqrt(e_f + n_f) if e_f else 0.0


def op2(e_f, e_p, n_f, n_p):
    return e_f - e_p / (e_p + n_p + 1)

spectra["Sop2"] = spectra.apply(
    lambda row: op2(row.e_f, row.e_p, row.n_f, row.n_p), axis=1
)
spectra["Sochiai"] = spectra.apply(
    lambda row: ochiai(row.e_f, row.e_p, row.n_f, row.n_p), axis=1
)
spectra["Rop2"] = spectra.Sop2.rank(ascending=False, method="max")
spectra["Rochiai"] = spectra.Sochiai.rank(ascending=False, method="max")

# %% [markdown]
# # Line level SBFL

# %%
for fault_meth in fault_meth2idx:
    fault_idxs_of_meth = fault_meth2idx[fault_meth]
    print("fault meth:", fault_meth)
    for fault_idx in fault_idxs_of_meth:
        print("fault idx:", tuple(fault_idx))
    print("SBFL score of faulty method:")
    display(spectra.loc[fault_idxs_of_meth].reset_index(drop=True))

print("Top 5 SBFL scores:")
print("Op2:")
display(
    spectra.sort_values("Sop2", ascending=False).head(5).reset_index(drop=True)
)
print("Ochiai:")
display(
    spectra.sort_values("Sochiai", ascending=False)
    .head(5)
    .reset_index(drop=True)
)
# Out:
# fault meth: ('/home/workspace/src/projections/tmerc.cpp', '_ZL12approx_s_inv5PJ_XYP8PJconsts')
# fault idx: ('/home/workspace/src/projections/tmerc.cpp', '_ZL12approx_s_inv5PJ_XYP8PJconsts', 190)
# fault idx: ('/home/workspace/src/projections/tmerc.cpp', '_ZL12approx_s_inv5PJ_XYP8PJconsts', 191)
# SBFL score of faulty method:
#                                                                                   line  \
# 0  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts, 190)
# 1  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts, 191)
#
#    e_p  e_f  n_p  n_f  Sop2  Sochiai    Rop2  Rochiai
# 0  0    1    38   0    1.0   1.0      3863.0  3863.0
# 1  0    1    38   0    1.0   1.0      3863.0  3863.0
# Top 5 SBFL scores:
# Op2:
#                                                                              line  \
# 0  (/home/workspace/src/projections/putp6.cpp, pj_putp6, 97)
# 1  (/home/workspace/src/projections/laea.cpp, _ZL9s_inverse5PJ_XYP8PJconsts, 211)
# 2  (/home/workspace/src/projections/laea.cpp, _ZL9s_inverse5PJ_XYP8PJconsts, 223)
# 3  (/home/workspace/src/projections/laea.cpp, _ZL9s_inverse5PJ_XYP8PJconsts, 221)
# 4  (/home/workspace/src/projections/laea.cpp, _ZL9s_inverse5PJ_XYP8PJconsts, 220)
#
#    e_p  e_f  n_p  n_f  Sop2  Sochiai    Rop2  Rochiai
# 0  0    1    38   0    1.0   1.0      3863.0  3863.0
# 1  0    1    38   0    1.0   1.0      3863.0  3863.0
# 2  0    1    38   0    1.0   1.0      3863.0  3863.0
# 3  0    1    38   0    1.0   1.0      3863.0  3863.0
# 4  0    1    38   0    1.0   1.0      3863.0  3863.0
# Ochiai:
#                                                                              line  \
# 0  (/home/workspace/src/projections/putp6.cpp, pj_putp6, 97)
# 1  (/home/workspace/src/projections/ortho.cpp, _ZL9s_forward5PJ_LPP8PJconsts, 66)
# 2  (/home/workspace/src/projections/ortho.cpp, _ZL9s_inverse5PJ_XYP8PJconsts, 83)
# 3  (/home/workspace/src/projections/ortho.cpp, _ZL9s_inverse5PJ_XYP8PJconsts, 81)
# 4  (/home/workspace/src/projections/ortho.cpp, _ZL9s_inverse5PJ_XYP8PJconsts, 80)
#
#    e_p  e_f  n_p  n_f  Sop2  Sochiai    Rop2  Rochiai
# 0  0    1    38   0    1.0   1.0      3863.0  3863.0
# 1  0    1    38   0    1.0   1.0      3863.0  3863.0
# 2  0    1    38   0    1.0   1.0      3863.0  3863.0
# 3  0    1    38   0    1.0   1.0      3863.0  3863.0
# 4  0    1    38   0    1.0   1.0      3863.0  3863.0

# %% [markdown]
# # Method level SBFL

# %%
spectra["file"] = spectra.index.map(lambda x: x[0])
spectra["func"] = spectra.index.map(lambda x: x[1])
spectra["line"] = spectra.index.map(lambda x: x[2])
# (file, func) is meth
spectra["meth"] = spectra.apply(lambda row: (row.file, row.func), axis=1)
spectra.reset_index(drop=True, inplace=True)
display(spectra)
# Out:
#        line  e_p  e_f  n_p  n_f      Sop2  Sochiai     Rop2  Rochiai  \
# 0      71    4    0    34   1   -0.102564  0.0      31392.0  34258.0
# 1      71    3    0    35   1   -0.076923  0.0      29588.0  34258.0
# 2      71    1    0    37   1   -0.025641  0.0      23894.0  34258.0
# 3      75    4    0    34   1   -0.102564  0.0      31392.0  34258.0
# 4      75    3    0    35   1   -0.076923  0.0      29588.0  34258.0
# ...    ..   ..   ..    ..  ..         ...  ...          ...      ...
# 34253  91    0    1    38   0    1.000000  1.0      3863.0   3863.0
# 34254  93    0    1    38   0    1.000000  1.0      3863.0   3863.0
# 34255  94    0    1    38   0    1.000000  1.0      3863.0   3863.0
# 34256  95    0    1    38   0    1.000000  1.0      3863.0   3863.0
# 34257  97    0    1    38   0    1.000000  1.0      3863.0   3863.0
#
#                                             file  \
# 0      /usr/include/c++/9/initializer_list
# 1      /usr/include/c++/9/initializer_list
# 2      /usr/include/c++/9/initializer_list
# 3      /usr/include/c++/9/initializer_list
# 4      /usr/include/c++/9/initializer_list
# ...                                    ...
# 34253  /home/workspace/src/projections/putp6.cpp
# 34254  /home/workspace/src/projections/putp6.cpp
# 34255  /home/workspace/src/projections/putp6.cpp
# 34256  /home/workspace/src/projections/putp6.cpp
# 34257  /home/workspace/src/projections/putp6.cpp
#
#                                                                                                        func  \
# 0      NaN
# 1      _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv
# 2      _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv
# 3      _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv
# 4      _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv
# ...                                                                                 ...
# 34253  pj_putp6
# 34254  pj_putp6
# 34255  pj_putp6
# 34256  pj_putp6
# 34257  pj_putp6
#
#                                                                                                                                               meth
# 0      (/usr/include/c++/9/initializer_list, nan)
# 1      (/usr/include/c++/9/initializer_list, _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE4sizeEv)
# 2      (/usr/include/c++/9/initializer_list, _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv)
# 3      (/usr/include/c++/9/initializer_list, _ZNKSt16initializer_listIN7dropbox6oxygen2nnISt10shared_ptrIN5osgeo4proj5datum9EllipsoidEEEEE4sizeEv)
# 4      (/usr/include/c++/9/initializer_list, _ZNKSt16initializer_listIN5osgeo4proj2io16AuthorityFactory10ObjectTypeEE5beginEv)
# ...                                                                                                                        ...
# 34253  (/home/workspace/src/projections/putp6.cpp, pj_putp6)
# 34254  (/home/workspace/src/projections/putp6.cpp, pj_putp6)
# 34255  (/home/workspace/src/projections/putp6.cpp, pj_putp6)
# 34256  (/home/workspace/src/projections/putp6.cpp, pj_putp6)
# 34257  (/home/workspace/src/projections/putp6.cpp, pj_putp6)
#
# [34258 rows x 12 columns]

# %% [markdown]
# ## Max aggregation

# %%
print("[Op2]")
spectra_max_op2 = spectra.copy().sort_values(
    ["Sop2", "meth", "line"], ascending=False
)
spectra_max_op2.drop_duplicates(subset="meth", keep="first", inplace=True)
spectra_max_op2 = spectra_max_op2[
    ["meth", "line", "e_p", "e_f", "n_p", "n_f", "Sop2"]
]
spectra_max_op2["Rop2"] = spectra_max_op2.Sop2.rank(
    ascending=False, method="max"
)
print("Faulty method:")
display(
    spectra_max_op2.loc[spectra_max_op2.meth.isin(fault_meths)].reset_index(
        drop=True
    )
)
print("Top 20 methods:")
display(spectra_max_op2.head(20).reset_index(drop=True))
print()
print("[Ochiai]")
spectra_max_ochiai = spectra.copy().sort_values(
    ["Sochiai", "meth", "line"], ascending=False
)
spectra_max_ochiai.drop_duplicates(subset="meth", keep="first", inplace=True)
spectra_max_ochiai = spectra_max_ochiai[
    ["meth", "line", "e_p", "e_f", "n_p", "n_f", "Sochiai"]
]
spectra_max_ochiai["Rochiai"] = spectra_max_ochiai.Sochiai.rank(
    ascending=False, method="max"
)
print("Faulty method:")
display(
    spectra_max_ochiai.loc[
        spectra_max_ochiai.meth.isin(fault_meths)
    ].reset_index(drop=True)
)
print("Top 20 methods:")
display(spectra_max_ochiai.head(20).reset_index(drop=True))
# Out:
# [Op2]
# Faulty method:
#                                                                              meth  \
# 0  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
#
#    line  e_p  e_f  n_p  n_f  Sop2   Rop2
# 0  199   0    1    38   0    1.0   306.0
# Top 20 methods:
#                                                                                                meth  \
# 0   (/home/workspace/src/projections/wink2.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 1   (/home/workspace/src/projections/wink1.cpp, _ZL9s_inverse5PJ_XYP8PJconsts)
# 2   (/home/workspace/src/projections/wink1.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 3   (/home/workspace/src/projections/wag7.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 4   (/home/workspace/src/projections/wag3.cpp, _ZL9s_inverse5PJ_XYP8PJconsts)
# 5   (/home/workspace/src/projections/wag3.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 6   (/home/workspace/src/projections/wag2.cpp, _ZL9s_inverse5PJ_XYP8PJconsts)
# 7   (/home/workspace/src/projections/wag2.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 8   (/home/workspace/src/projections/vandg4.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 9   (/home/workspace/src/projections/vandg2.cpp, pj_vandg2)
# 10  (/home/workspace/src/projections/vandg2.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 11  (/home/workspace/src/projections/vandg2.cpp, _Z35pj_projection_specific_setup_vandg2P8PJconsts)
# 12  (/home/workspace/src/projections/vandg.cpp, _ZL9s_inverse5PJ_XYP8PJconsts)
# 13  (/home/workspace/src/projections/vandg.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 14  (/home/workspace/src/projections/urmfps.cpp, pj_urmfps)
# 15  (/home/workspace/src/projections/urmfps.cpp, _ZL9s_inverse5PJ_XYP8PJconsts)
# 16  (/home/workspace/src/projections/urmfps.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 17  (/home/workspace/src/projections/urmfps.cpp, _ZL5setupP8PJconsts)
# 18  (/home/workspace/src/projections/urmfps.cpp, _Z35pj_projection_specific_setup_urmfpsP8PJconsts)
# 19  (/home/workspace/src/projections/tpeqd.cpp, _ZL9s_inverse5PJ_XYP8PJconsts)
#
#     line  e_p  e_f  n_p  n_f  Sop2   Rop2
# 0   56    0    1    38   0    1.0   306.0
# 1   46    0    1    38   0    1.0   306.0
# 2   23    0    1    38   0    1.0   306.0
# 3   22    0    1    38   0    1.0   306.0
# 4   32    0    1    38   0    1.0   306.0
# 5   24    0    1    38   0    1.0   306.0
# 6   30    0    1    38   0    1.0   306.0
# 7   21    0    1    38   0    1.0   306.0
# 8   55    0    1    38   0    1.0   306.0
# 9   76    0    1    38   0    1.0   306.0
# 10  63    0    1    38   0    1.0   306.0
# 11  63    0    1    38   0    1.0   306.0
# 12  95    0    1    38   0    1.0   306.0
# 13  57    0    1    38   0    1.0   306.0
# 14  49    0    1    38   0    1.0   306.0
# 15  36    0    1    38   0    1.0   306.0
# 16  27    0    1    38   0    1.0   306.0
# 17  64    0    1    38   0    1.0   306.0
# 18  64    0    1    38   0    1.0   306.0
# 19  107   0    1    38   0    1.0   306.0
# [Ochiai]
# Faulty method:
#                                                                              meth  \
# 0  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
#
#    line  e_p  e_f  n_p  n_f  Sochiai  Rochiai
# 0  199   0    1    38   0    1.0      306.0
# Top 20 methods:
#                                                                                                meth  \
# 0   (/home/workspace/src/projections/wink2.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 1   (/home/workspace/src/projections/wink1.cpp, _ZL9s_inverse5PJ_XYP8PJconsts)
# 2   (/home/workspace/src/projections/wink1.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 3   (/home/workspace/src/projections/wag7.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 4   (/home/workspace/src/projections/wag3.cpp, _ZL9s_inverse5PJ_XYP8PJconsts)
# 5   (/home/workspace/src/projections/wag3.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 6   (/home/workspace/src/projections/wag2.cpp, _ZL9s_inverse5PJ_XYP8PJconsts)
# 7   (/home/workspace/src/projections/wag2.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 8   (/home/workspace/src/projections/vandg4.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 9   (/home/workspace/src/projections/vandg2.cpp, pj_vandg2)
# 10  (/home/workspace/src/projections/vandg2.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 11  (/home/workspace/src/projections/vandg2.cpp, _Z35pj_projection_specific_setup_vandg2P8PJconsts)
# 12  (/home/workspace/src/projections/vandg.cpp, _ZL9s_inverse5PJ_XYP8PJconsts)
# 13  (/home/workspace/src/projections/vandg.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 14  (/home/workspace/src/projections/urmfps.cpp, pj_urmfps)
# 15  (/home/workspace/src/projections/urmfps.cpp, _ZL9s_inverse5PJ_XYP8PJconsts)
# 16  (/home/workspace/src/projections/urmfps.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 17  (/home/workspace/src/projections/urmfps.cpp, _ZL5setupP8PJconsts)
# 18  (/home/workspace/src/projections/urmfps.cpp, _Z35pj_projection_specific_setup_urmfpsP8PJconsts)
# 19  (/home/workspace/src/projections/tpeqd.cpp, _ZL9s_inverse5PJ_XYP8PJconsts)
#
#     line  e_p  e_f  n_p  n_f  Sochiai  Rochiai
# 0   56    0    1    38   0    1.0      306.0
# 1   46    0    1    38   0    1.0      306.0
# 2   23    0    1    38   0    1.0      306.0
# 3   22    0    1    38   0    1.0      306.0
# 4   32    0    1    38   0    1.0      306.0
# 5   24    0    1    38   0    1.0      306.0
# 6   30    0    1    38   0    1.0      306.0
# 7   21    0    1    38   0    1.0      306.0
# 8   55    0    1    38   0    1.0      306.0
# 9   76    0    1    38   0    1.0      306.0
# 10  63    0    1    38   0    1.0      306.0
# 11  63    0    1    38   0    1.0      306.0
# 12  95    0    1    38   0    1.0      306.0
# 13  57    0    1    38   0    1.0      306.0
# 14  49    0    1    38   0    1.0      306.0
# 15  36    0    1    38   0    1.0      306.0
# 16  27    0    1    38   0    1.0      306.0
# 17  64    0    1    38   0    1.0      306.0
# 18  64    0    1    38   0    1.0      306.0
# 19  107   0    1    38   0    1.0      306.0

# %% [markdown]
# ## Line2Method voting (weight: sbfl score / dense rank)

# %%
print("[Op2]")
ballot_op2 = {}
spectra_max_op2 = spectra.copy().sort_values(
    ["Sop2", "meth", "line"], ascending=False
)
spectra_max_op2["Rop2D"] = spectra_max_op2.Sop2.rank(
    ascending=False, method="dense"
)
spectra_max_op2["vote"] = spectra_max_op2.Sop2 / spectra_max_op2.Rop2D
for row in spectra_max_op2.itertuples():
    if row.meth not in ballot_op2:
        ballot_op2[row.meth] = row.vote
    else:
        ballot_op2[row.meth] += row.vote
L2M_op2 = pd.DataFrame(
    {"meth": list(ballot_op2.keys()), "vote": list(ballot_op2.values())}
)
L2M_op2["rank"] = L2M_op2.vote.rank(ascending=False, method="max")
L2M_op2.sort_values("rank", inplace=True)
L2M_op2.reset_index(drop=True, inplace=True)
for fault_meth in fault_meths:
    print("Faulty method:")
    display(L2M_op2.loc[L2M_op2.meth == fault_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_op2.loc[spectra_max_op2.meth == fault_meth].reset_index(
            drop=True
        )
    )
print("Top 5 methods:")
display(L2M_op2.head(5).reset_index(drop=True))
for idx, top_meth in enumerate(L2M_op2.head(5).meth.tolist(), 1):
    print(f"Top {idx}:")
    display(L2M_op2.loc[L2M_op2.meth == top_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_op2.loc[spectra_max_op2.meth == top_meth].reset_index(
            drop=True
        )
    )
print()
print("[Ochiai]")
ballot_ochiai = {}
spectra_max_ochiai = spectra.copy().sort_values(
    ["Sochiai", "meth", "line"], ascending=False
)
spectra_max_ochiai["RochiaiD"] = spectra_max_ochiai.Sochiai.rank(
    ascending=False, method="dense"
)
spectra_max_ochiai["vote"] = (
    spectra_max_ochiai.Sochiai / spectra_max_ochiai.RochiaiD
)
for row in spectra_max_ochiai.itertuples():
    if row.meth not in ballot_ochiai:
        ballot_ochiai[row.meth] = row.vote
    else:
        ballot_ochiai[row.meth] += row.vote
L2M_ochiai = pd.DataFrame(
    {"meth": list(ballot_ochiai.keys()), "vote": list(ballot_ochiai.values())}
)
L2M_ochiai["rank"] = L2M_ochiai.vote.rank(ascending=False, method="max")
L2M_ochiai.sort_values("rank", inplace=True)
L2M_ochiai.reset_index(drop=True, inplace=True)
for fault_meth in fault_meths:
    print("Faulty method:")
    display(
        L2M_ochiai.loc[L2M_ochiai.meth == fault_meth].reset_index(drop=True)
    )
    print("Voters:")
    display(
        spectra_max_ochiai.loc[
            spectra_max_ochiai.meth == fault_meth
        ].reset_index(drop=True)
    )
print("Top 5 methods:")
display(L2M_ochiai.head(5).reset_index(drop=True))
for idx, top_meth in enumerate(L2M_ochiai.head(5).meth.tolist(), 1):
    print(f"Top {idx}:")
    display(L2M_ochiai.loc[L2M_ochiai.meth == top_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_ochiai.loc[spectra_max_ochiai.meth == top_meth].reset_index(
            drop=True
        )
    )
# Out:
# [Op2]
# Faulty method:
#                                                                              meth  \
# 0  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
#
#    vote   rank
# 0  9.0   212.0
# Voters:
#    line  e_p  e_f  n_p  n_f  Sop2  Sochiai    Rop2  Rochiai  \
# 0  199   0    1    38   0    1.0   1.0      3863.0  3863.0
# 1  198   0    1    38   0    1.0   1.0      3863.0  3863.0
# 2  196   0    1    38   0    1.0   1.0      3863.0  3863.0
# 3  193   0    1    38   0    1.0   1.0      3863.0  3863.0
# 4  192   0    1    38   0    1.0   1.0      3863.0  3863.0
# 5  191   0    1    38   0    1.0   1.0      3863.0  3863.0
# 6  190   0    1    38   0    1.0   1.0      3863.0  3863.0
# 7  187   0    1    38   0    1.0   1.0      3863.0  3863.0
# 8  186   0    1    38   0    1.0   1.0      3863.0  3863.0
#
#                                         file  \
# 0  /home/workspace/src/projections/tmerc.cpp
# 1  /home/workspace/src/projections/tmerc.cpp
# 2  /home/workspace/src/projections/tmerc.cpp
# 3  /home/workspace/src/projections/tmerc.cpp
# 4  /home/workspace/src/projections/tmerc.cpp
# 5  /home/workspace/src/projections/tmerc.cpp
# 6  /home/workspace/src/projections/tmerc.cpp
# 7  /home/workspace/src/projections/tmerc.cpp
# 8  /home/workspace/src/projections/tmerc.cpp
#
#                                 func  \
# 0  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 1  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 2  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 3  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 4  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 5  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 6  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 7  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 8  _ZL12approx_s_inv5PJ_XYP8PJconsts
#
#                                                                              meth  \
# 0  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 1  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 2  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 3  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 4  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 5  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 6  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 7  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 8  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
#
#    Rop2D  vote
# 0  1.0    1.0
# 1  1.0    1.0
# 2  1.0    1.0
# 3  1.0    1.0
# 4  1.0    1.0
# 5  1.0    1.0
# 6  1.0    1.0
# 7  1.0    1.0
# 8  1.0    1.0
# Top 5 methods:
#                                                                          meth  \
# 0  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 1  (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 2  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 3  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 4  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
#
#         vote  rank
# 0  77.000000  1.0
# 1  63.000000  2.0
# 2  56.000000  3.0
# 3  54.000000  4.0
# 4  53.179487  5.0
# Top 1:
#                                                                         meth  \
# 0  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
#
#    vote  rank
# 0  77.0  1.0
# Voters:
#     line  e_p  e_f  n_p  n_f  Sop2  Sochiai    Rop2  Rochiai  \
# 0   211   0    1    38   0    1.0   1.0      3863.0  3863.0
# 1   209   0    1    38   0    1.0   1.0      3863.0  3863.0
# 2   208   0    1    38   0    1.0   1.0      3863.0  3863.0
# 3   206   0    1    38   0    1.0   1.0      3863.0  3863.0
# 4   205   0    1    38   0    1.0   1.0      3863.0  3863.0
# ..  ...  ..   ..    ..  ..    ...   ...         ...     ...
# 72  117   0    1    38   0    1.0   1.0      3863.0  3863.0
# 73  116   0    1    38   0    1.0   1.0      3863.0  3863.0
# 74  112   0    1    38   0    1.0   1.0      3863.0  3863.0
# 75  111   0    1    38   0    1.0   1.0      3863.0  3863.0
# 76  110   0    1    38   0    1.0   1.0      3863.0  3863.0
#
#                                         file                           func  \
# 0   /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 1   /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 2   /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 3   /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 4   /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# ..                                       ...                            ...
# 72  /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 73  /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 74  /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 75  /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 76  /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
#
#                                                                          meth  \
# 0   (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 1   (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 2   (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 3   (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 4   (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# ..                                                                        ...
# 72  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 73  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 74  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 75  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 76  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
#
#     Rop2D  vote
# 0   1.0    1.0
# 1   1.0    1.0
# 2   1.0    1.0
# 3   1.0    1.0
# 4   1.0    1.0
# ..  ...    ...
# 72  1.0    1.0
# 73  1.0    1.0
# 74  1.0    1.0
# 75  1.0    1.0
# 76  1.0    1.0
#
# [77 rows x 14 columns]
# Top 2:
#                                                                         meth  \
# 0  (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
#
#    vote  rank
# 0  63.0  2.0
# Voters:
#     line  e_p  e_f  n_p  n_f  Sop2  Sochiai    Rop2  Rochiai  \
# 0   152   0    1    38   0    1.0   1.0      3863.0  3863.0
# 1   151   0    1    38   0    1.0   1.0      3863.0  3863.0
# 2   150   0    1    38   0    1.0   1.0      3863.0  3863.0
# 3   147   0    1    38   0    1.0   1.0      3863.0  3863.0
# 4   146   0    1    38   0    1.0   1.0      3863.0  3863.0
# ..  ...  ..   ..    ..  ..    ...   ...         ...     ...
# 58  67    0    1    38   0    1.0   1.0      3863.0  3863.0
# 59  66    0    1    38   0    1.0   1.0      3863.0  3863.0
# 60  63    0    1    38   0    1.0   1.0      3863.0  3863.0
# 61  62    0    1    38   0    1.0   1.0      3863.0  3863.0
# 62  61    0    1    38   0    1.0   1.0      3863.0  3863.0
#
#                                         file                           func  \
# 0   /home/workspace/src/projections/airy.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 1   /home/workspace/src/projections/airy.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 2   /home/workspace/src/projections/airy.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 3   /home/workspace/src/projections/airy.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 4   /home/workspace/src/projections/airy.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# ..                                       ...                            ...
# 58  /home/workspace/src/projections/airy.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 59  /home/workspace/src/projections/airy.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 60  /home/workspace/src/projections/airy.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 61  /home/workspace/src/projections/airy.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 62  /home/workspace/src/projections/airy.cpp  _ZL9s_forward5PJ_LPP8PJconsts
#
#                                                                          meth  \
# 0   (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 1   (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 2   (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 3   (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 4   (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# ..                                                                        ...
# 58  (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 59  (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 60  (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 61  (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 62  (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
#
#     Rop2D  vote
# 0   1.0    1.0
# 1   1.0    1.0
# 2   1.0    1.0
# 3   1.0    1.0
# 4   1.0    1.0
# ..  ...    ...
# 58  1.0    1.0
# 59  1.0    1.0
# 60  1.0    1.0
# 61  1.0    1.0
# 62  1.0    1.0
#
# [63 rows x 14 columns]
# Top 3:
#                                                                          meth  \
# 0  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
#
#    vote  rank
# 0  56.0  3.0
# Voters:
#     line  e_p  e_f  n_p  n_f  Sop2  Sochiai    Rop2  Rochiai  \
# 0   140   0    1    38   0    1.0   1.0      3863.0  3863.0
# 1   138   0    1    38   0    1.0   1.0      3863.0  3863.0
# 2   137   0    1    38   0    1.0   1.0      3863.0  3863.0
# 3   135   0    1    38   0    1.0   1.0      3863.0  3863.0
# 4   134   0    1    38   0    1.0   1.0      3863.0  3863.0
# 5   133   0    1    38   0    1.0   1.0      3863.0  3863.0
# 6   132   0    1    38   0    1.0   1.0      3863.0  3863.0
# 7   131   0    1    38   0    1.0   1.0      3863.0  3863.0
# 8   130   0    1    38   0    1.0   1.0      3863.0  3863.0
# 9   129   0    1    38   0    1.0   1.0      3863.0  3863.0
# 10  125   0    1    38   0    1.0   1.0      3863.0  3863.0
# 11  124   0    1    38   0    1.0   1.0      3863.0  3863.0
# 12  123   0    1    38   0    1.0   1.0      3863.0  3863.0
# 13  122   0    1    38   0    1.0   1.0      3863.0  3863.0
# 14  121   0    1    38   0    1.0   1.0      3863.0  3863.0
# 15  119   0    1    38   0    1.0   1.0      3863.0  3863.0
# 16  118   0    1    38   0    1.0   1.0      3863.0  3863.0
# 17  117   0    1    38   0    1.0   1.0      3863.0  3863.0
# 18  116   0    1    38   0    1.0   1.0      3863.0  3863.0
# 19  115   0    1    38   0    1.0   1.0      3863.0  3863.0
# 20  114   0    1    38   0    1.0   1.0      3863.0  3863.0
# 21  113   0    1    38   0    1.0   1.0      3863.0  3863.0
# 22  112   0    1    38   0    1.0   1.0      3863.0  3863.0
# 23  109   0    1    38   0    1.0   1.0      3863.0  3863.0
# 24  107   0    1    38   0    1.0   1.0      3863.0  3863.0
# 25  106   0    1    38   0    1.0   1.0      3863.0  3863.0
# 26  103   0    1    38   0    1.0   1.0      3863.0  3863.0
# 27  98    0    1    38   0    1.0   1.0      3863.0  3863.0
# 28  96    0    1    38   0    1.0   1.0      3863.0  3863.0
# 29  95    0    1    38   0    1.0   1.0      3863.0  3863.0
# 30  92    0    1    38   0    1.0   1.0      3863.0  3863.0
# 31  91    0    1    38   0    1.0   1.0      3863.0  3863.0
# 32  90    0    1    38   0    1.0   1.0      3863.0  3863.0
# 33  88    0    1    38   0    1.0   1.0      3863.0  3863.0
# 34  87    0    1    38   0    1.0   1.0      3863.0  3863.0
# 35  86    0    1    38   0    1.0   1.0      3863.0  3863.0
# 36  85    0    1    38   0    1.0   1.0      3863.0  3863.0
# 37  84    0    1    38   0    1.0   1.0      3863.0  3863.0
# 38  83    0    1    38   0    1.0   1.0      3863.0  3863.0
# 39  82    0    1    38   0    1.0   1.0      3863.0  3863.0
# 40  81    0    1    38   0    1.0   1.0      3863.0  3863.0
# 41  80    0    1    38   0    1.0   1.0      3863.0  3863.0
# 42  79    0    1    38   0    1.0   1.0      3863.0  3863.0
# 43  78    0    1    38   0    1.0   1.0      3863.0  3863.0
# 44  77    0    1    38   0    1.0   1.0      3863.0  3863.0
# 45  76    0    1    38   0    1.0   1.0      3863.0  3863.0
# 46  73    0    1    38   0    1.0   1.0      3863.0  3863.0
# 47  71    0    1    38   0    1.0   1.0      3863.0  3863.0
# 48  69    0    1    38   0    1.0   1.0      3863.0  3863.0
# 49  68    0    1    38   0    1.0   1.0      3863.0  3863.0
# 50  67    0    1    38   0    1.0   1.0      3863.0  3863.0
# 51  66    0    1    38   0    1.0   1.0      3863.0  3863.0
# 52  65    0    1    38   0    1.0   1.0      3863.0  3863.0
# 53  64    0    1    38   0    1.0   1.0      3863.0  3863.0
# 54  59    0    1    38   0    1.0   1.0      3863.0  3863.0
# 55  57    0    1    38   0    1.0   1.0      3863.0  3863.0
#
#                                          file                           func  \
# 0   /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 1   /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 2   /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 3   /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 4   /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 5   /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 6   /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 7   /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 8   /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 9   /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 10  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 11  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 12  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 13  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 14  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 15  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 16  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 17  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 18  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 19  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 20  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 21  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 22  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 23  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 24  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 25  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 26  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 27  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 28  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 29  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 30  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 31  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 32  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 33  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 34  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 35  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 36  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 37  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 38  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 39  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 40  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 41  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 42  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 43  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 44  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 45  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 46  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 47  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 48  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 49  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 50  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 51  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 52  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 53  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 54  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
# 55  /home/workspace/src/projections/chamb.cpp  _ZL9s_forward5PJ_LPP8PJconsts
#
#                                                                           meth  \
# 0   (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 1   (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 2   (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 3   (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 4   (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 5   (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 6   (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 7   (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 8   (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 9   (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 10  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 11  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 12  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 13  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 14  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 15  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 16  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 17  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 18  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 19  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 20  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 21  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 22  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 23  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 24  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 25  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 26  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 27  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 28  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 29  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 30  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 31  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 32  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 33  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 34  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 35  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 36  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 37  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 38  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 39  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 40  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 41  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 42  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 43  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 44  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 45  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 46  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 47  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 48  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 49  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 50  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 51  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 52  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 53  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 54  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 55  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
#
#     Rop2D  vote
# 0   1.0    1.0
# 1   1.0    1.0
# 2   1.0    1.0
# 3   1.0    1.0
# 4   1.0    1.0
# 5   1.0    1.0
# 6   1.0    1.0
# 7   1.0    1.0
# 8   1.0    1.0
# 9   1.0    1.0
# 10  1.0    1.0
# 11  1.0    1.0
# 12  1.0    1.0
# 13  1.0    1.0
# 14  1.0    1.0
# 15  1.0    1.0
# 16  1.0    1.0
# 17  1.0    1.0
# 18  1.0    1.0
# 19  1.0    1.0
# 20  1.0    1.0
# 21  1.0    1.0
# 22  1.0    1.0
# 23  1.0    1.0
# 24  1.0    1.0
# 25  1.0    1.0
# 26  1.0    1.0
# 27  1.0    1.0
# 28  1.0    1.0
# 29  1.0    1.0
# 30  1.0    1.0
# 31  1.0    1.0
# 32  1.0    1.0
# 33  1.0    1.0
# 34  1.0    1.0
# 35  1.0    1.0
# 36  1.0    1.0
# 37  1.0    1.0
# 38  1.0    1.0
# 39  1.0    1.0
# 40  1.0    1.0
# 41  1.0    1.0
# 42  1.0    1.0
# 43  1.0    1.0
# 44  1.0    1.0
# 45  1.0    1.0
# 46  1.0    1.0
# 47  1.0    1.0
# 48  1.0    1.0
# 49  1.0    1.0
# 50  1.0    1.0
# 51  1.0    1.0
# 52  1.0    1.0
# 53  1.0    1.0
# 54  1.0    1.0
# 55  1.0    1.0
# Top 4:
#                                                                       meth  \
# 0  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
#
#    vote  rank
# 0  54.0  4.0
# Voters:
#     line  e_p  e_f  n_p  n_f  Sop2  Sochiai    Rop2  Rochiai  \
# 0   157   0    1    38   0    1.0   1.0      3863.0  3863.0
# 1   155   0    1    38   0    1.0   1.0      3863.0  3863.0
# 2   154   0    1    38   0    1.0   1.0      3863.0  3863.0
# 3   153   0    1    38   0    1.0   1.0      3863.0  3863.0
# 4   151   0    1    38   0    1.0   1.0      3863.0  3863.0
# 5   150   0    1    38   0    1.0   1.0      3863.0  3863.0
# 6   149   0    1    38   0    1.0   1.0      3863.0  3863.0
# 7   148   0    1    38   0    1.0   1.0      3863.0  3863.0
# 8   147   0    1    38   0    1.0   1.0      3863.0  3863.0
# 9   146   0    1    38   0    1.0   1.0      3863.0  3863.0
# 10  145   0    1    38   0    1.0   1.0      3863.0  3863.0
# 11  144   0    1    38   0    1.0   1.0      3863.0  3863.0
# 12  143   0    1    38   0    1.0   1.0      3863.0  3863.0
# 13  142   0    1    38   0    1.0   1.0      3863.0  3863.0
# 14  141   0    1    38   0    1.0   1.0      3863.0  3863.0
# 15  140   0    1    38   0    1.0   1.0      3863.0  3863.0
# 16  139   0    1    38   0    1.0   1.0      3863.0  3863.0
# 17  138   0    1    38   0    1.0   1.0      3863.0  3863.0
# 18  137   0    1    38   0    1.0   1.0      3863.0  3863.0
# 19  136   0    1    38   0    1.0   1.0      3863.0  3863.0
# 20  135   0    1    38   0    1.0   1.0      3863.0  3863.0
# 21  134   0    1    38   0    1.0   1.0      3863.0  3863.0
# 22  133   0    1    38   0    1.0   1.0      3863.0  3863.0
# 23  132   0    1    38   0    1.0   1.0      3863.0  3863.0
# 24  131   0    1    38   0    1.0   1.0      3863.0  3863.0
# 25  130   0    1    38   0    1.0   1.0      3863.0  3863.0
# 26  129   0    1    38   0    1.0   1.0      3863.0  3863.0
# 27  128   0    1    38   0    1.0   1.0      3863.0  3863.0
# 28  127   0    1    38   0    1.0   1.0      3863.0  3863.0
# 29  126   0    1    38   0    1.0   1.0      3863.0  3863.0
# 30  125   0    1    38   0    1.0   1.0      3863.0  3863.0
# 31  124   0    1    38   0    1.0   1.0      3863.0  3863.0
# 32  123   0    1    38   0    1.0   1.0      3863.0  3863.0
# 33  122   0    1    38   0    1.0   1.0      3863.0  3863.0
# 34  121   0    1    38   0    1.0   1.0      3863.0  3863.0
# 35  120   0    1    38   0    1.0   1.0      3863.0  3863.0
# 36  119   0    1    38   0    1.0   1.0      3863.0  3863.0
# 37  118   0    1    38   0    1.0   1.0      3863.0  3863.0
# 38  117   0    1    38   0    1.0   1.0      3863.0  3863.0
# 39  116   0    1    38   0    1.0   1.0      3863.0  3863.0
# 40  115   0    1    38   0    1.0   1.0      3863.0  3863.0
# 41  114   0    1    38   0    1.0   1.0      3863.0  3863.0
# 42  113   0    1    38   0    1.0   1.0      3863.0  3863.0
# 43  110   0    1    38   0    1.0   1.0      3863.0  3863.0
# 44  108   0    1    38   0    1.0   1.0      3863.0  3863.0
# 45  106   0    1    38   0    1.0   1.0      3863.0  3863.0
# 46  105   0    1    38   0    1.0   1.0      3863.0  3863.0
# 47  102   0    1    38   0    1.0   1.0      3863.0  3863.0
# 48  98    0    1    38   0    1.0   1.0      3863.0  3863.0
# 49  96    0    1    38   0    1.0   1.0      3863.0  3863.0
# 50  95    0    1    38   0    1.0   1.0      3863.0  3863.0
# 51  92    0    1    38   0    1.0   1.0      3863.0  3863.0
# 52  89    0    1    38   0    1.0   1.0      3863.0  3863.0
# 53  88    0    1    38   0    1.0   1.0      3863.0  3863.0
#
#                                          file                        func  \
# 0   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 1   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 2   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 3   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 4   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 5   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 6   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 7   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 8   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 9   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 10  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 11  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 12  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 13  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 14  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 15  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 16  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 17  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 18  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 19  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 20  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 21  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 22  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 23  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 24  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 25  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 26  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 27  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 28  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 29  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 30  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 31  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 32  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 33  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 34  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 35  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 36  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 37  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 38  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 39  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 40  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 41  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 42  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 43  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 44  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 45  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 46  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 47  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 48  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 49  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 50  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 51  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 52  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 53  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
#
#                                                                        meth  \
# 0   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 1   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 2   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 3   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 4   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 5   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 6   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 7   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 8   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 9   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 10  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 11  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 12  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 13  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 14  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 15  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 16  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 17  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 18  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 19  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 20  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 21  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 22  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 23  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 24  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 25  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 26  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 27  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 28  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 29  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 30  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 31  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 32  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 33  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 34  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 35  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 36  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 37  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 38  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 39  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 40  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 41  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 42  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 43  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 44  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 45  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 46  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 47  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 48  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 49  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 50  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 51  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 52  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 53  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
#
#     Rop2D  vote
# 0   1.0    1.0
# 1   1.0    1.0
# 2   1.0    1.0
# 3   1.0    1.0
# 4   1.0    1.0
# 5   1.0    1.0
# 6   1.0    1.0
# 7   1.0    1.0
# 8   1.0    1.0
# 9   1.0    1.0
# 10  1.0    1.0
# 11  1.0    1.0
# 12  1.0    1.0
# 13  1.0    1.0
# 14  1.0    1.0
# 15  1.0    1.0
# 16  1.0    1.0
# 17  1.0    1.0
# 18  1.0    1.0
# 19  1.0    1.0
# 20  1.0    1.0
# 21  1.0    1.0
# 22  1.0    1.0
# 23  1.0    1.0
# 24  1.0    1.0
# 25  1.0    1.0
# 26  1.0    1.0
# 27  1.0    1.0
# 28  1.0    1.0
# 29  1.0    1.0
# 30  1.0    1.0
# 31  1.0    1.0
# 32  1.0    1.0
# 33  1.0    1.0
# 34  1.0    1.0
# 35  1.0    1.0
# 36  1.0    1.0
# 37  1.0    1.0
# 38  1.0    1.0
# 39  1.0    1.0
# 40  1.0    1.0
# 41  1.0    1.0
# 42  1.0    1.0
# 43  1.0    1.0
# 44  1.0    1.0
# 45  1.0    1.0
# 46  1.0    1.0
# 47  1.0    1.0
# 48  1.0    1.0
# 49  1.0    1.0
# 50  1.0    1.0
# 51  1.0    1.0
# 52  1.0    1.0
# 53  1.0    1.0
# Top 5:
#                                                                          meth  \
# 0  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
#
#         vote  rank
# 0  53.179487  5.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai  \
# 0   112   0    1    38   0    1.000000  1.000000  3863.0  3863.0
# 1   100   0    1    38   0    1.000000  1.000000  3863.0  3863.0
# 2   99    0    1    38   0    1.000000  1.000000  3863.0  3863.0
# 3   98    0    1    38   0    1.000000  1.000000  3863.0  3863.0
# 4   97    0    1    38   0    1.000000  1.000000  3863.0  3863.0
# ..  ..   ..   ..    ..  ..         ...       ...     ...     ...
# 61  111   1    1    37   0    0.974359  0.707107  5473.0  5473.0
# 62  109   1    1    37   0    0.974359  0.707107  5473.0  5473.0
# 63  107   1    1    37   0    0.974359  0.707107  5473.0  5473.0
# 64  106   1    1    37   0    0.974359  0.707107  5473.0  5473.0
# 65  104   1    1    37   0    0.974359  0.707107  5473.0  5473.0
#
#                                          file                           func  \
# 0   /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 1   /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 2   /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 3   /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 4   /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# ..                                        ...                            ...
# 61  /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 62  /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 63  /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 64  /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 65  /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
#
#                                                                           meth  \
# 0   (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 1   (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 2   (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 3   (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 4   (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# ..                                                                         ...
# 61  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 62  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 63  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 64  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 65  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
#
#     Rop2D      vote
# 0   1.0    1.000000
# 1   1.0    1.000000
# 2   1.0    1.000000
# 3   1.0    1.000000
# 4   1.0    1.000000
# ..  ...         ...
# 61  2.0    0.487179
# 62  2.0    0.487179
# 63  2.0    0.487179
# 64  2.0    0.487179
# 65  2.0    0.487179
#
# [66 rows x 14 columns]
# [Ochiai]
# Faulty method:
#                                                                              meth  \
# 0  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
#
#    vote   rank
# 0  9.0   196.0
# Voters:
#    line  e_p  e_f  n_p  n_f  Sop2  Sochiai    Rop2  Rochiai  \
# 0  199   0    1    38   0    1.0   1.0      3863.0  3863.0
# 1  198   0    1    38   0    1.0   1.0      3863.0  3863.0
# 2  196   0    1    38   0    1.0   1.0      3863.0  3863.0
# 3  193   0    1    38   0    1.0   1.0      3863.0  3863.0
# 4  192   0    1    38   0    1.0   1.0      3863.0  3863.0
# 5  191   0    1    38   0    1.0   1.0      3863.0  3863.0
# 6  190   0    1    38   0    1.0   1.0      3863.0  3863.0
# 7  187   0    1    38   0    1.0   1.0      3863.0  3863.0
# 8  186   0    1    38   0    1.0   1.0      3863.0  3863.0
#
#                                         file  \
# 0  /home/workspace/src/projections/tmerc.cpp
# 1  /home/workspace/src/projections/tmerc.cpp
# 2  /home/workspace/src/projections/tmerc.cpp
# 3  /home/workspace/src/projections/tmerc.cpp
# 4  /home/workspace/src/projections/tmerc.cpp
# 5  /home/workspace/src/projections/tmerc.cpp
# 6  /home/workspace/src/projections/tmerc.cpp
# 7  /home/workspace/src/projections/tmerc.cpp
# 8  /home/workspace/src/projections/tmerc.cpp
#
#                                 func  \
# 0  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 1  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 2  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 3  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 4  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 5  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 6  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 7  _ZL12approx_s_inv5PJ_XYP8PJconsts
# 8  _ZL12approx_s_inv5PJ_XYP8PJconsts
#
#                                                                              meth  \
# 0  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 1  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 2  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 3  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 4  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 5  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 6  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 7  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
# 8  (/home/workspace/src/projections/tmerc.cpp, _ZL12approx_s_inv5PJ_XYP8PJconsts)
#
#    RochiaiD  vote
# 0  1.0       1.0
# 1  1.0       1.0
# 2  1.0       1.0
# 3  1.0       1.0
# 4  1.0       1.0
# 5  1.0       1.0
# 6  1.0       1.0
# 7  1.0       1.0
# 8  1.0       1.0
# Top 5 methods:
#                                                                          meth  \
# 0  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 1  (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 2  (/home/workspace/src/projections/chamb.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
# 3  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 4  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
#
#         vote  rank
# 0  77.000000  1.0
# 1  63.000000  2.0
# 2  56.000000  3.0
# 3  54.000000  4.0
# 4  49.838835  5.0
# Top 1:
#                                                                         meth  \
# 0  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
#
#    vote  rank
# 0  77.0  1.0
# Voters:
#     line  e_p  e_f  n_p  n_f  Sop2  Sochiai    Rop2  Rochiai  \
# 0   211   0    1    38   0    1.0   1.0      3863.0  3863.0
# 1   209   0    1    38   0    1.0   1.0      3863.0  3863.0
# 2   208   0    1    38   0    1.0   1.0      3863.0  3863.0
# 3   206   0    1    38   0    1.0   1.0      3863.0  3863.0
# 4   205   0    1    38   0    1.0   1.0      3863.0  3863.0
# ..  ...  ..   ..    ..  ..    ...   ...         ...     ...
# 72  117   0    1    38   0    1.0   1.0      3863.0  3863.0
# 73  116   0    1    38   0    1.0   1.0      3863.0  3863.0
# 74  112   0    1    38   0    1.0   1.0      3863.0  3863.0
# 75  111   0    1    38   0    1.0   1.0      3863.0  3863.0
# 76  110   0    1    38   0    1.0   1.0      3863.0  3863.0
#
#                                         file                           func  \
# 0   /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 1   /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 2   /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 3   /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 4   /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# ..                                       ...                            ...
# 72  /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 73  /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 74  /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 75  /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 76  /home/workspace/src/projections/lsat.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
#
#                                                                          meth  \
# 0   (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 1   (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 2   (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 3   (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 4   (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# ..                                                                        ...
# 72  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 73  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 74  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 75  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 76  (/home/workspace/src/projections/lsat.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
#
#     RochiaiD  vote
# 0   1.0       1.0
# 1   1.0       1.0
# 2   1.0       1.0
# 3   1.0       1.0
# 4   1.0       1.0
# ..  ...       ...
# 72  1.0       1.0
# 73  1.0       1.0
# 74  1.0       1.0
# 75  1.0       1.0
# 76  1.0       1.0
#
# [77 rows x 14 columns]
# Top 2:
#                                                                         meth  \
# 0  (/home/workspace/src/projections/airy.cpp, _ZL9s_forward5PJ_LPP8PJconsts)
#
#    vote  rank
# 0  63.0  2.0
# Voters:
#     line  e_p  e_f  n_p  n_f  Sop2  Sochiai    Rop2  Rochiai  \
# 0   152   0    1    38   0    1.0   1.0      3863.0  3863.0
# 1   151   0    1    38   0    1.0   1.0      3863.0  3863.0
# 2   150   0    1    38   0    1.0   1.0      3863.0  3863.0
# 3   147   0    1    38   0    1.0   1.0      3863.0  3863.0
# 4   146   0    1    38   0    1.0   1.0      3863.0  3863.0
# ..  ...  ..   ..    ..  ..    ...   ...         ...     ...
# 58  67    0    1    38   0    1.0   1.0      3863.0  3863.0
# 59  66    0    1    38   0    1.0   1.0      3863.0  3863.0
# 60  63    0    1    38   0    1.0   1.0      3863.0  3863.0
# 61  62    0    1    38   0    1.0   1.0      3863.0  3863.0
# 62  61    0    1    38   0    1.0   1.0      3863.0  3863.0
#
#                                         file                           func  \
# ...
# 8   147   0    1    38   0    1.0   1.0      3863.0  3863.0
# 9   146   0    1    38   0    1.0   1.0      3863.0  3863.0
# 10  145   0    1    38   0    1.0   1.0      3863.0  3863.0
# 11  144   0    1    38   0    1.0   1.0      3863.0  3863.0
# 12  143   0    1    38   0    1.0   1.0      3863.0  3863.0
# 13  142   0    1    38   0    1.0   1.0      3863.0  3863.0
# 14  141   0    1    38   0    1.0   1.0      3863.0  3863.0
# 15  140   0    1    38   0    1.0   1.0      3863.0  3863.0
# 16  139   0    1    38   0    1.0   1.0      3863.0  3863.0
# 17  138   0    1    38   0    1.0   1.0      3863.0  3863.0
# 18  137   0    1    38   0    1.0   1.0      3863.0  3863.0
# 19  136   0    1    38   0    1.0   1.0      3863.0  3863.0
# 20  135   0    1    38   0    1.0   1.0      3863.0  3863.0
# 21  134   0    1    38   0    1.0   1.0      3863.0  3863.0
# 22  133   0    1    38   0    1.0   1.0      3863.0  3863.0
# 23  132   0    1    38   0    1.0   1.0      3863.0  3863.0
# 24  131   0    1    38   0    1.0   1.0      3863.0  3863.0
# 25  130   0    1    38   0    1.0   1.0      3863.0  3863.0
# 26  129   0    1    38   0    1.0   1.0      3863.0  3863.0
# 27  128   0    1    38   0    1.0   1.0      3863.0  3863.0
# 28  127   0    1    38   0    1.0   1.0      3863.0  3863.0
# 29  126   0    1    38   0    1.0   1.0      3863.0  3863.0
# 30  125   0    1    38   0    1.0   1.0      3863.0  3863.0
# 31  124   0    1    38   0    1.0   1.0      3863.0  3863.0
# 32  123   0    1    38   0    1.0   1.0      3863.0  3863.0
# 33  122   0    1    38   0    1.0   1.0      3863.0  3863.0
# 34  121   0    1    38   0    1.0   1.0      3863.0  3863.0
# 35  120   0    1    38   0    1.0   1.0      3863.0  3863.0
# 36  119   0    1    38   0    1.0   1.0      3863.0  3863.0
# 37  118   0    1    38   0    1.0   1.0      3863.0  3863.0
# 38  117   0    1    38   0    1.0   1.0      3863.0  3863.0
# 39  116   0    1    38   0    1.0   1.0      3863.0  3863.0
# 40  115   0    1    38   0    1.0   1.0      3863.0  3863.0
# 41  114   0    1    38   0    1.0   1.0      3863.0  3863.0
# 42  113   0    1    38   0    1.0   1.0      3863.0  3863.0
# 43  110   0    1    38   0    1.0   1.0      3863.0  3863.0
# 44  108   0    1    38   0    1.0   1.0      3863.0  3863.0
# 45  106   0    1    38   0    1.0   1.0      3863.0  3863.0
# 46  105   0    1    38   0    1.0   1.0      3863.0  3863.0
# 47  102   0    1    38   0    1.0   1.0      3863.0  3863.0
# 48  98    0    1    38   0    1.0   1.0      3863.0  3863.0
# 49  96    0    1    38   0    1.0   1.0      3863.0  3863.0
# 50  95    0    1    38   0    1.0   1.0      3863.0  3863.0
# 51  92    0    1    38   0    1.0   1.0      3863.0  3863.0
# 52  89    0    1    38   0    1.0   1.0      3863.0  3863.0
# 53  88    0    1    38   0    1.0   1.0      3863.0  3863.0
#
#                                          file                        func  \
# 0   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 1   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 2   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 3   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 4   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 5   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 6   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 7   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 8   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 9   /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 10  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 11  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 12  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 13  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 14  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 15  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 16  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 17  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 18  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 19  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 20  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 21  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 22  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 23  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 24  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 25  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 26  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 27  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 28  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 29  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 30  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 31  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 32  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 33  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 34  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 35  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 36  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 37  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 38  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 39  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 40  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 41  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 42  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 43  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 44  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 45  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 46  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 47  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 48  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 49  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 50  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 51  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 52  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
# 53  /home/workspace/src/projections/rouss.cpp  _ZL10destructorP8PJconstsi
#
#                                                                        meth  \
# 0   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 1   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 2   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 3   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 4   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 5   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 6   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 7   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 8   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 9   (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 10  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 11  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 12  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 13  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 14  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 15  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 16  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 17  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 18  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 19  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 20  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 21  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 22  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 23  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 24  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 25  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 26  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 27  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 28  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 29  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 30  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 31  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 32  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 33  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 34  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 35  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 36  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 37  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 38  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 39  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 40  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 41  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 42  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 43  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 44  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 45  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 46  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 47  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 48  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 49  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 50  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 51  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 52  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
# 53  (/home/workspace/src/projections/rouss.cpp, _ZL10destructorP8PJconstsi)
#
#     RochiaiD  vote
# 0   1.0       1.0
# 1   1.0       1.0
# 2   1.0       1.0
# 3   1.0       1.0
# 4   1.0       1.0
# 5   1.0       1.0
# 6   1.0       1.0
# 7   1.0       1.0
# 8   1.0       1.0
# 9   1.0       1.0
# 10  1.0       1.0
# 11  1.0       1.0
# 12  1.0       1.0
# 13  1.0       1.0
# 14  1.0       1.0
# 15  1.0       1.0
# 16  1.0       1.0
# 17  1.0       1.0
# 18  1.0       1.0
# 19  1.0       1.0
# 20  1.0       1.0
# 21  1.0       1.0
# 22  1.0       1.0
# 23  1.0       1.0
# 24  1.0       1.0
# 25  1.0       1.0
# 26  1.0       1.0
# 27  1.0       1.0
# 28  1.0       1.0
# 29  1.0       1.0
# 30  1.0       1.0
# 31  1.0       1.0
# 32  1.0       1.0
# 33  1.0       1.0
# 34  1.0       1.0
# 35  1.0       1.0
# 36  1.0       1.0
# 37  1.0       1.0
# 38  1.0       1.0
# 39  1.0       1.0
# 40  1.0       1.0
# 41  1.0       1.0
# 42  1.0       1.0
# 43  1.0       1.0
# 44  1.0       1.0
# 45  1.0       1.0
# 46  1.0       1.0
# 47  1.0       1.0
# 48  1.0       1.0
# 49  1.0       1.0
# 50  1.0       1.0
# 51  1.0       1.0
# 52  1.0       1.0
# 53  1.0       1.0
# Top 5:
#                                                                          meth  \
# 0  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
#
#         vote  rank
# 0  49.838835  5.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai  \
# 0   112   0    1    38   0    1.000000  1.000000  3863.0  3863.0
# 1   100   0    1    38   0    1.000000  1.000000  3863.0  3863.0
# 2   99    0    1    38   0    1.000000  1.000000  3863.0  3863.0
# 3   98    0    1    38   0    1.000000  1.000000  3863.0  3863.0
# 4   97    0    1    38   0    1.000000  1.000000  3863.0  3863.0
# ..  ..   ..   ..    ..  ..         ...       ...     ...     ...
# 61  111   1    1    37   0    0.974359  0.707107  5473.0  5473.0
# 62  109   1    1    37   0    0.974359  0.707107  5473.0  5473.0
# 63  107   1    1    37   0    0.974359  0.707107  5473.0  5473.0
# 64  106   1    1    37   0    0.974359  0.707107  5473.0  5473.0
# 65  104   1    1    37   0    0.974359  0.707107  5473.0  5473.0
#
#                                          file                           func  \
# 0   /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 1   /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 2   /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 3   /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 4   /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# ..                                        ...                            ...
# 61  /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 62  /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 63  /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 64  /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
# 65  /home/workspace/src/projections/labrd.cpp  _ZL9e_inverse5PJ_XYP8PJconsts
#
#                                                                           meth  \
# 0   (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 1   (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 2   (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 3   (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 4   (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# ..                                                                         ...
# 61  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 62  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 63  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 64  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
# 65  (/home/workspace/src/projections/labrd.cpp, _ZL9e_inverse5PJ_XYP8PJconsts)
#
#     RochiaiD      vote
# 0   1.0       1.000000
# 1   1.0       1.000000
# 2   1.0       1.000000
# 3   1.0       1.000000
# 4   1.0       1.000000
# ..  ...            ...
# 61  2.0       0.353553
# 62  2.0       0.353553
# 63  2.0       0.353553
# 64  2.0       0.353553
# 65  2.0       0.353553
#
# [66 rows x 14 columns]

# %% [markdown]
# # 감상
#
# Max aggregation으로 top이지만 그게 306개. line 수가 많은 편이 아니어서 voting으로도 성적이 좋지 않음
