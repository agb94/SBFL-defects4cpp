# %%
import os
import pandas as pd
import numpy as np
pd.set_option("display.max_colwidth", 2)

os.chdir("/home/coinse/Workspace/SBFL")

# %% [markdown]
# # Load bug info

# %%
from scripts.util import load_bug_data, find_covmat_func, find_covmat_idx
from functools import reduce
from typing import Set

pid, vid = "xbps", 2

bug = load_bug_data(pid, vid)

print(f"{bug.buggy_files=}")
print(f"{bug.buggy_lines=}")
print("bug.coverage_df=")
display(bug.coverage_df)
print(f"{bug.failing_tests=}")
print(f"{bug.failing_tests_GT=}")
print("bug.functions={", end="")
for func in list(bug.functions)[:5]:
    print(f"{func},", end=" ")
print(", ...}")
print(f"{bug.id=}")
print(f"{bug.num_test_cases=}")
print(f"{bug.passing_tests=}")
print(f"{bug.path_to_cov_df=}")
print(f"{bug.path_to_patch=}")
print(f"{bug.path_to_test_results=}")
print("bug.source_files=", end="")
for src in list(bug.source_files)[:5]:
    print(f"{src},", end=" ")
print(", ...}")

fault_idxs = sorted(bug.buggy_lines)
# fault_idx2meth = {}
fault_meth2idx = {}
err_msg = ""
for fault_idx in fault_idxs:
    succ_func, ret_func = find_covmat_func(
        pid, bug.coverage_df, fault_idx, debug=False
    )
    if succ_func:
        succ_idx, ret_idx = find_covmat_idx(
            pid, bug.coverage_df, fault_idx, debug=False
        )
        if succ_idx:
            if ret_func in fault_meth2idx:
                fault_meth2idx[ret_func].add(ret_idx)
            else:
                fault_meth2idx[ret_func] = {ret_idx}
        else:
            print(f"{ret_idx}")
            if ret_func not in fault_meth2idx:
                fault_meth2idx[ret_func] = set()
    else:
        print(f"{ret_func}")
# fault_meths: Set = reduce(
#     lambda x, y: x | set([y]), fault_idx2meth.values(), set()
# )
# fault_meth2idx = {
#     v: {idx for idx in fault_idx2meth if fault_idx2meth[idx] == v}
#     for v in fault_meths
# }
fault_meths = set(fault_meth2idx.keys())
for meth in fault_meth2idx:
    print(f"{meth=}: {fault_meth2idx[meth]}")
# print(f"{fault_meths=}")
# Out:
# bug.buggy_files={'lib/repo.c'}
# bug.buggy_lines={('lib/repo.c', 371), ('lib/repo.c', 159), ('lib/repo.c', 167), ('lib/repo.c', 370)}
# bug.coverage_df=
#                                 36  131  123   57    1  201  129  209  126  \
# file        function      line
# util_hash.c digest2string 44    3   2    4    6    7    2    9    4    6
#                           46    99  66   132  198  231  66   297  132  198
#                           47    96  64   128  192  224  64   288  128  192
#                           48    58  34   87   123  131  41   184  81   114
#                           50    38  30   41   69   93   23   104  47   78
# ...                             ..  ..   ..   ...  ...  ..   ...  ..   ...
# initend.c   xbps_init     171   4   12   6    4    4    2    9    3    8
#             xbps_end      175   2   10   4    2    2    1    7    1    6
#                           177   2   10   4    2    2    1    7    1    6
#                           179   2   10   4    2    2    1    7    1    6
#                           180   2   10   4    2    2    1    7    1    6
#
#                                 197  ...  125   40  91  191  128  112   65  \
# file        function      line       ...
# util_hash.c digest2string 44    8    ...  9    4    3   0    18   6    9
#                           46    264  ...  297  132  99  0    594  198  297
#                           47    256  ...  288  128  96  0    576  192  288
#                           48    143  ...  177  79   56  0    353  101  187
#                           50    113  ...  111  49   40  0    223  91   101
# ...                             ...  ...  ...  ..   .. ..    ...  ...  ...
# initend.c   xbps_init     171   6    ...  6    2    3   0    14   5    4
#             xbps_end      175   4    ...  3    1    2   0    11   4    2
#                           177   4    ...  3    1    2   0    11   4    2
#                           179   4    ...  3    1    2   0    11   4    2
#                           180   4    ...  3    1    2   0    11   4    2
#
#                                 172   22  184
# file        function      line
# util_hash.c digest2string 44    6    4    2
#                           46    198  132  66
#                           47    192  128  64
#                           48    135  84   40
#                           50    57   44   24
# ...                             ...  ..   ..
# initend.c   xbps_init     171   3    14   2
#             xbps_end      175   2    12   1
#                           177   2    12   1
#                           179   2    12   1
#                           180   2    12   1
#
# [4832 rows x 216 columns]
# bug.failing_tests={'120'}
# bug.failing_tests_GT={'120'}
# bug.functions={('proplib_wrapper.c', 'xbps_array_set_cstring_nocopy'), ('search.c', 'print_results'), ('proplib_wrapper.c', 'xbps_string_create'), ('util.c', 'xbps_pkg_is_ignored'), ('proplib_wrapper.c', 'xbps_string_append_cstring'), , ...}
# bug.id='xbps-2'
# bug.num_test_cases=216
# bug.passing_tests={'100', '51', '149', '139', '7', '78', '77', '154', '106', '216', '157', '159', '211', '86', '24', '123', '147', '127', '215', '131', '59', '178', '69', '170', '22', '110', '143', '124', '39', '18', '191', '14', '207', '68', '115', '64', '76', '5', '9', '184', '29', '171', '136', '175', '56', '38', '4', '35', '146', '40', '70', '98', '49', '47', '21', '163', '162', '58', '65', '104', '144', '87', '32', '88', '52', '83', '176', '79', '25', '203', '46', '172', '3', '117', '150', '177', '36', '95', '209', '130', '33', '13', '93', '208', '6', '204', '126', '37', '74', '71', '166', '66', '101', '28', '107', '205', '44', '156', '129', '60', '31', '197', '200', '158', '11', '118', '169', '190', '137', '134', '152', '133', '116', '43', '109', '173', '23', '102', '30', '80', '206', '161', '198', '165', '84', '122', '72', '105', '15', '63', '99', '41', '189', '61', '185', '55', '108', '82', '132', '135', '90', '42', '62', '138', '182', '183', '34', '141', '193', '112', '155', '45', '201', '180', '151', '92', '97', '128', '85', '199', '57', '20', '164', '48', '119', '94', '2', '153', '168', '194', '187', '54', '10', '113', '186', '19', '17', '213', '214', '121', '1', '142', '196', '179', '188', '114', '202', '192', '53', '174', '212', '111', '73', '27', '210', '12', '103', '89', '16', '195', '91', '96', '81', '75', '181', '125', '148', '67', '140', '160', '167', '50', '145', '8', '26'}
# bug.path_to_cov_df='/home/coinse/Workspace/defects4cpp/coverage/xbps_2_buggy/coverage_df.pkl'
# bug.path_to_patch='/home/coinse/Workspace/defects4cpp/defects4cpp/taxonomy/xbps/patch/0002-buggy.patch'
# bug.path_to_test_results='/home/coinse/Workspace/defects4cpp/coverage/xbps_2_buggy/test_results.json'
# bug.source_files=archive.c, proplib_wrapper.c, plist_remove.c, plist.c, package_register.c, , ...}
# ('repo.c', 'repo_open_local', 159)
# ('repo.c', 'repo_open_local', 167)
# ('repo.c', 'xbps_repo_close', 370)
# meth=('repo.c', 'repo_open_local'): set()
# meth=('repo.c', 'xbps_repo_close'): {('repo.c', 'xbps_repo_close', 371)}

# %% [markdown]
# # Get spectra

# %%
covmat = bug.coverage_df
pass_tcs = bug.passing_tests
fail_tcs = bug.failing_tests

covmat_bool = covmat.astype(bool)
P = len(pass_tcs)
F = len(fail_tcs)
e_p = covmat_bool[pass_tcs].sum(axis=1)
e_f = covmat_bool[fail_tcs].sum(axis=1)
n_p = P - e_p
n_f = F - e_f
spectra = pd.DataFrame(
    {
        "line": covmat.index.to_list(),
        "e_p": e_p,
        "e_f": e_f,
        "n_p": n_p,
        "n_f": n_f,
    }
)

display(spectra)
# Out:
#                                                             line  e_p  e_f  \
# file        function      line
# util_hash.c digest2string 44    (util_hash.c, digest2string, 44)  210  1
#                           46    (util_hash.c, digest2string, 46)  210  1
#                           47    (util_hash.c, digest2string, 47)  210  1
#                           48    (util_hash.c, digest2string, 48)  210  1
#                           50    (util_hash.c, digest2string, 50)  210  1
# ...                                                          ...  ... ..
# initend.c   xbps_init     171   (initend.c, xbps_init, 171)       213  1
#             xbps_end      175   (initend.c, xbps_end, 175)        201  1
#                           177   (initend.c, xbps_end, 177)        201  1
#                           179   (initend.c, xbps_end, 179)        201  1
#                           180   (initend.c, xbps_end, 180)        201  1
#
#                                 n_p  n_f
# file        function      line
# util_hash.c digest2string 44    5    0
#                           46    5    0
#                           47    5    0
#                           48    5    0
#                           50    5    0
# ...                            ..   ..
# initend.c   xbps_init     171   2    0
#             xbps_end      175   14   0
#                           177   14   0
#                           179   14   0
#                           180   14   0
#
# [4832 rows x 5 columns]

# %% [markdown]
# # Compute suspiciousness scores

# %%
def ochiai(e_f, e_p, n_f, n_p):
    return e_f / np.sqrt(e_p + e_f) / np.sqrt(e_f + n_f) if e_f else 0.0


def op2(e_f, e_p, n_f, n_p):
    return e_f - e_p / (e_p + n_p + 1)

spectra["Sop2"] = spectra.apply(
    lambda row: op2(row.e_f, row.e_p, row.n_f, row.n_p), axis=1
)
spectra["Sochiai"] = spectra.apply(
    lambda row: ochiai(row.e_f, row.e_p, row.n_f, row.n_p), axis=1
)
spectra["Rop2"] = spectra.Sop2.rank(ascending=False, method="max")
spectra["Rochiai"] = spectra.Sochiai.rank(ascending=False, method="max")

# %% [markdown]
# # Line level SBFL

# %%
for fault_meth in fault_meth2idx:
    fault_idxs_of_meth = fault_meth2idx[fault_meth]
    print("fault meth:", fault_meth)
    for fault_idx in fault_idxs_of_meth:
        print("fault idx:", tuple(fault_idx))
    print("SBFL score of faulty method:")
    display(spectra.loc[fault_idxs_of_meth].reset_index(drop=True))

print("Top 5 SBFL scores:")
print("Op2:")
display(
    spectra.sort_values("Sop2", ascending=False).head(5).reset_index(drop=True)
)
print("Ochiai:")
display(
    spectra.sort_values("Sochiai", ascending=False)
    .head(5)
    .reset_index(drop=True)
)
# Out:
# fault meth: ('repo.c', 'repo_open_local')
# SBFL score of faulty method:
# Empty DataFrame
# Columns: [line, e_p, e_f, n_p, n_f, Sop2, Sochiai, Rop2, Rochiai]
# Index: []
# fault meth: ('repo.c', 'xbps_repo_close')
# fault idx: ('repo.c', 'xbps_repo_close', 371)
# SBFL score of faulty method:
#                              line  e_p  e_f  n_p  n_f      Sop2   Sochiai  \
# 0  (repo.c, xbps_repo_close, 371)  209  1    6    0    0.032407  0.069007
#
#      Rop2  Rochiai
# 0  1041.0  1041.0
# Top 5 SBFL scores:
# Op2:
#                                                       line  e_p  e_f  n_p  \
# 0  (transaction_prepare.c, compute_transaction_stats, 167)  5    1    210
# 1  (transaction_prepare.c, compute_transaction_stats, 168)  5    1    210
# 2  (transaction.c, ttype2str, 61)                           7    1    208
# 3  (transaction.c, ttype2str, 62)                           7    1    208
# 4  (pkgdb.c, xbps_pkgdb_get_pkg, 379)                       10   1    205
#
#    n_f      Sop2   Sochiai  Rop2  Rochiai
# 0  0    0.976852  0.408248  2.0   2.0
# 1  0    0.976852  0.408248  2.0   2.0
# 2  0    0.967593  0.353553  4.0   4.0
# 3  0    0.967593  0.353553  4.0   4.0
# 4  0    0.953704  0.301511  5.0   5.0
# Ochiai:
#                                                       line  e_p  e_f  n_p  \
# 0  (transaction_prepare.c, compute_transaction_stats, 167)  5    1    210
# 1  (transaction_prepare.c, compute_transaction_stats, 168)  5    1    210
# 2  (transaction.c, ttype2str, 61)                           7    1    208
# 3  (transaction.c, ttype2str, 62)                           7    1    208
# 4  (pkgdb.c, xbps_pkgdb_get_pkg, 379)                       10   1    205
#
#    n_f      Sop2   Sochiai  Rop2  Rochiai
# 0  0    0.976852  0.408248  2.0   2.0
# 1  0    0.976852  0.408248  2.0   2.0
# 2  0    0.967593  0.353553  4.0   4.0
# 3  0    0.967593  0.353553  4.0   4.0
# 4  0    0.953704  0.301511  5.0   5.0

# %% [markdown]
# # Method level SBFL

# %%
spectra["file"] = spectra.index.map(lambda x: x[0])
spectra["func"] = spectra.index.map(lambda x: x[1])
spectra["line"] = spectra.index.map(lambda x: x[2])
# (file, func) is meth
spectra["meth"] = spectra.apply(lambda row: (row.file, row.func), axis=1)
spectra.reset_index(drop=True, inplace=True)
display(spectra)
# Out:
#       line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai  \
# 0     44    210  1    5    0    0.027778  0.068843  1101.0  1101.0
# 1     46    210  1    5    0    0.027778  0.068843  1101.0  1101.0
# 2     47    210  1    5    0    0.027778  0.068843  1101.0  1101.0
# 3     48    210  1    5    0    0.027778  0.068843  1101.0  1101.0
# 4     50    210  1    5    0    0.027778  0.068843  1101.0  1101.0
# ...   ..    ... ..   ..   ..         ...       ...     ...     ...
# 4827  171   213  1    2    0    0.013889  0.068359  1274.0  1274.0
# 4828  175   201  1    14   0    0.069444  0.070360  705.0   705.0
# 4829  177   201  1    14   0    0.069444  0.070360  705.0   705.0
# 4830  179   201  1    14   0    0.069444  0.070360  705.0   705.0
# 4831  180   201  1    14   0    0.069444  0.070360  705.0   705.0
#
#              file           func                          meth
# 0     util_hash.c  digest2string  (util_hash.c, digest2string)
# 1     util_hash.c  digest2string  (util_hash.c, digest2string)
# 2     util_hash.c  digest2string  (util_hash.c, digest2string)
# 3     util_hash.c  digest2string  (util_hash.c, digest2string)
# 4     util_hash.c  digest2string  (util_hash.c, digest2string)
# ...           ...            ...                           ...
# 4827  initend.c    xbps_init      (initend.c, xbps_init)
# 4828  initend.c    xbps_end       (initend.c, xbps_end)
# 4829  initend.c    xbps_end       (initend.c, xbps_end)
# 4830  initend.c    xbps_end       (initend.c, xbps_end)
# 4831  initend.c    xbps_end       (initend.c, xbps_end)
#
# [4832 rows x 12 columns]

# %% [markdown]
# ## Max aggregation

# %%
print("[Op2]")
spectra_max_op2 = spectra.copy().sort_values(
    ["Sop2", "meth", "line"], ascending=False
)
spectra_max_op2.drop_duplicates(subset="meth", keep="first", inplace=True)
spectra_max_op2 = spectra_max_op2[
    ["meth", "line", "e_p", "e_f", "n_p", "n_f", "Sop2"]
]
spectra_max_op2["Rop2"] = spectra_max_op2.Sop2.rank(
    ascending=False, method="max"
)
print("Faulty method:")
display(
    spectra_max_op2.loc[spectra_max_op2.meth.isin(fault_meths)].reset_index(
        drop=True
    )
)
print("Top 20 methods:")
display(spectra_max_op2.head(20).reset_index(drop=True))
print()
print("[Ochiai]")
spectra_max_ochiai = spectra.copy().sort_values(
    ["Sochiai", "meth", "line"], ascending=False
)
spectra_max_ochiai.drop_duplicates(subset="meth", keep="first", inplace=True)
spectra_max_ochiai = spectra_max_ochiai[
    ["meth", "line", "e_p", "e_f", "n_p", "n_f", "Sochiai"]
]
spectra_max_ochiai["Rochiai"] = spectra_max_ochiai.Sochiai.rank(
    ascending=False, method="max"
)
print("Faulty method:")
display(
    spectra_max_ochiai.loc[
        spectra_max_ochiai.meth.isin(fault_meths)
    ].reset_index(drop=True)
)
print("Top 20 methods:")
display(spectra_max_ochiai.head(20).reset_index(drop=True))
# Out:
# [Op2]
# Faulty method:
#                         meth  line  e_p  e_f  n_p  n_f      Sop2   Rop2
# 0  (repo.c, repo_open_local)  177   204  1    11   0    0.055556  81.0
# 1  (repo.c, xbps_repo_close)  388   209  1    6    0    0.032407  109.0
# Top 20 methods:
#                                                                  meth  line  \
# 0   (transaction_prepare.c, compute_transaction_stats)                 168
# 1   (transaction.c, ttype2str)                                         62
# 2   (pkgdb.c, xbps_pkgdb_get_pkg)                                      379
# 3   (transaction.c, show_actions)                                      108
# 4   (transaction.c, exec_transaction)                                  419
# 5   (repo.c, xbps_repo_store)                                          293
# 6   (pkgdb.c, xbps_pkgdb_init)                                         249
# 7   (initend.c, xbps_init)                                             76
# 8   (transaction_pkg_deps.c, repo_deps)                                142
# 9   (util.c, xbps_pkg_name)                                            267
# 10  (transaction_prepare.c, xbps_transaction_prepare)                  424
# 11  (transaction_check_shlibs.c, xbps_transaction_check_shlibs)        183
# 12  (transaction_check_shlibs.c, collect_shlibs)                       134
# 13  (transaction_check_conflicts.c, xbps_transaction_check_conflicts)  246
# 14  (proplib_wrapper.c, xbps_dictionary_set_uint32)                    686
# 15  (proplib_wrapper.c, xbps_dictionary_copy)                          464
# 16  (plist.c, xbps_array_iter_from_dict)                               214
# 17  (transaction_ops.c, trans_find_pkg)                                75
# 18  (proplib_wrapper.c, xbps_dictionary_get_uint64)                    698
# 19  (util.c, xbps_pkg_is_installed)                                    93
#
#     e_p  e_f  n_p  n_f      Sop2  Rop2
# 0   5    1    210  0    0.976852  1.0
# 1   7    1    208  0    0.967593  2.0
# 2   10   1    205  0    0.953704  3.0
# 3   14   1    201  0    0.935185  5.0
# 4   14   1    201  0    0.935185  5.0
# 5   54   1    161  0    0.750000  6.0
# 6   79   1    136  0    0.634259  7.0
# 7   92   1    123  0    0.574074  8.0
# 8   145  1    70   0    0.328704  9.0
# 9   171  1    44   0    0.208333  17.0
# 10  171  1    44   0    0.208333  17.0
# 11  171  1    44   0    0.208333  17.0
# 12  171  1    44   0    0.208333  17.0
# 13  171  1    44   0    0.208333  17.0
# 14  171  1    44   0    0.208333  17.0
# 15  171  1    44   0    0.208333  17.0
# 16  171  1    44   0    0.208333  17.0
# 17  172  1    43   0    0.203704  19.0
# 18  172  1    43   0    0.203704  19.0
# 19  174  1    41   0    0.194444  31.0
# [Ochiai]
# Faulty method:
#                         meth  line  e_p  e_f  n_p  n_f   Sochiai  Rochiai
# 0  (repo.c, repo_open_local)  177   204  1    11   0    0.069843  81.0
# 1  (repo.c, xbps_repo_close)  388   209  1    6    0    0.069007  109.0
# Top 20 methods:
#                                                                  meth  line  \
# 0   (transaction_prepare.c, compute_transaction_stats)                 168
# 1   (transaction.c, ttype2str)                                         62
# 2   (pkgdb.c, xbps_pkgdb_get_pkg)                                      379
# 3   (transaction.c, show_actions)                                      108
# 4   (transaction.c, exec_transaction)                                  419
# 5   (repo.c, xbps_repo_store)                                          293
# 6   (pkgdb.c, xbps_pkgdb_init)                                         249
# 7   (initend.c, xbps_init)                                             76
# 8   (transaction_pkg_deps.c, repo_deps)                                142
# 9   (util.c, xbps_pkg_name)                                            267
# 10  (transaction_prepare.c, xbps_transaction_prepare)                  424
# 11  (transaction_check_shlibs.c, xbps_transaction_check_shlibs)        183
# 12  (transaction_check_shlibs.c, collect_shlibs)                       134
# 13  (transaction_check_conflicts.c, xbps_transaction_check_conflicts)  246
# 14  (proplib_wrapper.c, xbps_dictionary_set_uint32)                    686
# 15  (proplib_wrapper.c, xbps_dictionary_copy)                          464
# 16  (plist.c, xbps_array_iter_from_dict)                               214
# 17  (transaction_ops.c, trans_find_pkg)                                75
# 18  (proplib_wrapper.c, xbps_dictionary_get_uint64)                    698
# 19  (util.c, xbps_pkg_is_installed)                                    93
#
#     e_p  e_f  n_p  n_f   Sochiai  Rochiai
# 0   5    1    210  0    0.408248  1.0
# 1   7    1    208  0    0.353553  2.0
# 2   10   1    205  0    0.301511  3.0
# 3   14   1    201  0    0.258199  5.0
# 4   14   1    201  0    0.258199  5.0
# 5   54   1    161  0    0.134840  6.0
# 6   79   1    136  0    0.111803  7.0
# 7   92   1    123  0    0.103695  8.0
# 8   145  1    70   0    0.082761  9.0
# 9   171  1    44   0    0.076249  17.0
# 10  171  1    44   0    0.076249  17.0
# 11  171  1    44   0    0.076249  17.0
# 12  171  1    44   0    0.076249  17.0
# 13  171  1    44   0    0.076249  17.0
# 14  171  1    44   0    0.076249  17.0
# 15  171  1    44   0    0.076249  17.0
# 16  171  1    44   0    0.076249  17.0
# 17  172  1    43   0    0.076029  19.0
# 18  172  1    43   0    0.076029  19.0
# 19  174  1    41   0    0.075593  31.0

# %% [markdown]
# ## Line2Method voting (weight: sbfl score / dense rank)

# %%
print("[Op2]")
ballot_op2 = {}
spectra_max_op2 = spectra.copy().sort_values(
    ["Sop2", "meth", "line"], ascending=False
)
spectra_max_op2["Rop2D"] = spectra_max_op2.Sop2.rank(
    ascending=False, method="dense"
)
spectra_max_op2["vote"] = spectra_max_op2.Sop2 / spectra_max_op2.Rop2D
for row in spectra_max_op2.itertuples():
    if row.meth not in ballot_op2:
        ballot_op2[row.meth] = row.vote
    else:
        ballot_op2[row.meth] += row.vote
L2M_op2 = pd.DataFrame(
    {"meth": list(ballot_op2.keys()), "vote": list(ballot_op2.values())}
)
L2M_op2["rank"] = L2M_op2.vote.rank(ascending=False, method="max")
L2M_op2.sort_values("rank", inplace=True)
L2M_op2.reset_index(drop=True, inplace=True)
for fault_meth in fault_meths:
    print("Faulty method:")
    display(L2M_op2.loc[L2M_op2.meth == fault_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_op2.loc[spectra_max_op2.meth == fault_meth].reset_index(
            drop=True
        )
    )
print("Top 5 methods:")
display(L2M_op2.head(5).reset_index(drop=True))
for idx, top_meth in enumerate(L2M_op2.head(5).meth.tolist(), 1):
    print(f"Top {idx}:")
    display(L2M_op2.loc[L2M_op2.meth == top_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_op2.loc[spectra_max_op2.meth == top_meth].reset_index(
            drop=True
        )
    )
print()
print("[Ochiai]")
ballot_ochiai = {}
spectra_max_ochiai = spectra.copy().sort_values(
    ["Sochiai", "meth", "line"], ascending=False
)
spectra_max_ochiai["RochiaiD"] = spectra_max_ochiai.Sochiai.rank(
    ascending=False, method="dense"
)
spectra_max_ochiai["vote"] = (
    spectra_max_ochiai.Sochiai / spectra_max_ochiai.RochiaiD
)
for row in spectra_max_ochiai.itertuples():
    if row.meth not in ballot_ochiai:
        ballot_ochiai[row.meth] = row.vote
    else:
        ballot_ochiai[row.meth] += row.vote
L2M_ochiai = pd.DataFrame(
    {"meth": list(ballot_ochiai.keys()), "vote": list(ballot_ochiai.values())}
)
L2M_ochiai["rank"] = L2M_ochiai.vote.rank(ascending=False, method="max")
L2M_ochiai.sort_values("rank", inplace=True)
L2M_ochiai.reset_index(drop=True, inplace=True)
for fault_meth in fault_meths:
    print("Faulty method:")
    display(
        L2M_ochiai.loc[L2M_ochiai.meth == fault_meth].reset_index(drop=True)
    )
    print("Voters:")
    display(
        spectra_max_ochiai.loc[
            spectra_max_ochiai.meth == fault_meth
        ].reset_index(drop=True)
    )
print("Top 5 methods:")
display(L2M_ochiai.head(5).reset_index(drop=True))
for idx, top_meth in enumerate(L2M_ochiai.head(5).meth.tolist(), 1):
    print(f"Top {idx}:")
    display(L2M_ochiai.loc[L2M_ochiai.meth == top_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_ochiai.loc[spectra_max_ochiai.meth == top_meth].reset_index(
            drop=True
        )
    )
# Out:
# [Op2]
# Faulty method:
#                         meth      vote   rank
# 0  (repo.c, xbps_repo_close) -0.006287  196.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai    file  \
# 0   388   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 1   387   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 2   384   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 3   380   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 4   376   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 5   373   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 6   371   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 7   369   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 8   385   88   0    127  1   -0.407407  0.000000  3928.0  4832.0   repo.c
# 9   378   88   0    127  1   -0.407407  0.000000  3928.0  4832.0   repo.c
# 10  377   88   0    127  1   -0.407407  0.000000  3928.0  4832.0   repo.c
# 11  374   88   0    127  1   -0.407407  0.000000  3928.0  4832.0   repo.c
#
#                func                       meth  Rop2D      vote
# 0   xbps_repo_close  (repo.c, xbps_repo_close)  35.0   0.000926
# 1   xbps_repo_close  (repo.c, xbps_repo_close)  35.0   0.000926
# 2   xbps_repo_close  (repo.c, xbps_repo_close)  35.0   0.000926
# 3   xbps_repo_close  (repo.c, xbps_repo_close)  35.0   0.000926
# 4   xbps_repo_close  (repo.c, xbps_repo_close)  35.0   0.000926
# 5   xbps_repo_close  (repo.c, xbps_repo_close)  35.0   0.000926
# 6   xbps_repo_close  (repo.c, xbps_repo_close)  35.0   0.000926
# 7   xbps_repo_close  (repo.c, xbps_repo_close)  35.0   0.000926
# 8   xbps_repo_close  (repo.c, xbps_repo_close)  119.0 -0.003424
# 9   xbps_repo_close  (repo.c, xbps_repo_close)  119.0 -0.003424
# 10  xbps_repo_close  (repo.c, xbps_repo_close)  119.0 -0.003424
# 11  xbps_repo_close  (repo.c, xbps_repo_close)  119.0 -0.003424
# Faulty method:
#                         meth      vote  rank
# 0  (repo.c, repo_open_local)  0.027778  51.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai   Rop2  Rochiai    file  \
# 0   177   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 1   172   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 2   171   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 3   170   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 4   162   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 5   154   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 6   152   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 7   151   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 8   150   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 9   149   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 10  148   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 11  147   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 12  146   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 13  139   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 14  137   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 15  134   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
#
#                func                       meth  Rop2D      vote
# 0   repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 1   repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 2   repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 3   repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 4   repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 5   repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 6   repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 7   repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 8   repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 9   repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 10  repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 11  repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 12  repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 13  repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 14  repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# 15  repo_open_local  (repo.c, repo_open_local)  32.0   0.001736
# Top 5 methods:
#                                                  meth      vote  rank
# 0  (transaction.c, show_actions)                       3.974537  1.0
# 1  (transaction_prepare.c, compute_transaction_stats)  2.579136  2.0
# 2  (transaction.c, ttype2str)                          1.901323  3.0
# 3  (transaction.c, exec_transaction)                   0.668577  4.0
# 4  (transaction_prepare.c, xbps_transaction_prepare)   0.666465  5.0
# Top 1:
#                             meth      vote  rank
# 0  (transaction.c, show_actions)  3.974537  1.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai  Rop2  Rochiai  \
# 0   108   14   1    201  0    0.935185  0.258199  28.0  28.0
# 1   106   14   1    201  0    0.935185  0.258199  28.0  28.0
# 2   104   14   1    201  0    0.935185  0.258199  28.0  28.0
# 3   103   14   1    201  0    0.935185  0.258199  28.0  28.0
# 4   101   14   1    201  0    0.935185  0.258199  28.0  28.0
# 5   100   14   1    201  0    0.935185  0.258199  28.0  28.0
# 6   99    14   1    201  0    0.935185  0.258199  28.0  28.0
# 7   98    14   1    201  0    0.935185  0.258199  28.0  28.0
# 8   97    14   1    201  0    0.935185  0.258199  28.0  28.0
# 9   96    14   1    201  0    0.935185  0.258199  28.0  28.0
# 10  95    14   1    201  0    0.935185  0.258199  28.0  28.0
# 11  94    14   1    201  0    0.935185  0.258199  28.0  28.0
# 12  93    14   1    201  0    0.935185  0.258199  28.0  28.0
# 13  91    14   1    201  0    0.935185  0.258199  28.0  28.0
# 14  90    14   1    201  0    0.935185  0.258199  28.0  28.0
# 15  89    14   1    201  0    0.935185  0.258199  28.0  28.0
# 16  83    14   1    201  0    0.935185  0.258199  28.0  28.0
#
#              file          func                           meth  Rop2D  \
# 0   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 1   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 2   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 3   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 4   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 5   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 6   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 7   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 8   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 9   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 10  transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 11  transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 12  transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 13  transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 14  transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 15  transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 16  transaction.c  show_actions  (transaction.c, show_actions)  4.0
#
#         vote
# 0   0.233796
# 1   0.233796
# 2   0.233796
# 3   0.233796
# 4   0.233796
# 5   0.233796
# 6   0.233796
# 7   0.233796
# 8   0.233796
# 9   0.233796
# 10  0.233796
# 11  0.233796
# 12  0.233796
# 13  0.233796
# 14  0.233796
# 15  0.233796
# 16  0.233796
# Top 2:
#                                                  meth      vote  rank
# 0  (transaction_prepare.c, compute_transaction_stats)  2.579136  2.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai  \
# 0   168   5    1    210  0    0.976852  0.408248  2.0     2.0
# 1   167   5    1    210  0    0.976852  0.408248  2.0     2.0
# 2   137   139  1    76   0    0.356481  0.084515  35.0    35.0
# 3   133   144  1    71   0    0.333333  0.083045  36.0    36.0
# 4   166   171  1    44   0    0.208333  0.076249  137.0   137.0
# 5   161   171  1    44   0    0.208333  0.076249  137.0   137.0
# 6   158   171  1    44   0    0.208333  0.076249  137.0   137.0
# 7   155   171  1    44   0    0.208333  0.076249  137.0   137.0
# 8   152   171  1    44   0    0.208333  0.076249  137.0   137.0
# 9   149   171  1    44   0    0.208333  0.076249  137.0   137.0
# 10  146   171  1    44   0    0.208333  0.076249  137.0   137.0
# 11  143   171  1    44   0    0.208333  0.076249  137.0   137.0
# 12  140   171  1    44   0    0.208333  0.076249  137.0   137.0
# 13  130   171  1    44   0    0.208333  0.076249  137.0   137.0
# 14  128   171  1    44   0    0.208333  0.076249  137.0   137.0
# 15  118   171  1    44   0    0.208333  0.076249  137.0   137.0
# 16  112   171  1    44   0    0.208333  0.076249  137.0   137.0
# 17  111   171  1    44   0    0.208333  0.076249  137.0   137.0
# 18  109   171  1    44   0    0.208333  0.076249  137.0   137.0
# 19  105   171  1    44   0    0.208333  0.076249  137.0   137.0
# 20  98    171  1    44   0    0.208333  0.076249  137.0   137.0
# 21  97    171  1    44   0    0.208333  0.076249  137.0   137.0
# 22  92    171  1    44   0    0.208333  0.076249  137.0   137.0
# 23  91    171  1    44   0    0.208333  0.076249  137.0   137.0
# 24  89    171  1    44   0    0.208333  0.076249  137.0   137.0
# 25  87    171  1    44   0    0.208333  0.076249  137.0   137.0
# 26  85    171  1    44   0    0.208333  0.076249  137.0   137.0
# 27  84    171  1    44   0    0.208333  0.076249  137.0   137.0
# 28  83    171  1    44   0    0.208333  0.076249  137.0   137.0
# 29  82    171  1    44   0    0.208333  0.076249  137.0   137.0
# 30  81    171  1    44   0    0.208333  0.076249  137.0   137.0
# 31  75    171  1    44   0    0.208333  0.076249  137.0   137.0
# 32  74    171  1    44   0    0.208333  0.076249  137.0   137.0
# 33  73    171  1    44   0    0.208333  0.076249  137.0   137.0
# 34  70    171  1    44   0    0.208333  0.076249  137.0   137.0
# 35  69    171  1    44   0    0.208333  0.076249  137.0   137.0
# 36  67    171  1    44   0    0.208333  0.076249  137.0   137.0
# 37  66    171  1    44   0    0.208333  0.076249  137.0   137.0
# 38  57    171  1    44   0    0.208333  0.076249  137.0   137.0
# 39  135   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 40  134   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 41  132   39   0    176  1   -0.180556  0.000000  3600.0  4832.0
# 42  131   39   0    176  1   -0.180556  0.000000  3600.0  4832.0
# 43  125   42   0    173  1   -0.194444  0.000000  3627.0  4832.0
# 44  123   42   0    173  1   -0.194444  0.000000  3627.0  4832.0
# 45  88    45   0    170  1   -0.208333  0.000000  3667.0  4832.0
# 46  122   67   0    148  1   -0.310185  0.000000  3863.0  4832.0
# 47  119   67   0    148  1   -0.310185  0.000000  3863.0  4832.0
# 48  106   67   0    148  1   -0.310185  0.000000  3863.0  4832.0
# 49  94    67   0    148  1   -0.310185  0.000000  3863.0  4832.0
# 50  93    67   0    148  1   -0.310185  0.000000  3863.0  4832.0
# 51  121   105  0    110  1   -0.486111  0.000000  4019.0  4832.0
# 52  120   105  0    110  1   -0.486111  0.000000  4019.0  4832.0
# 53  180   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 54  177   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 55  173   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 56  171   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
#
#                      file                       func  \
# 0   transaction_prepare.c  compute_transaction_stats
# 1   transaction_prepare.c  compute_transaction_stats
# 2   transaction_prepare.c  compute_transaction_stats
# 3   transaction_prepare.c  compute_transaction_stats
# 4   transaction_prepare.c  compute_transaction_stats
# 5   transaction_prepare.c  compute_transaction_stats
# 6   transaction_prepare.c  compute_transaction_stats
# 7   transaction_prepare.c  compute_transaction_stats
# 8   transaction_prepare.c  compute_transaction_stats
# 9   transaction_prepare.c  compute_transaction_stats
# 10  transaction_prepare.c  compute_transaction_stats
# 11  transaction_prepare.c  compute_transaction_stats
# 12  transaction_prepare.c  compute_transaction_stats
# 13  transaction_prepare.c  compute_transaction_stats
# 14  transaction_prepare.c  compute_transaction_stats
# 15  transaction_prepare.c  compute_transaction_stats
# 16  transaction_prepare.c  compute_transaction_stats
# 17  transaction_prepare.c  compute_transaction_stats
# 18  transaction_prepare.c  compute_transaction_stats
# 19  transaction_prepare.c  compute_transaction_stats
# 20  transaction_prepare.c  compute_transaction_stats
# 21  transaction_prepare.c  compute_transaction_stats
# 22  transaction_prepare.c  compute_transaction_stats
# 23  transaction_prepare.c  compute_transaction_stats
# 24  transaction_prepare.c  compute_transaction_stats
# 25  transaction_prepare.c  compute_transaction_stats
# 26  transaction_prepare.c  compute_transaction_stats
# 27  transaction_prepare.c  compute_transaction_stats
# 28  transaction_prepare.c  compute_transaction_stats
# 29  transaction_prepare.c  compute_transaction_stats
# 30  transaction_prepare.c  compute_transaction_stats
# 31  transaction_prepare.c  compute_transaction_stats
# 32  transaction_prepare.c  compute_transaction_stats
# 33  transaction_prepare.c  compute_transaction_stats
# 34  transaction_prepare.c  compute_transaction_stats
# 35  transaction_prepare.c  compute_transaction_stats
# 36  transaction_prepare.c  compute_transaction_stats
# 37  transaction_prepare.c  compute_transaction_stats
# 38  transaction_prepare.c  compute_transaction_stats
# 39  transaction_prepare.c  compute_transaction_stats
# 40  transaction_prepare.c  compute_transaction_stats
# 41  transaction_prepare.c  compute_transaction_stats
# 42  transaction_prepare.c  compute_transaction_stats
# 43  transaction_prepare.c  compute_transaction_stats
# 44  transaction_prepare.c  compute_transaction_stats
# 45  transaction_prepare.c  compute_transaction_stats
# 46  transaction_prepare.c  compute_transaction_stats
# 47  transaction_prepare.c  compute_transaction_stats
# 48  transaction_prepare.c  compute_transaction_stats
# 49  transaction_prepare.c  compute_transaction_stats
# 50  transaction_prepare.c  compute_transaction_stats
# 51  transaction_prepare.c  compute_transaction_stats
# 52  transaction_prepare.c  compute_transaction_stats
# 53  transaction_prepare.c  compute_transaction_stats
# 54  transaction_prepare.c  compute_transaction_stats
# 55  transaction_prepare.c  compute_transaction_stats
# 56  transaction_prepare.c  compute_transaction_stats
#
#                                                   meth  Rop2D      vote
# 0   (transaction_prepare.c, compute_transaction_stats)  1.0    0.976852
# 1   (transaction_prepare.c, compute_transaction_stats)  1.0    0.976852
# 2   (transaction_prepare.c, compute_transaction_stats)  9.0    0.039609
# 3   (transaction_prepare.c, compute_transaction_stats)  10.0   0.033333
# 4   (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 5   (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 6   (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 7   (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 8   (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 9   (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 10  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 11  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 12  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 13  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 14  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 15  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 16  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 17  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 18  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 19  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 20  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 21  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 22  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 23  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 24  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 25  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 26  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 27  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 28  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 29  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 30  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 31  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 32  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 33  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 34  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 35  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 36  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 37  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 38  (transaction_prepare.c, compute_transaction_stats)  12.0   0.017361
# 39  (transaction_prepare.c, compute_transaction_stats)  46.0  -0.000503
# 40  (transaction_prepare.c, compute_transaction_stats)  46.0  -0.000503
# 41  (transaction_prepare.c, compute_transaction_stats)  79.0  -0.002286
# 42  (transaction_prepare.c, compute_transaction_stats)  79.0  -0.002286
# 43  (transaction_prepare.c, compute_transaction_stats)  82.0  -0.002371
# 44  (transaction_prepare.c, compute_transaction_stats)  82.0  -0.002371
# 45  (transaction_prepare.c, compute_transaction_stats)  85.0  -0.002451
# 46  (transaction_prepare.c, compute_transaction_stats)  105.0 -0.002954
# 47  (transaction_prepare.c, compute_transaction_stats)  105.0 -0.002954
# 48  (transaction_prepare.c, compute_transaction_stats)  105.0 -0.002954
# 49  (transaction_prepare.c, compute_transaction_stats)  105.0 -0.002954
# 50  (transaction_prepare.c, compute_transaction_stats)  105.0 -0.002954
# 51  (transaction_prepare.c, compute_transaction_stats)  127.0 -0.003828
# 52  (transaction_prepare.c, compute_transaction_stats)  127.0 -0.003828
# 53  (transaction_prepare.c, compute_transaction_stats)  155.0 -0.004988
# 54  (transaction_prepare.c, compute_transaction_stats)  155.0 -0.004988
# 55  (transaction_prepare.c, compute_transaction_stats)  155.0 -0.004988
# 56  (transaction_prepare.c, compute_transaction_stats)  155.0 -0.004988
# Top 3:
#                          meth      vote  rank
# 0  (transaction.c, ttype2str)  1.901323  3.0
# Voters:
#    line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai  \
# 0  62    7    1    208  0    0.967593  0.353553  4.0     4.0
# 1  61    7    1    208  0    0.967593  0.353553  4.0     4.0
# 2  60    14   1    201  0    0.935185  0.258199  28.0    28.0
# 3  57    14   1    201  0    0.935185  0.258199  28.0    28.0
# 4  55    14   1    201  0    0.935185  0.258199  28.0    28.0
# 5  51    14   1    201  0    0.935185  0.258199  28.0    28.0
# 6  68    3    0    212  1   -0.013889  0.000000  2098.0  4832.0
# 7  67    3    0    212  1   -0.013889  0.000000  2098.0  4832.0
# 8  66    4    0    211  1   -0.018519  0.000000  2331.0  4832.0
# 9  65    4    0    211  1   -0.018519  0.000000  2331.0  4832.0
#
#             file       func                        meth  Rop2D      vote
# 0  transaction.c  ttype2str  (transaction.c, ttype2str)  2.0    0.483796
# 1  transaction.c  ttype2str  (transaction.c, ttype2str)  2.0    0.483796
# 2  transaction.c  ttype2str  (transaction.c, ttype2str)  4.0    0.233796
# 3  transaction.c  ttype2str  (transaction.c, ttype2str)  4.0    0.233796
# 4  transaction.c  ttype2str  (transaction.c, ttype2str)  4.0    0.233796
# 5  transaction.c  ttype2str  (transaction.c, ttype2str)  4.0    0.233796
# 6  transaction.c  ttype2str  (transaction.c, ttype2str)  44.0  -0.000316
# 7  transaction.c  ttype2str  (transaction.c, ttype2str)  44.0  -0.000316
# 8  transaction.c  ttype2str  (transaction.c, ttype2str)  45.0  -0.000412
# 9  transaction.c  ttype2str  (transaction.c, ttype2str)  45.0  -0.000412
# Top 4:
#                                 meth      vote  rank
# 0  (transaction.c, exec_transaction)  0.668577  4.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai  \
# 0   419   14   1    201  0    0.935185  0.258199  28.0    28.0
# 1   418   14   1    201  0    0.935185  0.258199  28.0    28.0
# 2   454   171  1    44   0    0.208333  0.076249  137.0   137.0
# 3   417   171  1    44   0    0.208333  0.076249  137.0   137.0
# 4   412   171  1    44   0    0.208333  0.076249  137.0   137.0
# 5   411   171  1    44   0    0.208333  0.076249  137.0   137.0
# 6   410   171  1    44   0    0.208333  0.076249  137.0   137.0
# 7   409   171  1    44   0    0.208333  0.076249  137.0   137.0
# 8   457   175  1    40   0    0.189815  0.075378  502.0   502.0
# 9   456   175  1    40   0    0.189815  0.075378  502.0   502.0
# 10  455   175  1    40   0    0.189815  0.075378  502.0   502.0
# 11  453   175  1    40   0    0.189815  0.075378  502.0   502.0
# 12  452   175  1    40   0    0.189815  0.075378  502.0   502.0
# 13  357   175  1    40   0    0.189815  0.075378  502.0   502.0
# 14  354   175  1    40   0    0.189815  0.075378  502.0   502.0
# 15  353   175  1    40   0    0.189815  0.075378  502.0   502.0
# 16  351   175  1    40   0    0.189815  0.075378  502.0   502.0
# 17  349   175  1    40   0    0.189815  0.075378  502.0   502.0
# 18  345   175  1    40   0    0.189815  0.075378  502.0   502.0
# 19  399   1    0    214  1   -0.004630  0.000000  1572.0  4832.0
# 20  398   1    0    214  1   -0.004630  0.000000  1572.0  4832.0
# 21  377   1    0    214  1   -0.004630  0.000000  1572.0  4832.0
# 22  450   4    0    211  1   -0.018519  0.000000  2331.0  4832.0
# 23  370   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 24  369   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 25  367   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 26  366   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 27  363   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 28  362   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 29  360   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 30  359   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 31  376   9    0    206  1   -0.041667  0.000000  2778.0  4832.0
# 32  375   9    0    206  1   -0.041667  0.000000  2778.0  4832.0
# 33  374   9    0    206  1   -0.041667  0.000000  2778.0  4832.0
# 34  372   10   0    205  1   -0.046296  0.000000  2814.0  4832.0
# 35  365   15   0    200  1   -0.069444  0.000000  3046.0  4832.0
# 36  401   20   0    195  1   -0.092593  0.000000  3192.0  4832.0
# 37  358   20   0    195  1   -0.092593  0.000000  3192.0  4832.0
# 38  447   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 39  443   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 40  442   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 41  435   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 42  430   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 43  424   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
#
#              file              func                               meth  Rop2D  \
# 0   transaction.c  exec_transaction  (transaction.c, exec_transaction)  4.0
# 1   transaction.c  exec_transaction  (transaction.c, exec_transaction)  4.0
# 2   transaction.c  exec_transaction  (transaction.c, exec_transaction)  12.0
# 3   transaction.c  exec_transaction  (transaction.c, exec_transaction)  12.0
# 4   transaction.c  exec_transaction  (transaction.c, exec_transaction)  12.0
# 5   transaction.c  exec_transaction  (transaction.c, exec_transaction)  12.0
# 6   transaction.c  exec_transaction  (transaction.c, exec_transaction)  12.0
# 7   transaction.c  exec_transaction  (transaction.c, exec_transaction)  12.0
# 8   transaction.c  exec_transaction  (transaction.c, exec_transaction)  15.0
# 9   transaction.c  exec_transaction  (transaction.c, exec_transaction)  15.0
# 10  transaction.c  exec_transaction  (transaction.c, exec_transaction)  15.0
# 11  transaction.c  exec_transaction  (transaction.c, exec_transaction)  15.0
# 12  transaction.c  exec_transaction  (transaction.c, exec_transaction)  15.0
# 13  transaction.c  exec_transaction  (transaction.c, exec_transaction)  15.0
# 14  transaction.c  exec_transaction  (transaction.c, exec_transaction)  15.0
# 15  transaction.c  exec_transaction  (transaction.c, exec_transaction)  15.0
# 16  transaction.c  exec_transaction  (transaction.c, exec_transaction)  15.0
# 17  transaction.c  exec_transaction  (transaction.c, exec_transaction)  15.0
# 18  transaction.c  exec_transaction  (transaction.c, exec_transaction)  15.0
# 19  transaction.c  exec_transaction  (transaction.c, exec_transaction)  42.0
# 20  transaction.c  exec_transaction  (transaction.c, exec_transaction)  42.0
# 21  transaction.c  exec_transaction  (transaction.c, exec_transaction)  42.0
# 22  transaction.c  exec_transaction  (transaction.c, exec_transaction)  45.0
# 23  transaction.c  exec_transaction  (transaction.c, exec_transaction)  46.0
# 24  transaction.c  exec_transaction  (transaction.c, exec_transaction)  46.0
# 25  transaction.c  exec_transaction  (transaction.c, exec_transaction)  46.0
# 26  transaction.c  exec_transaction  (transaction.c, exec_transaction)  46.0
# 27  transaction.c  exec_transaction  (transaction.c, exec_transaction)  46.0
# 28  transaction.c  exec_transaction  (transaction.c, exec_transaction)  46.0
# 29  transaction.c  exec_transaction  (transaction.c, exec_transaction)  46.0
# 30  transaction.c  exec_transaction  (transaction.c, exec_transaction)  46.0
# 31  transaction.c  exec_transaction  (transaction.c, exec_transaction)  50.0
# 32  transaction.c  exec_transaction  (transaction.c, exec_transaction)  50.0
# 33  transaction.c  exec_transaction  (transaction.c, exec_transaction)  50.0
# 34  transaction.c  exec_transaction  (transaction.c, exec_transaction)  51.0
# 35  transaction.c  exec_transaction  (transaction.c, exec_transaction)  56.0
# 36  transaction.c  exec_transaction  (transaction.c, exec_transaction)  61.0
# 37  transaction.c  exec_transaction  (transaction.c, exec_transaction)  61.0
# 38  transaction.c  exec_transaction  (transaction.c, exec_transaction)  155.0
# 39  transaction.c  exec_transaction  (transaction.c, exec_transaction)  155.0
# 40  transaction.c  exec_transaction  (transaction.c, exec_transaction)  155.0
# 41  transaction.c  exec_transaction  (transaction.c, exec_transaction)  155.0
# 42  transaction.c  exec_transaction  (transaction.c, exec_transaction)  155.0
# 43  transaction.c  exec_transaction  (transaction.c, exec_transaction)  155.0
#
#         vote
# 0   0.233796
# 1   0.233796
# 2   0.017361
# 3   0.017361
# 4   0.017361
# 5   0.017361
# 6   0.017361
# 7   0.017361
# 8   0.012654
# 9   0.012654
# 10  0.012654
# 11  0.012654
# 12  0.012654
# 13  0.012654
# 14  0.012654
# 15  0.012654
# 16  0.012654
# 17  0.012654
# 18  0.012654
# 19 -0.000110
# 20 -0.000110
# 21 -0.000110
# 22 -0.000412
# 23 -0.000503
# 24 -0.000503
# 25 -0.000503
# 26 -0.000503
# 27 -0.000503
# 28 -0.000503
# 29 -0.000503
# 30 -0.000503
# 31 -0.000833
# 32 -0.000833
# 33 -0.000833
# 34 -0.000908
# 35 -0.001240
# 36 -0.001518
# 37 -0.001518
# 38 -0.004988
# 39 -0.004988
# 40 -0.004988
# 41 -0.004988
# 42 -0.004988
# 43 -0.004988
# Top 5:
#                                                 meth      vote  rank
# 0  (transaction_prepare.c, xbps_transaction_prepare)  0.666465  5.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai  \
# 0   424   171  1    44   0    0.208333  0.076249  137.0   137.0
# 1   422   171  1    44   0    0.208333  0.076249  137.0   137.0
# 2   416   171  1    44   0    0.208333  0.076249  137.0   137.0
# 3   415   171  1    44   0    0.208333  0.076249  137.0   137.0
# 4   409   171  1    44   0    0.208333  0.076249  137.0   137.0
# 5   402   171  1    44   0    0.208333  0.076249  137.0   137.0
# 6   397   171  1    44   0    0.208333  0.076249  137.0   137.0
# 7   396   171  1    44   0    0.208333  0.076249  137.0   137.0
# 8   390   174  1    41   0    0.194444  0.075593  277.0   277.0
# 9   385   174  1    41   0    0.194444  0.075593  277.0   277.0
# 10  384   174  1    41   0    0.194444  0.075593  277.0   277.0
# 11  374   174  1    41   0    0.194444  0.075593  277.0   277.0
# 12  369   174  1    41   0    0.194444  0.075593  277.0   277.0
# 13  368   174  1    41   0    0.194444  0.075593  277.0   277.0
# 14  360   174  1    41   0    0.194444  0.075593  277.0   277.0
# 15  359   174  1    41   0    0.194444  0.075593  277.0   277.0
# 16  353   174  1    41   0    0.194444  0.075593  277.0   277.0
# 17  350   174  1    41   0    0.194444  0.075593  277.0   277.0
# 18  349   174  1    41   0    0.194444  0.075593  277.0   277.0
# 19  348   174  1    41   0    0.194444  0.075593  277.0   277.0
# 20  347   174  1    41   0    0.194444  0.075593  277.0   277.0
# 21  346   174  1    41   0    0.194444  0.075593  277.0   277.0
# 22  345   174  1    41   0    0.194444  0.075593  277.0   277.0
# 23  338   174  1    41   0    0.194444  0.075593  277.0   277.0
# 24  332   174  1    41   0    0.194444  0.075593  277.0   277.0
# 25  330   174  1    41   0    0.194444  0.075593  277.0   277.0
# 26  329   174  1    41   0    0.194444  0.075593  277.0   277.0
# 27  328   174  1    41   0    0.194444  0.075593  277.0   277.0
# 28  327   174  1    41   0    0.194444  0.075593  277.0   277.0
# 29  321   174  1    41   0    0.194444  0.075593  277.0   277.0
# 30  317   175  1    40   0    0.189815  0.075378  502.0   502.0
# 31  313   175  1    40   0    0.189815  0.075378  502.0   502.0
# 32  311   175  1    40   0    0.189815  0.075378  502.0   502.0
# 33  308   175  1    40   0    0.189815  0.075378  502.0   502.0
# 34  306   175  1    40   0    0.189815  0.075378  502.0   502.0
# 35  305   175  1    40   0    0.189815  0.075378  502.0   502.0
# 36  304   175  1    40   0    0.189815  0.075378  502.0   502.0
# 37  300   175  1    40   0    0.189815  0.075378  502.0   502.0
# 38  299   175  1    40   0    0.189815  0.075378  502.0   502.0
# 39  298   175  1    40   0    0.189815  0.075378  502.0   502.0
# 40  297   175  1    40   0    0.189815  0.075378  502.0   502.0
# 41  292   175  1    40   0    0.189815  0.075378  502.0   502.0
# 42  289   175  1    40   0    0.189815  0.075378  502.0   502.0
# 43  283   175  1    40   0    0.189815  0.075378  502.0   502.0
# 44  280   175  1    40   0    0.189815  0.075378  502.0   502.0
# 45  278   175  1    40   0    0.189815  0.075378  502.0   502.0
# 46  277   175  1    40   0    0.189815  0.075378  502.0   502.0
# 47  271   175  1    40   0    0.189815  0.075378  502.0   502.0
# 48  376   2    0    213  1   -0.009259  0.000000  1722.0  4832.0
# 49  319   2    0    213  1   -0.009259  0.000000  1722.0  4832.0
# 50  318   2    0    213  1   -0.009259  0.000000  1722.0  4832.0
# 51  406   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 52  403   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 53  378   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 54  375   7    0    208  1   -0.032407  0.000000  2669.0  4832.0
# 55  391   9    0    206  1   -0.041667  0.000000  2778.0  4832.0
# 56  309   33   0    182  1   -0.152778  0.000000  3542.0  4832.0
#
#                      file                      func  \
# 0   transaction_prepare.c  xbps_transaction_prepare
# 1   transaction_prepare.c  xbps_transaction_prepare
# 2   transaction_prepare.c  xbps_transaction_prepare
# 3   transaction_prepare.c  xbps_transaction_prepare
# 4   transaction_prepare.c  xbps_transaction_prepare
# 5   transaction_prepare.c  xbps_transaction_prepare
# 6   transaction_prepare.c  xbps_transaction_prepare
# 7   transaction_prepare.c  xbps_transaction_prepare
# 8   transaction_prepare.c  xbps_transaction_prepare
# 9   transaction_prepare.c  xbps_transaction_prepare
# 10  transaction_prepare.c  xbps_transaction_prepare
# 11  transaction_prepare.c  xbps_transaction_prepare
# 12  transaction_prepare.c  xbps_transaction_prepare
# 13  transaction_prepare.c  xbps_transaction_prepare
# 14  transaction_prepare.c  xbps_transaction_prepare
# 15  transaction_prepare.c  xbps_transaction_prepare
# 16  transaction_prepare.c  xbps_transaction_prepare
# 17  transaction_prepare.c  xbps_transaction_prepare
# 18  transaction_prepare.c  xbps_transaction_prepare
# 19  transaction_prepare.c  xbps_transaction_prepare
# 20  transaction_prepare.c  xbps_transaction_prepare
# 21  transaction_prepare.c  xbps_transaction_prepare
# 22  transaction_prepare.c  xbps_transaction_prepare
# 23  transaction_prepare.c  xbps_transaction_prepare
# 24  transaction_prepare.c  xbps_transaction_prepare
# 25  transaction_prepare.c  xbps_transaction_prepare
# 26  transaction_prepare.c  xbps_transaction_prepare
# 27  transaction_prepare.c  xbps_transaction_prepare
# 28  transaction_prepare.c  xbps_transaction_prepare
# 29  transaction_prepare.c  xbps_transaction_prepare
# 30  transaction_prepare.c  xbps_transaction_prepare
# 31  transaction_prepare.c  xbps_transaction_prepare
# 32  transaction_prepare.c  xbps_transaction_prepare
# 33  transaction_prepare.c  xbps_transaction_prepare
# 34  transaction_prepare.c  xbps_transaction_prepare
# 35  transaction_prepare.c  xbps_transaction_prepare
# 36  transaction_prepare.c  xbps_transaction_prepare
# 37  transaction_prepare.c  xbps_transaction_prepare
# 38  transaction_prepare.c  xbps_transaction_prepare
# 39  transaction_prepare.c  xbps_transaction_prepare
# 40  transaction_prepare.c  xbps_transaction_prepare
# 41  transaction_prepare.c  xbps_transaction_prepare
# 42  transaction_prepare.c  xbps_transaction_prepare
# 43  transaction_prepare.c  xbps_transaction_prepare
# 44  transaction_prepare.c  xbps_transaction_prepare
# 45  transaction_prepare.c  xbps_transaction_prepare
# 46  transaction_prepare.c  xbps_transaction_prepare
# 47  transaction_prepare.c  xbps_transaction_prepare
# 48  transaction_prepare.c  xbps_transaction_prepare
# 49  transaction_prepare.c  xbps_transaction_prepare
# 50  transaction_prepare.c  xbps_transaction_prepare
# 51  transaction_prepare.c  xbps_transaction_prepare
# 52  transaction_prepare.c  xbps_transaction_prepare
# 53  transaction_prepare.c  xbps_transaction_prepare
# 54  transaction_prepare.c  xbps_transaction_prepare
# 55  transaction_prepare.c  xbps_transaction_prepare
# 56  transaction_prepare.c  xbps_transaction_prepare
#
#                                                  meth  Rop2D      vote
# 0   (transaction_prepare.c, xbps_transaction_prepare)  12.0   0.017361
# 1   (transaction_prepare.c, xbps_transaction_prepare)  12.0   0.017361
# 2   (transaction_prepare.c, xbps_transaction_prepare)  12.0   0.017361
# 3   (transaction_prepare.c, xbps_transaction_prepare)  12.0   0.017361
# 4   (transaction_prepare.c, xbps_transaction_prepare)  12.0   0.017361
# 5   (transaction_prepare.c, xbps_transaction_prepare)  12.0   0.017361
# 6   (transaction_prepare.c, xbps_transaction_prepare)  12.0   0.017361
# 7   (transaction_prepare.c, xbps_transaction_prepare)  12.0   0.017361
# 8   (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 9   (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 10  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 11  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 12  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 13  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 14  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 15  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 16  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 17  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 18  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 19  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 20  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 21  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 22  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 23  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 24  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 25  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 26  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 27  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 28  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 29  (transaction_prepare.c, xbps_transaction_prepare)  14.0   0.013889
# 30  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 31  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 32  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 33  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 34  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 35  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 36  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 37  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 38  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 39  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 40  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 41  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 42  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 43  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 44  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 45  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 46  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 47  (transaction_prepare.c, xbps_transaction_prepare)  15.0   0.012654
# 48  (transaction_prepare.c, xbps_transaction_prepare)  43.0  -0.000215
# 49  (transaction_prepare.c, xbps_transaction_prepare)  43.0  -0.000215
# 50  (transaction_prepare.c, xbps_transaction_prepare)  43.0  -0.000215
# 51  (transaction_prepare.c, xbps_transaction_prepare)  46.0  -0.000503
# 52  (transaction_prepare.c, xbps_transaction_prepare)  46.0  -0.000503
# 53  (transaction_prepare.c, xbps_transaction_prepare)  46.0  -0.000503
# 54  (transaction_prepare.c, xbps_transaction_prepare)  48.0  -0.000675
# 55  (transaction_prepare.c, xbps_transaction_prepare)  50.0  -0.000833
# 56  (transaction_prepare.c, xbps_transaction_prepare)  73.0  -0.002093
# [Ochiai]
# Faulty method:
#                         meth      vote  rank
# 0  (repo.c, xbps_repo_close)  0.015773  70.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai    file  \
# 0   388   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 1   387   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 2   384   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 3   380   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 4   376   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 5   373   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 6   371   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 7   369   209  1    6    0    0.032407  0.069007  1041.0  1041.0   repo.c
# 8   385   88   0    127  1   -0.407407  0.000000  3928.0  4832.0   repo.c
# 9   378   88   0    127  1   -0.407407  0.000000  3928.0  4832.0   repo.c
# 10  377   88   0    127  1   -0.407407  0.000000  3928.0  4832.0   repo.c
# 11  374   88   0    127  1   -0.407407  0.000000  3928.0  4832.0   repo.c
#
#                func                       meth  RochiaiD      vote
# 0   xbps_repo_close  (repo.c, xbps_repo_close)  35.0      0.001972
# 1   xbps_repo_close  (repo.c, xbps_repo_close)  35.0      0.001972
# 2   xbps_repo_close  (repo.c, xbps_repo_close)  35.0      0.001972
# 3   xbps_repo_close  (repo.c, xbps_repo_close)  35.0      0.001972
# 4   xbps_repo_close  (repo.c, xbps_repo_close)  35.0      0.001972
# 5   xbps_repo_close  (repo.c, xbps_repo_close)  35.0      0.001972
# 6   xbps_repo_close  (repo.c, xbps_repo_close)  35.0      0.001972
# 7   xbps_repo_close  (repo.c, xbps_repo_close)  35.0      0.001972
# 8   xbps_repo_close  (repo.c, xbps_repo_close)  42.0      0.000000
# 9   xbps_repo_close  (repo.c, xbps_repo_close)  42.0      0.000000
# 10  xbps_repo_close  (repo.c, xbps_repo_close)  42.0      0.000000
# 11  xbps_repo_close  (repo.c, xbps_repo_close)  42.0      0.000000
# Faulty method:
#                         meth      vote  rank
# 0  (repo.c, repo_open_local)  0.034922  47.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai   Rop2  Rochiai    file  \
# 0   177   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 1   172   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 2   171   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 3   170   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 4   162   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 5   154   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 6   152   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 7   151   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 8   150   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 9   149   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 10  148   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 11  147   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 12  146   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 13  139   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 14  137   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
# 15  134   204  1    11   0    0.055556  0.069843  739.0  739.0    repo.c
#
#                func                       meth  RochiaiD      vote
# 0   repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 1   repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 2   repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 3   repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 4   repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 5   repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 6   repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 7   repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 8   repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 9   repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 10  repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 11  repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 12  repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 13  repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 14  repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# 15  repo_open_local  (repo.c, repo_open_local)  32.0      0.002183
# Top 5 methods:
#                                                  meth      vote  rank
# 0  (transaction.c, show_actions)                       1.097345  1.0
# 1  (transaction_prepare.c, compute_transaction_stats)  1.056585  2.0
# 2  (transaction.c, ttype2str)                          0.611752  3.0
# 3  (transaction_prepare.c, xbps_transaction_prepare)   0.260075  4.0
# 4  (transaction.c, exec_transaction)                   0.222501  5.0
# Top 1:
#                             meth      vote  rank
# 0  (transaction.c, show_actions)  1.097345  1.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai  Rop2  Rochiai  \
# 0   108   14   1    201  0    0.935185  0.258199  28.0  28.0
# 1   106   14   1    201  0    0.935185  0.258199  28.0  28.0
# 2   104   14   1    201  0    0.935185  0.258199  28.0  28.0
# 3   103   14   1    201  0    0.935185  0.258199  28.0  28.0
# 4   101   14   1    201  0    0.935185  0.258199  28.0  28.0
# 5   100   14   1    201  0    0.935185  0.258199  28.0  28.0
# 6   99    14   1    201  0    0.935185  0.258199  28.0  28.0
# 7   98    14   1    201  0    0.935185  0.258199  28.0  28.0
# 8   97    14   1    201  0    0.935185  0.258199  28.0  28.0
# 9   96    14   1    201  0    0.935185  0.258199  28.0  28.0
# 10  95    14   1    201  0    0.935185  0.258199  28.0  28.0
# 11  94    14   1    201  0    0.935185  0.258199  28.0  28.0
# 12  93    14   1    201  0    0.935185  0.258199  28.0  28.0
# 13  91    14   1    201  0    0.935185  0.258199  28.0  28.0
# 14  90    14   1    201  0    0.935185  0.258199  28.0  28.0
# 15  89    14   1    201  0    0.935185  0.258199  28.0  28.0
# 16  83    14   1    201  0    0.935185  0.258199  28.0  28.0
#
#              file          func                           meth  RochiaiD  \
# 0   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 1   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 2   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 3   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 4   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 5   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 6   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 7   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 8   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 9   transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 10  transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 11  transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 12  transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 13  transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 14  transaction.c  show_actions  (transaction.c, show_actions)  4.0
# 15  transaction.c  show_actions  (transaction.c, show_actions)  4.0
# ...
# 47  271   175  1    40   0    0.189815  0.075378  502.0   502.0
# 48  406   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 49  403   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 50  391   9    0    206  1   -0.041667  0.000000  2778.0  4832.0
# 51  378   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 52  376   2    0    213  1   -0.009259  0.000000  1722.0  4832.0
# 53  375   7    0    208  1   -0.032407  0.000000  2669.0  4832.0
# 54  319   2    0    213  1   -0.009259  0.000000  1722.0  4832.0
# 55  318   2    0    213  1   -0.009259  0.000000  1722.0  4832.0
# 56  309   33   0    182  1   -0.152778  0.000000  3542.0  4832.0
#
#                      file                      func  \
# 0   transaction_prepare.c  xbps_transaction_prepare
# 1   transaction_prepare.c  xbps_transaction_prepare
# 2   transaction_prepare.c  xbps_transaction_prepare
# 3   transaction_prepare.c  xbps_transaction_prepare
# 4   transaction_prepare.c  xbps_transaction_prepare
# 5   transaction_prepare.c  xbps_transaction_prepare
# 6   transaction_prepare.c  xbps_transaction_prepare
# 7   transaction_prepare.c  xbps_transaction_prepare
# 8   transaction_prepare.c  xbps_transaction_prepare
# 9   transaction_prepare.c  xbps_transaction_prepare
# 10  transaction_prepare.c  xbps_transaction_prepare
# 11  transaction_prepare.c  xbps_transaction_prepare
# 12  transaction_prepare.c  xbps_transaction_prepare
# 13  transaction_prepare.c  xbps_transaction_prepare
# 14  transaction_prepare.c  xbps_transaction_prepare
# 15  transaction_prepare.c  xbps_transaction_prepare
# 16  transaction_prepare.c  xbps_transaction_prepare
# 17  transaction_prepare.c  xbps_transaction_prepare
# 18  transaction_prepare.c  xbps_transaction_prepare
# 19  transaction_prepare.c  xbps_transaction_prepare
# 20  transaction_prepare.c  xbps_transaction_prepare
# 21  transaction_prepare.c  xbps_transaction_prepare
# 22  transaction_prepare.c  xbps_transaction_prepare
# 23  transaction_prepare.c  xbps_transaction_prepare
# 24  transaction_prepare.c  xbps_transaction_prepare
# 25  transaction_prepare.c  xbps_transaction_prepare
# 26  transaction_prepare.c  xbps_transaction_prepare
# 27  transaction_prepare.c  xbps_transaction_prepare
# 28  transaction_prepare.c  xbps_transaction_prepare
# 29  transaction_prepare.c  xbps_transaction_prepare
# 30  transaction_prepare.c  xbps_transaction_prepare
# 31  transaction_prepare.c  xbps_transaction_prepare
# 32  transaction_prepare.c  xbps_transaction_prepare
# 33  transaction_prepare.c  xbps_transaction_prepare
# 34  transaction_prepare.c  xbps_transaction_prepare
# 35  transaction_prepare.c  xbps_transaction_prepare
# 36  transaction_prepare.c  xbps_transaction_prepare
# 37  transaction_prepare.c  xbps_transaction_prepare
# 38  transaction_prepare.c  xbps_transaction_prepare
# 39  transaction_prepare.c  xbps_transaction_prepare
# 40  transaction_prepare.c  xbps_transaction_prepare
# 41  transaction_prepare.c  xbps_transaction_prepare
# 42  transaction_prepare.c  xbps_transaction_prepare
# 43  transaction_prepare.c  xbps_transaction_prepare
# 44  transaction_prepare.c  xbps_transaction_prepare
# 45  transaction_prepare.c  xbps_transaction_prepare
# 46  transaction_prepare.c  xbps_transaction_prepare
# 47  transaction_prepare.c  xbps_transaction_prepare
# 48  transaction_prepare.c  xbps_transaction_prepare
# 49  transaction_prepare.c  xbps_transaction_prepare
# 50  transaction_prepare.c  xbps_transaction_prepare
# 51  transaction_prepare.c  xbps_transaction_prepare
# 52  transaction_prepare.c  xbps_transaction_prepare
# 53  transaction_prepare.c  xbps_transaction_prepare
# 54  transaction_prepare.c  xbps_transaction_prepare
# 55  transaction_prepare.c  xbps_transaction_prepare
# 56  transaction_prepare.c  xbps_transaction_prepare
#
#                                                  meth  RochiaiD      vote
# 0   (transaction_prepare.c, xbps_transaction_prepare)  12.0      0.006354
# 1   (transaction_prepare.c, xbps_transaction_prepare)  12.0      0.006354
# 2   (transaction_prepare.c, xbps_transaction_prepare)  12.0      0.006354
# 3   (transaction_prepare.c, xbps_transaction_prepare)  12.0      0.006354
# 4   (transaction_prepare.c, xbps_transaction_prepare)  12.0      0.006354
# 5   (transaction_prepare.c, xbps_transaction_prepare)  12.0      0.006354
# 6   (transaction_prepare.c, xbps_transaction_prepare)  12.0      0.006354
# 7   (transaction_prepare.c, xbps_transaction_prepare)  12.0      0.006354
# 8   (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 9   (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 10  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 11  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 12  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 13  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 14  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 15  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 16  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 17  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 18  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 19  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 20  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 21  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 22  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 23  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 24  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 25  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 26  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 27  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 28  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 29  (transaction_prepare.c, xbps_transaction_prepare)  14.0      0.005399
# 30  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 31  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 32  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 33  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 34  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 35  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 36  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 37  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 38  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 39  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 40  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 41  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 42  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 43  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 44  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 45  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 46  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 47  (transaction_prepare.c, xbps_transaction_prepare)  15.0      0.005025
# 48  (transaction_prepare.c, xbps_transaction_prepare)  42.0      0.000000
# 49  (transaction_prepare.c, xbps_transaction_prepare)  42.0      0.000000
# 50  (transaction_prepare.c, xbps_transaction_prepare)  42.0      0.000000
# 51  (transaction_prepare.c, xbps_transaction_prepare)  42.0      0.000000
# 52  (transaction_prepare.c, xbps_transaction_prepare)  42.0      0.000000
# 53  (transaction_prepare.c, xbps_transaction_prepare)  42.0      0.000000
# 54  (transaction_prepare.c, xbps_transaction_prepare)  42.0      0.000000
# 55  (transaction_prepare.c, xbps_transaction_prepare)  42.0      0.000000
# 56  (transaction_prepare.c, xbps_transaction_prepare)  42.0      0.000000
# Top 5:
#                                 meth      vote  rank
# 0  (transaction.c, exec_transaction)  0.222501  5.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai  \
# 0   419   14   1    201  0    0.935185  0.258199  28.0    28.0
# 1   418   14   1    201  0    0.935185  0.258199  28.0    28.0
# 2   454   171  1    44   0    0.208333  0.076249  137.0   137.0
# 3   417   171  1    44   0    0.208333  0.076249  137.0   137.0
# 4   412   171  1    44   0    0.208333  0.076249  137.0   137.0
# 5   411   171  1    44   0    0.208333  0.076249  137.0   137.0
# 6   410   171  1    44   0    0.208333  0.076249  137.0   137.0
# 7   409   171  1    44   0    0.208333  0.076249  137.0   137.0
# 8   457   175  1    40   0    0.189815  0.075378  502.0   502.0
# 9   456   175  1    40   0    0.189815  0.075378  502.0   502.0
# 10  455   175  1    40   0    0.189815  0.075378  502.0   502.0
# 11  453   175  1    40   0    0.189815  0.075378  502.0   502.0
# 12  452   175  1    40   0    0.189815  0.075378  502.0   502.0
# 13  357   175  1    40   0    0.189815  0.075378  502.0   502.0
# 14  354   175  1    40   0    0.189815  0.075378  502.0   502.0
# 15  353   175  1    40   0    0.189815  0.075378  502.0   502.0
# 16  351   175  1    40   0    0.189815  0.075378  502.0   502.0
# 17  349   175  1    40   0    0.189815  0.075378  502.0   502.0
# 18  345   175  1    40   0    0.189815  0.075378  502.0   502.0
# 19  450   4    0    211  1   -0.018519  0.000000  2331.0  4832.0
# 20  447   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 21  443   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 22  442   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 23  435   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 24  430   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 25  424   167  0    48   1   -0.773148  0.000000  4793.0  4832.0
# 26  401   20   0    195  1   -0.092593  0.000000  3192.0  4832.0
# 27  399   1    0    214  1   -0.004630  0.000000  1572.0  4832.0
# 28  398   1    0    214  1   -0.004630  0.000000  1572.0  4832.0
# 29  377   1    0    214  1   -0.004630  0.000000  1572.0  4832.0
# 30  376   9    0    206  1   -0.041667  0.000000  2778.0  4832.0
# 31  375   9    0    206  1   -0.041667  0.000000  2778.0  4832.0
# 32  374   9    0    206  1   -0.041667  0.000000  2778.0  4832.0
# 33  372   10   0    205  1   -0.046296  0.000000  2814.0  4832.0
# 34  370   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 35  369   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 36  367   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 37  366   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 38  365   15   0    200  1   -0.069444  0.000000  3046.0  4832.0
# 39  363   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 40  362   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 41  360   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 42  359   5    0    210  1   -0.023148  0.000000  2442.0  4832.0
# 43  358   20   0    195  1   -0.092593  0.000000  3192.0  4832.0
#
#              file              func                               meth  \
# 0   transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 1   transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 2   transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 3   transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 4   transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 5   transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 6   transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 7   transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 8   transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 9   transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 10  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 11  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 12  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 13  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 14  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 15  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 16  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 17  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 18  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 19  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 20  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 21  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 22  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 23  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 24  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 25  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 26  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 27  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 28  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 29  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 30  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 31  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 32  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 33  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 34  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 35  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 36  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 37  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 38  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 39  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 40  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 41  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 42  transaction.c  exec_transaction  (transaction.c, exec_transaction)
# 43  transaction.c  exec_transaction  (transaction.c, exec_transaction)
#
#     RochiaiD      vote
# 0   4.0       0.064550
# 1   4.0       0.064550
# 2   12.0      0.006354
# 3   12.0      0.006354
# 4   12.0      0.006354
# 5   12.0      0.006354
# 6   12.0      0.006354
# 7   12.0      0.006354
# 8   15.0      0.005025
# 9   15.0      0.005025
# 10  15.0      0.005025
# 11  15.0      0.005025
# 12  15.0      0.005025
# 13  15.0      0.005025
# 14  15.0      0.005025
# 15  15.0      0.005025
# 16  15.0      0.005025
# 17  15.0      0.005025
# 18  15.0      0.005025
# 19  42.0      0.000000
# 20  42.0      0.000000
# 21  42.0      0.000000
# 22  42.0      0.000000
# 23  42.0      0.000000
# 24  42.0      0.000000
# 25  42.0      0.000000
# 26  42.0      0.000000
# 27  42.0      0.000000
# 28  42.0      0.000000
# 29  42.0      0.000000
# 30  42.0      0.000000
# 31  42.0      0.000000
# 32  42.0      0.000000
# 33  42.0      0.000000
# 34  42.0      0.000000
# 35  42.0      0.000000
# 36  42.0      0.000000
# 37  42.0      0.000000
# 38  42.0      0.000000
# 39  42.0      0.000000
# 40  42.0      0.000000
# 41  42.0      0.000000
# 42  42.0      0.000000
# 43  42.0      0.000000

# %% [markdown]
# # 감상
#
# 그래도 51(op2 기준)등 정도까지는 올라오는 듯.
#
# 한 번도 passing test에 의해서 실행되는 method가 너무 많거나, 그저 test가 부족해서 tie가 너무 많은 경우 등이 아니기 때문에,
#
# hierarchy를 이용하는 방법이든 뭔가를 해서 성능을 더 올릴 수도 있을 듯.
