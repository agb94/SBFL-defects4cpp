# %%
import os
import pandas as pd
import numpy as np
pd.set_option("display.max_colwidth", 2)

os.chdir("/home/coinse/Workspace/SBFL")

# %% [markdown]
# # Load bug info

# %%
from scripts.util import load_bug_data, find_covmat_func, find_covmat_idx
from functools import reduce
from typing import Set

pid, vid = "cppcheck", 16

bug = load_bug_data(pid, vid)

print(f"{bug.buggy_files=}")
print(f"{bug.buggy_lines=}")
print("bug.coverage_df=")
display(bug.coverage_df)
print(f"{bug.failing_tests=}")
print(f"{bug.failing_tests_GT=}")
print("bug.functions={", end="")
for func in list(bug.functions)[:5]:
    print(f"{func},", end=" ")
print(", ...}")
print(f"{bug.id=}")
print(f"{bug.num_test_cases=}")
print(f"{bug.passing_tests=}")
print(f"{bug.path_to_cov_df=}")
print(f"{bug.path_to_patch=}")
print(f"{bug.path_to_test_results=}")
print("bug.source_files=", end="")
for src in list(bug.source_files)[:5]:
    print(f"{src},", end=" ")
print(", ...}")

fault_idxs = sorted(bug.buggy_lines)
# fault_idx2meth = {}
fault_meth2idx = {}
err_msg = ""
for fault_idx in fault_idxs:
    succ_func, ret_func = find_covmat_func(
        pid, bug.coverage_df, fault_idx, debug=False
    )
    if succ_func:
        succ_idx, ret_idx = find_covmat_idx(
            pid, bug.coverage_df, fault_idx, debug=False
        )
        if succ_idx:
            if ret_func in fault_meth2idx:
                fault_meth2idx[ret_func].add(ret_idx)
            else:
                fault_meth2idx[ret_func] = {ret_idx}
        else:
            print(f"{ret_idx}")
            if ret_func not in fault_meth2idx:
                fault_meth2idx[ret_func] = set()
    else:
        print(f"{ret_func}")
# fault_meths: Set = reduce(
#     lambda x, y: x | set([y]), fault_idx2meth.values(), set()
# )
# fault_meth2idx = {
#     v: {idx for idx in fault_idx2meth if fault_idx2meth[idx] == v}
#     for v in fault_meths
# }
fault_meths = set(fault_meth2idx.keys())
for meth in fault_meth2idx:
    print(f"{meth=}: {fault_meth2idx[meth]}")
# print(f"{fault_meths=}")
# Out:
# bug.buggy_files={'lib/forwardanalyzer.cpp'}
# bug.buggy_lines={('lib/forwardanalyzer.cpp', 293), ('lib/forwardanalyzer.cpp', 308), ('lib/forwardanalyzer.cpp', 311), ('lib/forwardanalyzer.cpp', 307), ('lib/forwardanalyzer.cpp', 50), ('lib/forwardanalyzer.cpp', 310), ('lib/forwardanalyzer.cpp', 294), ('lib/forwardanalyzer.cpp', 49)}
# bug.coverage_df=
#                                                                                                                          15  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   2
#                                            _Z41__static_initialization_and_destruction_0ii                         938   4
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          71  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    2
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    1
#                                                                                                                    52    1
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          50  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   60
#                                                                                                                    167   60
#                                                                                                                    168   60
#
#                                                                                                                          69  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    2
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    1
#                                                                                                                    52    1
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          6  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          56  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   6
#                                                                                                                    167   6
#                                                                                                                    168   6
#
#                                                                                                                          39  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   14
#                                                                                                                    167   14
#                                                                                                                    168   14
#
#                                                                                                                          54  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   10
#                                                                                                                    167   10
#                                                                                                                    168   10
#
#                                                                                                                          20  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          51  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          ...  \
# file                                       function                                                                line  ...
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    ...
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    ...
#                                                                                                                    48    ...
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    ...
#                                                                                                                    52    ...
# ...                                                                                                                      ...
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   ...
#                                            _Z41__static_initialization_and_destruction_0ii                         938   ...
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   ...
#                                                                                                                    167   ...
#                                                                                                                    168   ...
#
#                                                                                                                          68  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    2
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    1
#                                                                                                                    52    1
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          33  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          75  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    2
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    1
#                                                                                                                    52    1
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          17  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          8  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   8
#                                            _Z41__static_initialization_and_destruction_0ii                         938   7
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          5  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          26  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          82  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    2
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    1
#                                                                                                                    52    1
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          55  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   3
#                                                                                                                    167   3
#                                                                                                                    168   3
#
#                                                                                                                          14
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   8
#                                                                                                                    167   8
#                                                                                                                    168   8
#
# [39698 rows x 84 columns]
# bug.failing_tests={'30'}
# bug.failing_tests_GT={'30'}
# bug.functions={('/home/workspace/lib/timer.h', '_ZN12TimerResultsC2Ev'), ('/home/workspace/lib/templatesimplifier.cpp', '_ZN18TemplateSimplifier18templateParametersEPK5Token'), ('/home/workspace/lib/symboldatabase.cpp', '_ZNK8Function14getArgumentVarEi'), ('/home/workspace/lib/astutils.cpp', '_ZL8nonLocalPK8Variableb'), ('/home/workspace/lib/astutils.cpp', '_Z11isTemporarybPK5TokenPK7Libraryb'), , ...}
# bug.id='cppcheck-16'
# bug.num_test_cases=84
# bug.passing_tests={'44', '31', '18', '17', '7', '16', '2', '77', '78', '6', '83', '12', '4', '20', '23', '67', '46', '55', '27', '41', '79', '73', '28', '15', '34', '9', '35', '58', '51', '43', '74', '54', '52', '24', '45', '71', '38', '53', '37', '14', '56', '3', '1', '60', '19', '75', '76', '29', '36', '13', '39', '59', '49', '48', '68', '26', '47', '70', '66', '42', '8', '57', '72', '82', '65', '69', '84', '62', '61', '21', '32', '5', '81', '11', '22', '64', '10', '25', '80', '50', '33', '40', '63'}
# bug.path_to_cov_df='/home/coinse/Workspace/defects4cpp/coverage/cppcheck_16_buggy/coverage_df.pkl'
# bug.path_to_patch='/home/coinse/Workspace/defects4cpp/defects4cpp/taxonomy/cppcheck/patch/0016-buggy.patch'
# bug.path_to_test_results='/home/coinse/Workspace/defects4cpp/coverage/cppcheck_16_buggy/test_results.json'
# bug.source_files=/home/workspace/cli/cppcheckexecutor.cpp, /home/workspace/lib/timer.cpp, /home/workspace/lib/astutils.cpp, /home/workspace/lib/checkio.h, /home/workspace/lib/pathmatch.h, , ...}
# ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_', 310)
# meth=('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_'): {('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_', 49), ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_', 50)}
# meth=('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_'): {('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_', 293), ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_', 308), ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_', 311), ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_', 294), ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_', 307)}

# %% [markdown]
# # Get spectra

# %%
covmat = bug.coverage_df
pass_tcs = bug.passing_tests
fail_tcs = bug.failing_tests

covmat_bool = covmat.astype(bool)
P = len(pass_tcs)
F = len(fail_tcs)
e_p = covmat_bool[pass_tcs].sum(axis=1)
e_f = covmat_bool[fail_tcs].sum(axis=1)
n_p = P - e_p
n_f = F - e_f
spectra = pd.DataFrame(
    {
        "line": covmat.index.to_list(),
        "e_p": e_p,
        "e_f": e_f,
        "n_p": n_p,
        "n_f": n_f,
    }
)

display(spectra)
# Out:
#                                                                                                                                                                                                                                                line  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarD2Ev, 44)
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2Ev, 47)
#                                                                                                                    48    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2Ev, 48)
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger, 51)
#                                                                                                                    52    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger, 52)
# ...                                                                                                                                                                                                                          ...
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   (/home/workspace/lib/checkbufferoverrun.cpp, _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb, 935)
#                                            _Z41__static_initialization_and_destruction_0ii                         938   (/home/workspace/lib/checkbufferoverrun.cpp, _Z41__static_initialization_and_destruction_0ii, 938)
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token, 166)
#                                                                                                                    167   (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token, 167)
#                                                                                                                    168   (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token, 168)
#
#                                                                                                                          e_p  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    18
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    83
#                                                                                                                    48    83
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    18
#                                                                                                                    52    18
# ...                                                                                                                      ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   2
#                                            _Z41__static_initialization_and_destruction_0ii                         938   83
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   17
#                                                                                                                    167   17
#                                                                                                                    168   17
#
#                                                                                                                          e_f  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   1
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          n_p  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    65
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    0
#                                                                                                                    48    0
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    65
#                                                                                                                    52    65
# ...                                                                                                                      ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   81
#                                            _Z41__static_initialization_and_destruction_0ii                         938   0
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   66
#                                                                                                                    167   66
#                                                                                                                    168   66
#
#                                                                                                                          n_f
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    1
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    0
#                                                                                                                    48    0
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    1
#                                                                                                                    52    1
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   1
#                                            _Z41__static_initialization_and_destruction_0ii                         938   0
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   1
#                                                                                                                    167   1
#                                                                                                                    168   1
#
# [39698 rows x 5 columns]

# %% [markdown]
# # Compute suspiciousness scores

# %%
def ochiai(e_f, e_p, n_f, n_p):
    return e_f / np.sqrt(e_p + e_f) / np.sqrt(e_f + n_f) if e_f else 0.0


def op2(e_f, e_p, n_f, n_p):
    return e_f - e_p / (e_p + n_p + 1)

spectra["Sop2"] = spectra.apply(
    lambda row: op2(row.e_f, row.e_p, row.n_f, row.n_p), axis=1
)
spectra["Sochiai"] = spectra.apply(
    lambda row: ochiai(row.e_f, row.e_p, row.n_f, row.n_p), axis=1
)
spectra["Rop2"] = spectra.Sop2.rank(ascending=False, method="max")
spectra["Rochiai"] = spectra.Sochiai.rank(ascending=False, method="max")

# %% [markdown]
# # Line level SBFL

# %%
for fault_meth in fault_meth2idx:
    fault_idxs_of_meth = fault_meth2idx[fault_meth]
    print("fault meth:", fault_meth)
    for fault_idx in fault_idxs_of_meth:
        print("fault idx:", tuple(fault_idx))
    print("SBFL score of faulty method:")
    display(spectra.loc[fault_idxs_of_meth].reset_index(drop=True))

print("Top 5 SBFL scores:")
print("Op2:")
display(
    spectra.sort_values("Sop2", ascending=False).head(5).reset_index(drop=True)
)
print("Ochiai:")
display(
    spectra.sort_values("Sochiai", ascending=False)
    .head(5)
    .reset_index(drop=True)
)
# Out:
# fault meth: ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_')
# fault idx: ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_', 49)
# fault idx: ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_', 50)
# SBFL score of faulty method:
#                                                                                                                                     line  \
# 0  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_, 49)
# 1  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_, 50)
#
#    e_p  e_f  n_p  n_f      Sop2  Sochiai     Rop2  Rochiai
# 0  7    0    76   1   -0.083333  0.0      32023.0  39698.0
# 1  4    0    79   1   -0.047619  0.0      29949.0  39698.0
# fault meth: ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_')
# fault idx: ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_', 293)
# fault idx: ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_', 308)
# fault idx: ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_', 311)
# fault idx: ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_', 294)
# fault idx: ('/home/workspace/lib/forwardanalyzer.cpp', '_ZN16ForwardTraversal11updateRangeEP5TokenPKS0_', 307)
# SBFL score of faulty method:
#                                                                                               line  \
# 0  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_, 293)
# 1  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_, 308)
# 2  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_, 311)
# 3  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_, 294)
# 4  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_, 307)
#
#    e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai
# 0  63   1    20   0    0.250000  0.125000  8916.0  8916.0
# 1  15   1    68   0    0.821429  0.250000  1792.0  1792.0
# 2  15   1    68   0    0.821429  0.250000  1792.0  1792.0
# 3  30   1    53   0    0.642857  0.179605  4467.0  4467.0
# 4  8    1    75   0    0.904762  0.333333  903.0   903.0
# Top 5 SBFL scores:
# Op2:
#                                                                                                                                                                                    line  \
# 0  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv, 357)
# 1  (/home/workspace/lib/valueflow.cpp, _ZZNK25ValueFlowConditionHandler14afterConditionEP9TokenListP14SymbolDatabaseP11ErrorLoggerPK8SettingsENKUlPK8VariableE0_clESB_, 4078)
# 2  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings, 253)
# 3  (/home/workspace/lib/ctu.cpp, _ZN3CTU11getFileInfoEPK9Tokenizer, 329)
# 4  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer19analyseWholeProgramEPKN3CTU8FileInfoERKNSt7__debug4listIPN5Check8FileInfoESaIS8_EEERK8SettingsR11ErrorLogger, 612)
#
#    e_p  e_f  n_p  n_f  Sop2  Sochiai  Rop2  Rochiai
# 0  0    1    83   0    1.0   1.0      73.0  73.0
# 1  0    1    83   0    1.0   1.0      73.0  73.0
# 2  0    1    83   0    1.0   1.0      73.0  73.0
# 3  0    1    83   0    1.0   1.0      73.0  73.0
# 4  0    1    83   0    1.0   1.0      73.0  73.0
# Ochiai:
#                                                                                                                            line  \
# 0  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv, 345)
# 1  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings, 253)
# 2  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer22pointerArithmeticErrorEPK5TokenPKN9ValueFlow5ValueEb, 508)
# 3  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings, 219)
# 4  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv, 414)
#
#    e_p  e_f  n_p  n_f  Sop2  Sochiai  Rop2  Rochiai
# 0  0    1    83   0    1.0   1.0      73.0  73.0
# 1  0    1    83   0    1.0   1.0      73.0  73.0
# 2  0    1    83   0    1.0   1.0      73.0  73.0
# 3  0    1    83   0    1.0   1.0      73.0  73.0
# 4  0    1    83   0    1.0   1.0      73.0  73.0

# %% [markdown]
# # Method level SBFL

# %%
spectra["file"] = spectra.index.map(lambda x: x[0])
spectra["func"] = spectra.index.map(lambda x: x[1])
spectra["line"] = spectra.index.map(lambda x: x[2])
# (file, func) is meth
spectra["meth"] = spectra.apply(lambda row: (row.file, row.func), axis=1)
spectra.reset_index(drop=True, inplace=True)
display(spectra)
# Out:
#        line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0      44    18   0    65   1   -0.214286  0.000000  36459.0  39698.0
# 1      47    83   1    0    0    0.011905  0.109109  12642.0  12642.0
# 2      48    83   1    0    0    0.011905  0.109109  12642.0  12642.0
# 3      51    18   0    65   1   -0.214286  0.000000  36459.0  39698.0
# 4      52    18   0    65   1   -0.214286  0.000000  36459.0  39698.0
# ...    ..    ..  ..    ..  ..         ...       ...      ...      ...
# 39693  935   2    0    81   1   -0.023810  0.000000  27013.0  39698.0
# 39694  938   83   1    0    0    0.011905  0.109109  12642.0  12642.0
# 39695  166   17   0    66   1   -0.202381  0.000000  35775.0  39698.0
# 39696  167   17   0    66   1   -0.202381  0.000000  35775.0  39698.0
# 39697  168   17   0    66   1   -0.202381  0.000000  35775.0  39698.0
#
#                                              file  \
# 0      /home/workspace/lib/checkunusedvar.h
# 1      /home/workspace/lib/checkunusedvar.h
# 2      /home/workspace/lib/checkunusedvar.h
# 3      /home/workspace/lib/checkunusedvar.h
# 4      /home/workspace/lib/checkunusedvar.h
# ...                                     ...
# 39693  /home/workspace/lib/checkbufferoverrun.cpp
# 39694  /home/workspace/lib/checkbufferoverrun.cpp
# 39695  /home/workspace/lib/templatesimplifier.h
# 39696  /home/workspace/lib/templatesimplifier.h
# 39697  /home/workspace/lib/templatesimplifier.h
#
#                                                                           func  \
# 0      _ZN14CheckUnusedVarD2Ev
# 1      _ZN14CheckUnusedVarC2Ev
# 2      _ZN14CheckUnusedVarC2Ev
# 3      _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger
# 4      _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger
# ...                                                            ...
# 39693  _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb
# 39694  _Z41__static_initialization_and_destruction_0ii
# 39695  _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token
# 39696  _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token
# 39697  _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token
#
#                                                                                                                         meth
# 0      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarD2Ev)
# 1      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2Ev)
# 2      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2Ev)
# 3      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger)
# 4      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger)
# ...                                                                                                    ...
# 39693  (/home/workspace/lib/checkbufferoverrun.cpp, _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb)
# 39694  (/home/workspace/lib/checkbufferoverrun.cpp, _Z41__static_initialization_and_destruction_0ii)
# 39695  (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token)
# 39696  (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token)
# 39697  (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token)
#
# [39698 rows x 12 columns]

# %% [markdown]
# ## Max aggregation

# %%
print("[Op2]")
spectra_max_op2 = spectra.copy().sort_values(
    ["Sop2", "meth", "line"], ascending=False
)
spectra_max_op2.drop_duplicates(subset="meth", keep="first", inplace=True)
spectra_max_op2 = spectra_max_op2[
    ["meth", "line", "e_p", "e_f", "n_p", "n_f", "Sop2"]
]
spectra_max_op2["Rop2"] = spectra_max_op2.Sop2.rank(
    ascending=False, method="max"
)
print("Faulty method:")
display(
    spectra_max_op2.loc[spectra_max_op2.meth.isin(fault_meths)].reset_index(
        drop=True
    )
)
print("Top 20 methods:")
display(spectra_max_op2.head(20).reset_index(drop=True))
print()
print("[Ochiai]")
spectra_max_ochiai = spectra.copy().sort_values(
    ["Sochiai", "meth", "line"], ascending=False
)
spectra_max_ochiai.drop_duplicates(subset="meth", keep="first", inplace=True)
spectra_max_ochiai = spectra_max_ochiai[
    ["meth", "line", "e_p", "e_f", "n_p", "n_f", "Sochiai"]
]
spectra_max_ochiai["Rochiai"] = spectra_max_ochiai.Sochiai.rank(
    ascending=False, method="max"
)
print("Faulty method:")
display(
    spectra_max_ochiai.loc[
        spectra_max_ochiai.meth.isin(fault_meths)
    ].reset_index(drop=True)
)
print("Top 20 methods:")
display(spectra_max_ochiai.head(20).reset_index(drop=True))
# Out:
# [Op2]
# Faulty method:
#                                                                                                                                 meth  \
# 0  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# 1  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
#
#    line  e_p  e_f  n_p  n_f      Sop2   Rop2
# 0  368   2    1    81   0    0.976190  58.0
# 1  48    4    1    79   0    0.952381  105.0
# Top 20 methods:
#                                                                                                                                                                                                                                    meth  \
# 0   (/home/workspace/lib/valueflow.cpp, _ZZNK25ValueFlowConditionHandler14afterConditionEP9TokenListP14SymbolDatabaseP11ErrorLoggerPK8SettingsENKUlPK8VariableE0_clESB_)
# 1   (/home/workspace/lib/valueflow.cpp, _ZNK29MultiValueFlowForwardAnalyzer11updateScopeEPK5Tokenb)
# 2   (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 3   (/home/workspace/lib/valueflow.cpp, _ZL16valueFlowReverseP9TokenListP5TokenPKS1_N9ValueFlow5ValueES6_P11ErrorLoggerPK8Settings)
# 4   (/home/workspace/lib/library.cpp, _ZNK7Library15isScopeNoReturnEPK5TokenPNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE)
# 5   (/home/workspace/lib/ctu.cpp, _ZN3CTU11getFileInfoEPK9Tokenizer)
# 6   (/home/workspace/lib/ctu.cpp, _ZL8findPathRKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEixN3CTU8FileInfo16InvalidValueTypeERKNSt7__debug3mapIS4_NSA_4listIPKNS8_8CallBaseESaISF_EEESt4lessIS4_ESaISt4pairIS5_SH_EEEEPSF_ib)
# 7   (/home/workspace/lib/ctu.cpp, _ZL17getUnsafeFunctionPK9TokenizerPK8SettingsPK5ScopeiPK5CheckPFbSA_PK5TokenPxE)
# 8   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer25redundantConditionWarningEPK5TokenPKN9ValueFlow5ValueES2_b)
# 9   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 10  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer22pointerArithmeticErrorEPK5TokenPKN9ValueFlow5ValueEb)
# 11  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer19analyseWholeProgramEPKN3CTU8FileInfoERKNSt7__debug4listIPN5Check8FileInfoESaIS8_EEERK8SettingsR11ErrorLogger)
# 12  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 13  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer16nullPointerErrorEPK5TokenRKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEPKN9ValueFlow5ValueEb)
# 14  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
# 15  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer10arithmeticEv)
# 16  (/home/workspace/lib/checknullpointer.cpp, _ZL20arithmeticTypeStringPK5Token)
# 17  (/home/workspace/lib/checknullpointer.cpp, _ZL17isNullablePointerPK5TokenPK8Settings)
# 18  (/home/workspace/lib/astutils.cpp, _Z16isEscapeFunctionPK5TokenPK7Library)
# 19  (/usr/include/c++/7/debug/unordered_map, _ZNSt7__debug13unordered_mapIiN9ValueFlow5ValueESt4hashIiESt8equal_toIiESaISt4pairIKiS2_EEEC2ESt16initializer_listIS9_EmRKS4_RKS6_RKSA_)
#
#     line  e_p  e_f  n_p  n_f      Sop2  Rop2
# 0   4083  0    1    83   0    1.000000  19.0
# 1   4785  0    1    83   0    1.000000  19.0
# 2   5652  0    1    83   0    1.000000  19.0
# 3   1906  0    1    83   0    1.000000  19.0
# 4   1103  0    1    83   0    1.000000  19.0
# 5   329   0    1    83   0    1.000000  19.0
# 6   498   0    1    83   0    1.000000  19.0
# 7   431   0    1    83   0    1.000000  19.0
# 8   526   0    1    83   0    1.000000  19.0
# 9   414   0    1    83   0    1.000000  19.0
# 10  508   0    1    83   0    1.000000  19.0
# 11  612   0    1    83   0    1.000000  19.0
# 12  111   0    1    83   0    1.000000  19.0
# 13  444   0    1    83   0    1.000000  19.0
# 14  253   0    1    83   0    1.000000  19.0
# 15  488   0    1    83   0    1.000000  19.0
# 16  498   0    1    83   0    1.000000  19.0
# 17  269   0    1    83   0    1.000000  19.0
# 18  1092  0    1    83   0    1.000000  19.0
# 19  132   1    1    82   0    0.988095  41.0
# [Ochiai]
# Faulty method:
#                                                                                                                                 meth  \
# 0  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# 1  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
#
#    line  e_p  e_f  n_p  n_f   Sochiai  Rochiai
# 0  368   2    1    81   0    0.577350  58.0
# 1  48    4    1    79   0    0.447214  105.0
# Top 20 methods:
#                                                                                                                                                                                                                                    meth  \
# 0   (/home/workspace/lib/valueflow.cpp, _ZZNK25ValueFlowConditionHandler14afterConditionEP9TokenListP14SymbolDatabaseP11ErrorLoggerPK8SettingsENKUlPK8VariableE0_clESB_)
# 1   (/home/workspace/lib/valueflow.cpp, _ZNK29MultiValueFlowForwardAnalyzer11updateScopeEPK5Tokenb)
# 2   (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 3   (/home/workspace/lib/valueflow.cpp, _ZL16valueFlowReverseP9TokenListP5TokenPKS1_N9ValueFlow5ValueES6_P11ErrorLoggerPK8Settings)
# 4   (/home/workspace/lib/library.cpp, _ZNK7Library15isScopeNoReturnEPK5TokenPNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE)
# 5   (/home/workspace/lib/ctu.cpp, _ZN3CTU11getFileInfoEPK9Tokenizer)
# 6   (/home/workspace/lib/ctu.cpp, _ZL8findPathRKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEixN3CTU8FileInfo16InvalidValueTypeERKNSt7__debug3mapIS4_NSA_4listIPKNS8_8CallBaseESaISF_EEESt4lessIS4_ESaISt4pairIS5_SH_EEEEPSF_ib)
# 7   (/home/workspace/lib/ctu.cpp, _ZL17getUnsafeFunctionPK9TokenizerPK8SettingsPK5ScopeiPK5CheckPFbSA_PK5TokenPxE)
# 8   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer25redundantConditionWarningEPK5TokenPKN9ValueFlow5ValueES2_b)
# 9   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 10  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer22pointerArithmeticErrorEPK5TokenPKN9ValueFlow5ValueEb)
# 11  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer19analyseWholeProgramEPKN3CTU8FileInfoERKNSt7__debug4listIPN5Check8FileInfoESaIS8_EEERK8SettingsR11ErrorLogger)
# 12  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 13  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer16nullPointerErrorEPK5TokenRKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEPKN9ValueFlow5ValueEb)
# 14  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
# 15  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer10arithmeticEv)
# 16  (/home/workspace/lib/checknullpointer.cpp, _ZL20arithmeticTypeStringPK5Token)
# 17  (/home/workspace/lib/checknullpointer.cpp, _ZL17isNullablePointerPK5TokenPK8Settings)
# 18  (/home/workspace/lib/astutils.cpp, _Z16isEscapeFunctionPK5TokenPK7Library)
# 19  (/usr/include/c++/7/debug/unordered_map, _ZNSt7__debug13unordered_mapIiN9ValueFlow5ValueESt4hashIiESt8equal_toIiESaISt4pairIKiS2_EEEC2ESt16initializer_listIS9_EmRKS4_RKS6_RKSA_)
#
#     line  e_p  e_f  n_p  n_f   Sochiai  Rochiai
# 0   4083  0    1    83   0    1.000000  19.0
# 1   4785  0    1    83   0    1.000000  19.0
# 2   5652  0    1    83   0    1.000000  19.0
# 3   1906  0    1    83   0    1.000000  19.0
# 4   1103  0    1    83   0    1.000000  19.0
# 5   329   0    1    83   0    1.000000  19.0
# 6   498   0    1    83   0    1.000000  19.0
# 7   431   0    1    83   0    1.000000  19.0
# 8   526   0    1    83   0    1.000000  19.0
# 9   414   0    1    83   0    1.000000  19.0
# 10  508   0    1    83   0    1.000000  19.0
# 11  612   0    1    83   0    1.000000  19.0
# 12  111   0    1    83   0    1.000000  19.0
# 13  444   0    1    83   0    1.000000  19.0
# 14  253   0    1    83   0    1.000000  19.0
# 15  488   0    1    83   0    1.000000  19.0
# 16  498   0    1    83   0    1.000000  19.0
# 17  269   0    1    83   0    1.000000  19.0
# 18  1092  0    1    83   0    1.000000  19.0
# 19  132   1    1    82   0    0.707107  41.0

# %% [markdown]
# ## Line2Method voting (weight: sbfl score / dense rank)

# %%
print("[Op2]")
ballot_op2 = {}
spectra_max_op2 = spectra.copy().sort_values(
    ["Sop2", "meth", "line"], ascending=False
)
spectra_max_op2["Rop2D"] = spectra_max_op2.Sop2.rank(
    ascending=False, method="dense"
)
spectra_max_op2["vote"] = spectra_max_op2.Sop2 / spectra_max_op2.Rop2D
for row in spectra_max_op2.itertuples():
    if row.meth not in ballot_op2:
        ballot_op2[row.meth] = row.vote
    else:
        ballot_op2[row.meth] += row.vote
L2M_op2 = pd.DataFrame(
    {"meth": list(ballot_op2.keys()), "vote": list(ballot_op2.values())}
)
L2M_op2["rank"] = L2M_op2.vote.rank(ascending=False, method="max")
L2M_op2.sort_values("rank", inplace=True)
L2M_op2.reset_index(drop=True, inplace=True)
for fault_meth in fault_meths:
    print("Faulty method:")
    display(L2M_op2.loc[L2M_op2.meth == fault_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_op2.loc[spectra_max_op2.meth == fault_meth].reset_index(
            drop=True
        )
    )
print("Top 5 methods:")
display(L2M_op2.head(5).reset_index(drop=True))
for idx, top_meth in enumerate(L2M_op2.head(5).meth.tolist(), 1):
    print(f"Top {idx}:")
    display(L2M_op2.loc[L2M_op2.meth == top_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_op2.loc[spectra_max_op2.meth == top_meth].reset_index(
            drop=True
        )
    )
print()
print("[Ochiai]")
ballot_ochiai = {}
spectra_max_ochiai = spectra.copy().sort_values(
    ["Sochiai", "meth", "line"], ascending=False
)
spectra_max_ochiai["RochiaiD"] = spectra_max_ochiai.Sochiai.rank(
    ascending=False, method="dense"
)
spectra_max_ochiai["vote"] = (
    spectra_max_ochiai.Sochiai / spectra_max_ochiai.RochiaiD
)
for row in spectra_max_ochiai.itertuples():
    if row.meth not in ballot_ochiai:
        ballot_ochiai[row.meth] = row.vote
    else:
        ballot_ochiai[row.meth] += row.vote
L2M_ochiai = pd.DataFrame(
    {"meth": list(ballot_ochiai.keys()), "vote": list(ballot_ochiai.values())}
)
L2M_ochiai["rank"] = L2M_ochiai.vote.rank(ascending=False, method="max")
L2M_ochiai.sort_values("rank", inplace=True)
L2M_ochiai.reset_index(drop=True, inplace=True)
for fault_meth in fault_meths:
    print("Faulty method:")
    display(
        L2M_ochiai.loc[L2M_ochiai.meth == fault_meth].reset_index(drop=True)
    )
    print("Voters:")
    display(
        spectra_max_ochiai.loc[
            spectra_max_ochiai.meth == fault_meth
        ].reset_index(drop=True)
    )
print("Top 5 methods:")
display(L2M_ochiai.head(5).reset_index(drop=True))
for idx, top_meth in enumerate(L2M_ochiai.head(5).meth.tolist(), 1):
    print(f"Top {idx}:")
    display(L2M_ochiai.loc[L2M_ochiai.meth == top_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_ochiai.loc[spectra_max_ochiai.meth == top_meth].reset_index(
            drop=True
        )
    )
# Out:
# [Op2]
# Faulty method:
#                                                                                          meth  \
# 0  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
#
#        vote  rank
# 0  6.668186  10.0
# Voters:
#      line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0    368   2    1    81   0    0.976190  0.577350  312.0    312.0
# 1    349   2    1    81   0    0.976190  0.577350  312.0    312.0
# 2    428   3    1    80   0    0.964286  0.500000  411.0    411.0
# 3    378   3    1    80   0    0.964286  0.500000  411.0    411.0
# 4    416   4    1    79   0    0.952381  0.447214  478.0    478.0
# ..   ...  ..   ..    ..  ..         ...       ...    ...      ...
# 137  406   8    0    75   1   -0.095238  0.000000  32505.0  39698.0
# 138  405   8    0    75   1   -0.095238  0.000000  32505.0  39698.0
# 139  357   9    0    74   1   -0.107143  0.000000  32931.0  39698.0
# 140  386   10   0    73   1   -0.119048  0.000000  33414.0  39698.0
# 141  298   17   0    66   1   -0.202381  0.000000  35775.0  39698.0
#
#                                         file  \
# 0    /home/workspace/lib/forwardanalyzer.cpp
# 1    /home/workspace/lib/forwardanalyzer.cpp
# 2    /home/workspace/lib/forwardanalyzer.cpp
# 3    /home/workspace/lib/forwardanalyzer.cpp
# 4    /home/workspace/lib/forwardanalyzer.cpp
# ..                                       ...
# 137  /home/workspace/lib/forwardanalyzer.cpp
# 138  /home/workspace/lib/forwardanalyzer.cpp
# 139  /home/workspace/lib/forwardanalyzer.cpp
# 140  /home/workspace/lib/forwardanalyzer.cpp
# 141  /home/workspace/lib/forwardanalyzer.cpp
#
#                                                 func  \
# 0    _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_
# 1    _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_
# 2    _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_
# 3    _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_
# 4    _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_
# ..                                               ...
# 137  _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_
# 138  _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_
# 139  _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_
# 140  _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_
# 141  _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_
#
#                                                                                            meth  \
# 0    (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# 1    (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# 2    (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# 3    (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# 4    (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# ..                                                                                          ...
# 137  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# 138  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# 139  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# 140  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# 141  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
#
#      Rop2D      vote
# 0    3.0    0.325397
# 1    3.0    0.325397
# 2    4.0    0.241071
# 3    4.0    0.241071
# 4    5.0    0.190476
# ..   ...         ...
# 137  82.0  -0.001161
# 138  82.0  -0.001161
# 139  83.0  -0.001291
# 140  84.0  -0.001417
# 141  91.0  -0.002224
#
# [142 rows x 14 columns]
# Faulty method:
#                                                                                                                                 meth  \
# 0  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
#
#        vote   rank
# 0  0.952192  120.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0   48    4    1    79   0    0.952381  0.447214  478.0    478.0
# 1   43    5    1    78   0    0.940476  0.408248  577.0    577.0
# 2   47    7    1    76   0    0.916667  0.353553  835.0    835.0
# 3   41    7    1    76   0    0.916667  0.353553  835.0    835.0
# 4   30    13   1    70   0    0.845238  0.267261  1517.0   1517.0
# 5   37    15   1    68   0    0.821429  0.250000  1792.0   1792.0
# 6   44    18   1    65   0    0.785714  0.229416  2262.0   2262.0
# 7   42    18   1    65   0    0.785714  0.229416  2262.0   2262.0
# 8   40    18   1    65   0    0.785714  0.229416  2262.0   2262.0
# 9   38    21   1    62   0    0.750000  0.213201  2692.0   2692.0
# 10  36    21   1    62   0    0.750000  0.213201  2692.0   2692.0
# 11  34    44   1    39   0    0.476190  0.149071  6618.0   6618.0
# 12  33    44   1    39   0    0.476190  0.149071  6618.0   6618.0
# 13  32    44   1    39   0    0.476190  0.149071  6618.0   6618.0
# 14  57    51   1    32   0    0.392857  0.138675  7581.0   7581.0
# 15  59    62   1    21   0    0.261905  0.125988  8650.0   8650.0
# 16  56    63   1    20   0    0.250000  0.125000  8916.0   8916.0
# 17  52    63   1    20   0    0.250000  0.125000  8916.0   8916.0
# 18  46    63   1    20   0    0.250000  0.125000  8916.0   8916.0
# 19  39    63   1    20   0    0.250000  0.125000  8916.0   8916.0
# 20  35    63   1    20   0    0.250000  0.125000  8916.0   8916.0
# 21  31    63   1    20   0    0.250000  0.125000  8916.0   8916.0
# 22  29    63   1    20   0    0.250000  0.125000  8916.0   8916.0
# 23  28    63   1    20   0    0.250000  0.125000  8916.0   8916.0
# 24  54    4    0    79   1   -0.047619  0.000000  29949.0  39698.0
# 25  53    4    0    79   1   -0.047619  0.000000  29949.0  39698.0
# 26  50    4    0    79   1   -0.047619  0.000000  29949.0  39698.0
# 27  49    7    0    76   1   -0.083333  0.000000  32023.0  39698.0
#
#                                        file  \
# 0   /home/workspace/lib/forwardanalyzer.cpp
# 1   /home/workspace/lib/forwardanalyzer.cpp
# 2   /home/workspace/lib/forwardanalyzer.cpp
# 3   /home/workspace/lib/forwardanalyzer.cpp
# 4   /home/workspace/lib/forwardanalyzer.cpp
# 5   /home/workspace/lib/forwardanalyzer.cpp
# 6   /home/workspace/lib/forwardanalyzer.cpp
# 7   /home/workspace/lib/forwardanalyzer.cpp
# 8   /home/workspace/lib/forwardanalyzer.cpp
# 9   /home/workspace/lib/forwardanalyzer.cpp
# 10  /home/workspace/lib/forwardanalyzer.cpp
# 11  /home/workspace/lib/forwardanalyzer.cpp
# 12  /home/workspace/lib/forwardanalyzer.cpp
# 13  /home/workspace/lib/forwardanalyzer.cpp
# 14  /home/workspace/lib/forwardanalyzer.cpp
# 15  /home/workspace/lib/forwardanalyzer.cpp
# 16  /home/workspace/lib/forwardanalyzer.cpp
# 17  /home/workspace/lib/forwardanalyzer.cpp
# 18  /home/workspace/lib/forwardanalyzer.cpp
# 19  /home/workspace/lib/forwardanalyzer.cpp
# 20  /home/workspace/lib/forwardanalyzer.cpp
# 21  /home/workspace/lib/forwardanalyzer.cpp
# 22  /home/workspace/lib/forwardanalyzer.cpp
# 23  /home/workspace/lib/forwardanalyzer.cpp
# 24  /home/workspace/lib/forwardanalyzer.cpp
# 25  /home/workspace/lib/forwardanalyzer.cpp
# 26  /home/workspace/lib/forwardanalyzer.cpp
# 27  /home/workspace/lib/forwardanalyzer.cpp
#
#                                                                                       func  \
# 0   _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 1   _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 2   _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 3   _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 4   _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 5   _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 6   _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 7   _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 8   _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 9   _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 10  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 11  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 12  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 13  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 14  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 15  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 16  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 17  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 18  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 19  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 20  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 21  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 22  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 23  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 24  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 25  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 26  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
# 27  _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_
#
#                                                                                                                                  meth  \
# 0   (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 1   (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 2   (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 3   (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 4   (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 5   (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 6   (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 7   (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 8   (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 9   (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 10  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 11  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 12  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 13  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 14  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 15  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 16  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 17  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 18  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 19  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 20  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 21  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 22  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 23  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 24  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 25  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 26  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
# 27  (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11traverseTokI5TokenvEENS_8ProgressEPT_St8functionIFS2_S4_EEbPS4_)
#
#     Rop2D      vote
# 0   5.0    0.190476
# 1   6.0    0.156746
# 2   8.0    0.114583
# 3   8.0    0.114583
# 4   14.0   0.060374
# 5   16.0   0.051339
# 6   19.0   0.041353
# 7   19.0   0.041353
# 8   19.0   0.041353
# 9   22.0   0.034091
# 10  22.0   0.034091
# 11  45.0   0.010582
# 12  45.0   0.010582
# 13  45.0   0.010582
# 14  52.0   0.007555
# 15  63.0   0.004157
# 16  64.0   0.003906
# 17  64.0   0.003906
# 18  64.0   0.003906
# 19  64.0   0.003906
# 20  64.0   0.003906
# 21  64.0   0.003906
# 22  64.0   0.003906
# 23  64.0   0.003906
# 24  78.0  -0.000611
# 25  78.0  -0.000611
# 26  78.0  -0.000611
# 27  81.0  -0.001029
# Top 5 methods:
#                                                                                                                               meth  \
# 0  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
# 1  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 2  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 3  (/home/workspace/lib/valueflow.cpp, _ZL16valueFlowReverseP9TokenListP5TokenPKS1_N9ValueFlow5ValueES6_P11ErrorLoggerPK8Settings)
# 4  (/home/workspace/lib/ctu.cpp, _ZN3CTU11getFileInfoEPK9Tokenizer)
#
#         vote  rank
# 0  20.093729  1.0
# 1  16.891251  2.0
# 2  14.756086  3.0
# 3  11.530928  4.0
# 4  11.042170  5.0
# Top 1:
#                                                                                                       meth  \
# 0  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
#
#         vote  rank
# 0  20.093729  1.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0   253   0    1    83   0    1.000000  1.000000  73.0     73.0
# 1   240   0    1    83   0    1.000000  1.000000  73.0     73.0
# 2   239   0    1    83   0    1.000000  1.000000  73.0     73.0
# 3   238   0    1    83   0    1.000000  1.000000  73.0     73.0
# 4   237   0    1    83   0    1.000000  1.000000  73.0     73.0
# ..  ...  ..   ..    ..  ..         ...       ...   ...      ...
# 63  145   23   1    60   0    0.726190  0.204124  3087.0   3087.0
# 64  214   1    0    82   1   -0.011905  0.000000  21853.0  39698.0
# 65  199   1    0    82   1   -0.011905  0.000000  21853.0  39698.0
# 66  154   1    0    82   1   -0.011905  0.000000  21853.0  39698.0
# 67  173   2    0    81   1   -0.023810  0.000000  27013.0  39698.0
#
#                                         file  \
# 0   /home/workspace/lib/checknullpointer.cpp
# 1   /home/workspace/lib/checknullpointer.cpp
# 2   /home/workspace/lib/checknullpointer.cpp
# 3   /home/workspace/lib/checknullpointer.cpp
# 4   /home/workspace/lib/checknullpointer.cpp
# ..                                       ...
# 63  /home/workspace/lib/checknullpointer.cpp
# 64  /home/workspace/lib/checknullpointer.cpp
# 65  /home/workspace/lib/checknullpointer.cpp
# 66  /home/workspace/lib/checknullpointer.cpp
# 67  /home/workspace/lib/checknullpointer.cpp
#
#                                                            func  \
# 0   _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings
# 1   _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings
# 2   _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings
# 3   _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings
# 4   _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings
# ..                                                          ...
# 63  _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings
# 64  _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings
# 65  _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings
# 66  _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings
# 67  _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings
#
#                                                                                                        meth  \
# 0   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
# 1   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
# 2   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
# 3   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
# 4   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
# ..                                                                                                      ...
# 63  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
# 64  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
# 65  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
# 66  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
# 67  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer14isPointerDeRefEPK5TokenRbPK8Settings)
#
#     Rop2D      vote
# 0   1.0    1.000000
# 1   1.0    1.000000
# 2   1.0    1.000000
# 3   1.0    1.000000
# 4   1.0    1.000000
# ..  ...         ...
# 63  24.0   0.030258
# 64  75.0  -0.000159
# 65  75.0  -0.000159
# 66  75.0  -0.000159
# 67  76.0  -0.000313
#
# [68 rows x 14 columns]
# Top 2:
#                                                                                                   meth  \
# 0  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
#
#         vote  rank
# 0  16.891251  2.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai  \
# 0   5652  0    1    83   0    1.000000  1.000000  73.0    73.0
# 1   5651  0    1    83   0    1.000000  1.000000  73.0    73.0
# 2   5650  0    1    83   0    1.000000  1.000000  73.0    73.0
# 3   5649  0    1    83   0    1.000000  1.000000  73.0    73.0
# 4   5648  0    1    83   0    1.000000  1.000000  73.0    73.0
# 5   5647  0    1    83   0    1.000000  1.000000  73.0    73.0
# 6   5646  0    1    83   0    1.000000  1.000000  73.0    73.0
# 7   5659  1    1    82   0    0.988095  0.707107  202.0   202.0
# 8   5658  1    1    82   0    0.988095  0.707107  202.0   202.0
# 9   5657  1    1    82   0    0.988095  0.707107  202.0   202.0
# 10  5656  1    1    82   0    0.988095  0.707107  202.0   202.0
# 11  5655  1    1    82   0    0.988095  0.707107  202.0   202.0
# 12  5636  1    1    82   0    0.988095  0.707107  202.0   202.0
# 13  5635  1    1    82   0    0.988095  0.707107  202.0   202.0
# 14  5634  1    1    82   0    0.988095  0.707107  202.0   202.0
# 15  5633  1    1    82   0    0.988095  0.707107  202.0   202.0
# 16  5632  1    1    82   0    0.988095  0.707107  202.0   202.0
# 17  5629  1    1    82   0    0.988095  0.707107  202.0   202.0
# 18  5628  1    1    82   0    0.988095  0.707107  202.0   202.0
# 19  5627  1    1    82   0    0.988095  0.707107  202.0   202.0
# 20  5626  1    1    82   0    0.988095  0.707107  202.0   202.0
# 21  5644  2    1    81   0    0.976190  0.577350  312.0   312.0
# 22  5643  2    1    81   0    0.976190  0.577350  312.0   312.0
# 23  5642  2    1    81   0    0.976190  0.577350  312.0   312.0
# 24  5641  2    1    81   0    0.976190  0.577350  312.0   312.0
# 25  5640  2    1    81   0    0.976190  0.577350  312.0   312.0
# 26  5639  2    1    81   0    0.976190  0.577350  312.0   312.0
# 27  5631  3    1    80   0    0.964286  0.500000  411.0   411.0
# 28  5625  3    1    80   0    0.964286  0.500000  411.0   411.0
# 29  5654  5    1    78   0    0.940476  0.408248  577.0   577.0
# 30  5638  5    1    78   0    0.940476  0.408248  577.0   577.0
# 31  5624  5    1    78   0    0.940476  0.408248  577.0   577.0
# 32  5623  53   1    30   0    0.369048  0.136083  7737.0  7737.0
# 33  5622  53   1    30   0    0.369048  0.136083  7737.0  7737.0
# 34  5621  53   1    30   0    0.369048  0.136083  7737.0  7737.0
# 35  5662  55   1    28   0    0.345238  0.133631  8123.0  8123.0
# 36  5620  55   1    28   0    0.345238  0.133631  8123.0  8123.0
# 37  5619  55   1    28   0    0.345238  0.133631  8123.0  8123.0
# 38  5618  55   1    28   0    0.345238  0.133631  8123.0  8123.0
# 39  5617  55   1    28   0    0.345238  0.133631  8123.0  8123.0
# 40  5615  55   1    28   0    0.345238  0.133631  8123.0  8123.0
# 41  5614  55   1    28   0    0.345238  0.133631  8123.0  8123.0
# 42  5612  55   1    28   0    0.345238  0.133631  8123.0  8123.0
#
#                                  file  \
# 0   /home/workspace/lib/valueflow.cpp
# 1   /home/workspace/lib/valueflow.cpp
# 2   /home/workspace/lib/valueflow.cpp
# 3   /home/workspace/lib/valueflow.cpp
# 4   /home/workspace/lib/valueflow.cpp
# 5   /home/workspace/lib/valueflow.cpp
# 6   /home/workspace/lib/valueflow.cpp
# 7   /home/workspace/lib/valueflow.cpp
# 8   /home/workspace/lib/valueflow.cpp
# 9   /home/workspace/lib/valueflow.cpp
# 10  /home/workspace/lib/valueflow.cpp
# 11  /home/workspace/lib/valueflow.cpp
# 12  /home/workspace/lib/valueflow.cpp
# 13  /home/workspace/lib/valueflow.cpp
# 14  /home/workspace/lib/valueflow.cpp
# 15  /home/workspace/lib/valueflow.cpp
# 16  /home/workspace/lib/valueflow.cpp
# 17  /home/workspace/lib/valueflow.cpp
# 18  /home/workspace/lib/valueflow.cpp
# 19  /home/workspace/lib/valueflow.cpp
# 20  /home/workspace/lib/valueflow.cpp
# 21  /home/workspace/lib/valueflow.cpp
# 22  /home/workspace/lib/valueflow.cpp
# 23  /home/workspace/lib/valueflow.cpp
# 24  /home/workspace/lib/valueflow.cpp
# 25  /home/workspace/lib/valueflow.cpp
# 26  /home/workspace/lib/valueflow.cpp
# 27  /home/workspace/lib/valueflow.cpp
# 28  /home/workspace/lib/valueflow.cpp
# 29  /home/workspace/lib/valueflow.cpp
# 30  /home/workspace/lib/valueflow.cpp
# 31  /home/workspace/lib/valueflow.cpp
# 32  /home/workspace/lib/valueflow.cpp
# 33  /home/workspace/lib/valueflow.cpp
# 34  /home/workspace/lib/valueflow.cpp
# 35  /home/workspace/lib/valueflow.cpp
# 36  /home/workspace/lib/valueflow.cpp
# 37  /home/workspace/lib/valueflow.cpp
# 38  /home/workspace/lib/valueflow.cpp
# 39  /home/workspace/lib/valueflow.cpp
# 40  /home/workspace/lib/valueflow.cpp
# 41  /home/workspace/lib/valueflow.cpp
# 42  /home/workspace/lib/valueflow.cpp
#
#                                                               func  \
# 0   _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 1   _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 2   _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 3   _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 4   _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 5   _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 6   _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 7   _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 8   _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 9   _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 10  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 11  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 12  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 13  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 14  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 15  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 16  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 17  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 18  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 19  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 20  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 21  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 22  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 23  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 24  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 25  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 26  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 27  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 28  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 29  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 30  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 31  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 32  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 33  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 34  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 35  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 36  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 37  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 38  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 39  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 40  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 41  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
# 42  _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings
#
#                                                                                                    meth  \
# 0   (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 1   (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 2   (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 3   (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 4   (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 5   (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 6   (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 7   (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 8   (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 9   (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 10  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 11  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 12  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 13  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 14  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 15  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 16  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 17  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 18  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 19  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 20  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 21  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 22  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 23  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 24  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 25  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 26  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 27  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 28  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 29  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 30  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 31  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 32  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 33  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 34  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 35  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 36  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 37  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 38  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 39  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 40  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 41  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
# 42  (/home/workspace/lib/valueflow.cpp, _ZL21valueFlowSmartPointerP9TokenListP11ErrorLoggerPK8Settings)
#
#     Rop2D      vote
# 0   1.0    1.000000
# 1   1.0    1.000000
# 2   1.0    1.000000
# 3   1.0    1.000000
# 4   1.0    1.000000
# 5   1.0    1.000000
# 6   1.0    1.000000
# 7   2.0    0.494048
# 8   2.0    0.494048
# 9   2.0    0.494048
# 10  2.0    0.494048
# 11  2.0    0.494048
# 12  2.0    0.494048
# 13  2.0    0.494048
# 14  2.0    0.494048
# 15  2.0    0.494048
# 16  2.0    0.494048
# 17  2.0    0.494048
# 18  2.0    0.494048
# 19  2.0    0.494048
# 20  2.0    0.494048
# 21  3.0    0.325397
# 22  3.0    0.325397
# 23  3.0    0.325397
# 24  3.0    0.325397
# 25  3.0    0.325397
# 26  3.0    0.325397
# 27  4.0    0.241071
# 28  4.0    0.241071
# 29  6.0    0.156746
# 30  6.0    0.156746
# 31  6.0    0.156746
# 32  54.0   0.006834
# 33  54.0   0.006834
# 34  54.0   0.006834
# 35  56.0   0.006165
# 36  56.0   0.006165
# 37  56.0   0.006165
# 38  56.0   0.006165
# 39  56.0   0.006165
# 40  56.0   0.006165
# 41  56.0   0.006165
# 42  56.0   0.006165
# Top 3:
#                                                                                            meth  \
# 0  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
#
#         vote  rank
# 0  14.756086  3.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0   414   0    1    83   0    1.000000  1.000000  73.0     73.0
# 1   391   0    1    83   0    1.000000  1.000000  73.0     73.0
# 2   390   0    1    83   0    1.000000  1.000000  73.0     73.0
# 3   388   0    1    83   0    1.000000  1.000000  73.0     73.0
# 4   387   0    1    83   0    1.000000  1.000000  73.0     73.0
# 5   386   0    1    83   0    1.000000  1.000000  73.0     73.0
# 6   385   0    1    83   0    1.000000  1.000000  73.0     73.0
# 7   369   0    1    83   0    1.000000  1.000000  73.0     73.0
# 8   357   0    1    83   0    1.000000  1.000000  73.0     73.0
# 9   346   0    1    83   0    1.000000  1.000000  73.0     73.0
# 10  345   0    1    83   0    1.000000  1.000000  73.0     73.0
# 11  356   1    1    82   0    0.988095  0.707107  202.0    202.0
# 12  355   1    1    82   0    0.988095  0.707107  202.0    202.0
# 13  406   3    1    80   0    0.964286  0.500000  411.0    411.0
# 14  405   3    1    80   0    0.964286  0.500000  411.0    411.0
# 15  404   3    1    80   0    0.964286  0.500000  411.0    411.0
# 16  338   4    1    79   0    0.952381  0.447214  478.0    478.0
# 17  379   5    1    78   0    0.940476  0.408248  577.0    577.0
# 18  377   8    1    75   0    0.904762  0.333333  903.0    903.0
# 19  376   8    1    75   0    0.904762  0.333333  903.0    903.0
# 20  375   8    1    75   0    0.904762  0.333333  903.0    903.0
# 21  374   8    1    75   0    0.904762  0.333333  903.0    903.0
# 22  373   8    1    75   0    0.904762  0.333333  903.0    903.0
# 23  372   8    1    75   0    0.904762  0.333333  903.0    903.0
# 24  342   9    1    74   0    0.892857  0.316228  1024.0   1024.0
# 25  365   12   1    71   0    0.857143  0.277350  1402.0   1402.0
# 26  364   14   1    69   0    0.833333  0.258199  1713.0   1713.0
# 27  411   18   1    65   0    0.785714  0.229416  2262.0   2262.0
# 28  410   18   1    65   0    0.785714  0.229416  2262.0   2262.0
# 29  417   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 30  413   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 31  409   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 32  408   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 33  403   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 34  402   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 35  401   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 36  384   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 37  371   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 38  368   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 39  363   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 40  360   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 41  359   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 42  354   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 43  353   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 44  350   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 45  344   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 46  341   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 47  340   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 48  337   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 49  335   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 50  332   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 51  331   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 52  329   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 53  327   22   1    61   0    0.738095  0.208514  2866.0   2866.0
# 54  380   2    0    81   1   -0.023810  0.000000  27013.0  39698.0
# 55  333   2    0    81   1   -0.023810  0.000000  27013.0  39698.0
# 56  378   5    0    78   1   -0.059524  0.000000  30834.0  39698.0
#
#                                         file  \
# 0   /home/workspace/lib/checknullpointer.cpp
# 1   /home/workspace/lib/checknullpointer.cpp
# 2   /home/workspace/lib/checknullpointer.cpp
# 3   /home/workspace/lib/checknullpointer.cpp
# 4   /home/workspace/lib/checknullpointer.cpp
# 5   /home/workspace/lib/checknullpointer.cpp
# 6   /home/workspace/lib/checknullpointer.cpp
# 7   /home/workspace/lib/checknullpointer.cpp
# 8   /home/workspace/lib/checknullpointer.cpp
# 9   /home/workspace/lib/checknullpointer.cpp
# 10  /home/workspace/lib/checknullpointer.cpp
# 11  /home/workspace/lib/checknullpointer.cpp
# 12  /home/workspace/lib/checknullpointer.cpp
# 13  /home/workspace/lib/checknullpointer.cpp
# 14  /home/workspace/lib/checknullpointer.cpp
# 15  /home/workspace/lib/checknullpointer.cpp
# 16  /home/workspace/lib/checknullpointer.cpp
# 17  /home/workspace/lib/checknullpointer.cpp
# 18  /home/workspace/lib/checknullpointer.cpp
# 19  /home/workspace/lib/checknullpointer.cpp
# 20  /home/workspace/lib/checknullpointer.cpp
# 21  /home/workspace/lib/checknullpointer.cpp
# 22  /home/workspace/lib/checknullpointer.cpp
# 23  /home/workspace/lib/checknullpointer.cpp
# 24  /home/workspace/lib/checknullpointer.cpp
# 25  /home/workspace/lib/checknullpointer.cpp
# 26  /home/workspace/lib/checknullpointer.cpp
# 27  /home/workspace/lib/checknullpointer.cpp
# 28  /home/workspace/lib/checknullpointer.cpp
# 29  /home/workspace/lib/checknullpointer.cpp
# 30  /home/workspace/lib/checknullpointer.cpp
# 31  /home/workspace/lib/checknullpointer.cpp
# 32  /home/workspace/lib/checknullpointer.cpp
# 33  /home/workspace/lib/checknullpointer.cpp
# 34  /home/workspace/lib/checknullpointer.cpp
# 35  /home/workspace/lib/checknullpointer.cpp
# 36  /home/workspace/lib/checknullpointer.cpp
# 37  /home/workspace/lib/checknullpointer.cpp
# 38  /home/workspace/lib/checknullpointer.cpp
# 39  /home/workspace/lib/checknullpointer.cpp
# 40  /home/workspace/lib/checknullpointer.cpp
# 41  /home/workspace/lib/checknullpointer.cpp
# 42  /home/workspace/lib/checknullpointer.cpp
# 43  /home/workspace/lib/checknullpointer.cpp
# 44  /home/workspace/lib/checknullpointer.cpp
# 45  /home/workspace/lib/checknullpointer.cpp
# 46  /home/workspace/lib/checknullpointer.cpp
# 47  /home/workspace/lib/checknullpointer.cpp
# 48  /home/workspace/lib/checknullpointer.cpp
# 49  /home/workspace/lib/checknullpointer.cpp
# 50  /home/workspace/lib/checknullpointer.cpp
# 51  /home/workspace/lib/checknullpointer.cpp
# 52  /home/workspace/lib/checknullpointer.cpp
# 53  /home/workspace/lib/checknullpointer.cpp
# 54  /home/workspace/lib/checknullpointer.cpp
# 55  /home/workspace/lib/checknullpointer.cpp
# 56  /home/workspace/lib/checknullpointer.cpp
#
#                                                 func  \
# 0   _ZN16CheckNullPointer23nullConstantDereferenceEv
# 1   _ZN16CheckNullPointer23nullConstantDereferenceEv
# 2   _ZN16CheckNullPointer23nullConstantDereferenceEv
# 3   _ZN16CheckNullPointer23nullConstantDereferenceEv
# 4   _ZN16CheckNullPointer23nullConstantDereferenceEv
# 5   _ZN16CheckNullPointer23nullConstantDereferenceEv
# 6   _ZN16CheckNullPointer23nullConstantDereferenceEv
# 7   _ZN16CheckNullPointer23nullConstantDereferenceEv
# 8   _ZN16CheckNullPointer23nullConstantDereferenceEv
# 9   _ZN16CheckNullPointer23nullConstantDereferenceEv
# 10  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 11  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 12  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 13  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 14  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 15  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 16  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 17  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 18  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 19  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 20  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 21  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 22  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 23  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 24  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 25  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 26  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 27  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 28  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 29  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 30  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 31  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 32  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 33  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 34  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 35  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 36  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 37  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 38  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 39  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 40  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 41  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 42  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 43  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 44  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 45  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 46  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 47  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 48  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 49  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 50  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 51  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 52  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 53  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 54  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 55  _ZN16CheckNullPointer23nullConstantDereferenceEv
# 56  _ZN16CheckNullPointer23nullConstantDereferenceEv
#
#                                                                                             meth  \
# 0   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 1   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 2   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 3   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 4   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 5   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 6   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 7   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 8   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 9   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 10  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 11  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 12  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 13  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 14  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 15  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 16  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 17  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 18  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 19  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 20  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 21  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 22  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 23  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 24  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 25  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 26  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 27  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 28  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 29  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 30  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 31  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 32  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 33  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 34  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 35  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# 36  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer23nullConstantDereferenceEv)
# ...
# 28  89    17   1    66   0    0.797619  0.235702  2126.0   2126.0
# 29  88    17   1    66   0    0.797619  0.235702  2126.0   2126.0
# 30  87    17   1    66   0    0.797619  0.235702  2126.0   2126.0
# 31  85    17   1    66   0    0.797619  0.235702  2126.0   2126.0
# 32  82    17   1    66   0    0.797619  0.235702  2126.0   2126.0
# 33  78    17   1    66   0    0.797619  0.235702  2126.0   2126.0
# 34  77    17   1    66   0    0.797619  0.235702  2126.0   2126.0
# 35  76    23   1    60   0    0.726190  0.204124  3087.0   3087.0
# 36  68    23   1    60   0    0.726190  0.204124  3087.0   3087.0
# 37  66    23   1    60   0    0.726190  0.204124  3087.0   3087.0
# 38  65    23   1    60   0    0.726190  0.204124  3087.0   3087.0
# 39  64    23   1    60   0    0.726190  0.204124  3087.0   3087.0
# 40  63    23   1    60   0    0.726190  0.204124  3087.0   3087.0
# 41  61    23   1    60   0    0.726190  0.204124  3087.0   3087.0
# 42  58    23   1    60   0    0.726190  0.204124  3087.0   3087.0
# 43  56    23   1    60   0    0.726190  0.204124  3087.0   3087.0
# 44  128   83   1    0    0    0.011905  0.109109  12642.0  12642.0
# 45  124   83   1    0    0    0.011905  0.109109  12642.0  12642.0
#
#                                         file  \
# 0   /home/workspace/lib/checknullpointer.cpp
# 1   /home/workspace/lib/checknullpointer.cpp
# 2   /home/workspace/lib/checknullpointer.cpp
# 3   /home/workspace/lib/checknullpointer.cpp
# 4   /home/workspace/lib/checknullpointer.cpp
# 5   /home/workspace/lib/checknullpointer.cpp
# 6   /home/workspace/lib/checknullpointer.cpp
# 7   /home/workspace/lib/checknullpointer.cpp
# 8   /home/workspace/lib/checknullpointer.cpp
# 9   /home/workspace/lib/checknullpointer.cpp
# 10  /home/workspace/lib/checknullpointer.cpp
# 11  /home/workspace/lib/checknullpointer.cpp
# 12  /home/workspace/lib/checknullpointer.cpp
# 13  /home/workspace/lib/checknullpointer.cpp
# 14  /home/workspace/lib/checknullpointer.cpp
# 15  /home/workspace/lib/checknullpointer.cpp
# 16  /home/workspace/lib/checknullpointer.cpp
# 17  /home/workspace/lib/checknullpointer.cpp
# 18  /home/workspace/lib/checknullpointer.cpp
# 19  /home/workspace/lib/checknullpointer.cpp
# 20  /home/workspace/lib/checknullpointer.cpp
# 21  /home/workspace/lib/checknullpointer.cpp
# 22  /home/workspace/lib/checknullpointer.cpp
# 23  /home/workspace/lib/checknullpointer.cpp
# 24  /home/workspace/lib/checknullpointer.cpp
# 25  /home/workspace/lib/checknullpointer.cpp
# 26  /home/workspace/lib/checknullpointer.cpp
# 27  /home/workspace/lib/checknullpointer.cpp
# 28  /home/workspace/lib/checknullpointer.cpp
# 29  /home/workspace/lib/checknullpointer.cpp
# 30  /home/workspace/lib/checknullpointer.cpp
# 31  /home/workspace/lib/checknullpointer.cpp
# 32  /home/workspace/lib/checknullpointer.cpp
# 33  /home/workspace/lib/checknullpointer.cpp
# 34  /home/workspace/lib/checknullpointer.cpp
# 35  /home/workspace/lib/checknullpointer.cpp
# 36  /home/workspace/lib/checknullpointer.cpp
# 37  /home/workspace/lib/checknullpointer.cpp
# 38  /home/workspace/lib/checknullpointer.cpp
# 39  /home/workspace/lib/checknullpointer.cpp
# 40  /home/workspace/lib/checknullpointer.cpp
# 41  /home/workspace/lib/checknullpointer.cpp
# 42  /home/workspace/lib/checknullpointer.cpp
# 43  /home/workspace/lib/checknullpointer.cpp
# 44  /home/workspace/lib/checknullpointer.cpp
# 45  /home/workspace/lib/checknullpointer.cpp
#
#                                                                                           func  \
# 0   _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 1   _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 2   _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 3   _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 4   _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 5   _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 6   _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 7   _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 8   _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 9   _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 10  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 11  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 12  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 13  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 14  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 15  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 16  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 17  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 18  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 19  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 20  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 21  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 22  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 23  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 24  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 25  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 26  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 27  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 28  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 29  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 30  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 31  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 32  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 33  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 34  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 35  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 36  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 37  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 38  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 39  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 40  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 41  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 42  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 43  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 44  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
# 45  _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library
#
#                                                                                                                                       meth  \
# 0   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 1   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 2   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 3   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 4   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 5   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 6   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 7   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 8   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 9   (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 10  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 11  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 12  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 13  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 14  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 15  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 16  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 17  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 18  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 19  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 20  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 21  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 22  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 23  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 24  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 25  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 26  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 27  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 28  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 29  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 30  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 31  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 32  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 33  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 34  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 35  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 36  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 37  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 38  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 39  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 40  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 41  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 42  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 43  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 44  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
# 45  (/home/workspace/lib/checknullpointer.cpp, _ZN16CheckNullPointer17parseFunctionCallERK5TokenRNSt7__debug4listIPS1_SaIS5_EEEPK7Library)
#
#     RochiaiD      vote
# 0   1.0       1.000000
# 1   1.0       1.000000
# 2   1.0       1.000000
# 3   1.0       1.000000
# 4   1.0       1.000000
# 5   1.0       1.000000
# 6   1.0       1.000000
# 7   1.0       1.000000
# 8   4.0       0.125000
# 9   6.0       0.068041
# 10  6.0       0.068041
# 11  7.0       0.053995
# 12  7.0       0.053995
# 13  10.0      0.031623
# 14  15.0      0.017213
# 15  17.0      0.014267
# 16  17.0      0.014267
# 17  17.0      0.014267
# 18  17.0      0.014267
# 19  17.0      0.014267
# 20  17.0      0.014267
# 21  17.0      0.014267
# 22  17.0      0.014267
# 23  17.0      0.014267
# 24  18.0      0.013095
# 25  18.0      0.013095
# 26  18.0      0.013095
# 27  18.0      0.013095
# 28  18.0      0.013095
# 29  18.0      0.013095
# 30  18.0      0.013095
# 31  18.0      0.013095
# 32  18.0      0.013095
# 33  18.0      0.013095
# 34  18.0      0.013095
# 35  24.0      0.008505
# 36  24.0      0.008505
# 37  24.0      0.008505
# 38  24.0      0.008505
# 39  24.0      0.008505
# 40  24.0      0.008505
# 41  24.0      0.008505
# 42  24.0      0.008505
# 43  24.0      0.008505
# 44  74.0      0.001474
# 45  74.0      0.001474

# %% [markdown]
# # 감상
#
# rank 10도 있는 것 같은데?
