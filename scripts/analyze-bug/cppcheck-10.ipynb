# %%
import os
import pandas as pd
import numpy as np
pd.set_option("display.max_colwidth", 2)

os.chdir("/home/coinse/Workspace/SBFL")

# %% [markdown]
# # Load bug info

# %%
from scripts.util import load_bug_data, find_covmat_func, find_covmat_idx
from functools import reduce
from typing import Set

pid, vid = "cppcheck", 10

bug = load_bug_data(pid, vid)

print(f"{bug.buggy_files=}")
print(f"{bug.buggy_lines=}")
print("bug.coverage_df=")
display(bug.coverage_df)
print(f"{bug.failing_tests=}")
print(f"{bug.failing_tests_GT=}")
print("bug.functions={", end="")
for func in list(bug.functions)[:5]:
    print(f"{func},", end=" ")
print(", ...}")
print(f"{bug.id=}")
print(f"{bug.num_test_cases=}")
print(f"{bug.passing_tests=}")
print(f"{bug.path_to_cov_df=}")
print(f"{bug.path_to_patch=}")
print(f"{bug.path_to_test_results=}")
print("bug.source_files=", end="")
for src in list(bug.source_files)[:5]:
    print(f"{src},", end=" ")
print(", ...}")

fault_idxs = sorted(bug.buggy_lines)
# fault_idx2meth = {}
fault_meth2idx = {}
err_msg = ""
for fault_idx in fault_idxs:
    succ_func, ret_func = find_covmat_func(
        pid, bug.coverage_df, fault_idx, debug=False
    )
    if succ_func:
        succ_idx, ret_idx = find_covmat_idx(
            pid, bug.coverage_df, fault_idx, debug=False
        )
        if succ_idx:
            if ret_func in fault_meth2idx:
                fault_meth2idx[ret_func].add(ret_idx)
            else:
                fault_meth2idx[ret_func] = {ret_idx}
        else:
            print(f"{ret_idx}")
            if ret_func not in fault_meth2idx:
                fault_meth2idx[ret_func] = set()
    else:
        print(f"{ret_func}")
# fault_meths: Set = reduce(
#     lambda x, y: x | set([y]), fault_idx2meth.values(), set()
# )
# fault_meth2idx = {
#     v: {idx for idx in fault_idx2meth if fault_idx2meth[idx] == v}
#     for v in fault_meths
# }
fault_meths = set(fault_meth2idx.keys())
for meth in fault_meth2idx:
    print(f"{meth=}: {fault_meth2idx[meth]}")
# print(f"{fault_meths=}")
# Out:
# bug.buggy_files={'lib/symboldatabase.cpp'}
# bug.buggy_lines={('lib/symboldatabase.cpp', 1957), ('lib/symboldatabase.cpp', 1958)}
# bug.coverage_df=
#                                                                                                                    26  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   9
#                                                                                                              162   9
#                                                                                                              163   9
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    18  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    80  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    2
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    1
#                                                                                                              53    1
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    1
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    2
#                                                                                                              99    2
#
#                                                                                                                    84  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    2
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    1
#                                                                                                              53    1
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    1
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    36  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    57  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   10
#                                                                                                              162   10
#                                                                                                              163   10
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    83  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    2
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    1
#                                                                                                              53    1
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    1
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    67  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    9
#                                                                                                              99    9
#
#                                                                                                                    34  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    23  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    ...  \
# file                                     function                                                            line  ...
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    ...
#                                          _ZN14CheckUnusedVarC2Ev                                             49    ...
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    ...
#                                                                                                              53    ...
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    ...
# ...                                                                                                                ...
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   ...
#                                                                                                              162   ...
#                                                                                                              163   ...
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    ...
#                                                                                                              99    ...
#
#                                                                                                                    52  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   58
#                                                                                                              162   58
#                                                                                                              163   58
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    2
#                                                                                                              99    2
#
#                                                                                                                     62  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   3
#                                                                                                              162   3
#                                                                                                              163   3
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    284
#                                                                                                              99    284
#
#                                                                                                                    2  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    11  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    73  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    2
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    1
#                                                                                                              53    1
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    1
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    77  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    2
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    1
#                                                                                                              53    1
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    1
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    24
#                                                                                                              99    24
#
#                                                                                                                    10  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    43  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    12  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   28
#                                                                                                              162   28
#                                                                                                              163   28
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    2
#                                                                                                              99    2
#
#                                                                                                                    21
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    2
#                                                                                                              99    2
#
# [43652 rows x 92 columns]
# bug.failing_tests={'15'}
# bug.failing_tests_GT={'15'}
# bug.functions={('/usr/include/c++/7/bits/stl_deque.h', '_ZNSt9__cxx19985dequeISt4pairIPKcS3_ESaIS4_EE5beginEv'), ('/home/workspace/lib/symboldatabase.cpp', '_ZNK8Function21getOverriddenFunctionEPb'), ('/home/workspace/lib/checkother.cpp', '_ZN10CheckOther25checkCommaSeparatedReturnEv'), ('/home/workspace/lib/library.h', '_ZN7Library9CodeBlock8setStartEPKc'), ('/home/workspace/lib/token.cpp', '_ZL16removePointValueRNSt7__debug4listIN9ValueFlow5ValueESaIS2_EEERS2_'), , ...}
# bug.id='cppcheck-10'
# bug.num_test_cases=92
# bug.passing_tests={'34', '48', '51', '31', '54', '68', '88', '6', '92', '8', '23', '22', '85', '37', '86', '36', '89', '67', '29', '30', '52', '69', '58', '71', '63', '62', '39', '2', '70', '55', '87', '11', '90', '81', '14', '16', '65', '80', '4', '12', '64', '28', '57', '32', '91', '1', '25', '45', '74', '20', '78', '47', '79', '84', '41', '82', '3', '61', '72', '59', '77', '35', '75', '49', '24', '9', '26', '66', '42', '38', '73', '83', '19', '10', '76', '44', '21', '5', '13', '56', '46', '40', '60', '50', '43', '33', '17', '53', '18', '7', '27'}
# bug.path_to_cov_df='/home/coinse/Workspace/defects4cpp/coverage/cppcheck_10_buggy/coverage_df.pkl'
# bug.path_to_patch='/home/coinse/Workspace/defects4cpp/defects4cpp/taxonomy/cppcheck/patch/0010-buggy.patch'
# bug.path_to_test_results='/home/coinse/Workspace/defects4cpp/coverage/cppcheck_10_buggy/test_results.json'
# bug.source_files=/usr/include/c++/7/debug/stl_iterator.h, /home/workspace/lib/checkmemoryleak.cpp, /home/workspace/lib/checkvaarg.cpp, /usr/include/c++/7/istream, /home/workspace/lib/timer.h, , ...}
# meth=('/home/workspace/lib/symboldatabase.cpp', '_ZNK8Variable12declEndTokenEv'): {('/home/workspace/lib/symboldatabase.cpp', '_ZNK8Variable12declEndTokenEv', 1957), ('/home/workspace/lib/symboldatabase.cpp', '_ZNK8Variable12declEndTokenEv', 1958)}

# %% [markdown]
# # Get spectra

# %%
covmat = bug.coverage_df
pass_tcs = bug.passing_tests
fail_tcs = bug.failing_tests

covmat_bool = covmat.astype(bool)
P = len(pass_tcs)
F = len(fail_tcs)
e_p = covmat_bool[pass_tcs].sum(axis=1)
e_f = covmat_bool[fail_tcs].sum(axis=1)
n_p = P - e_p
n_f = F - e_f
spectra = pd.DataFrame(
    {
        "line": covmat.index.to_list(),
        "e_p": e_p,
        "e_f": e_f,
        "n_p": n_p,
        "n_f": n_f,
    }
)

display(spectra)
# Out:
#                                                                                                                                                                                                                               line  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarD2Ev, 46)
#                                          _ZN14CheckUnusedVarC2Ev                                             49    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2Ev, 49)
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger, 52)
#                                                                                                              53    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger, 53)
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger, 56)
# ...                                                                                                                                                                                                                    ...
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token, 161)
#                                                                                                              162   (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token, 162)
#                                                                                                              163   (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token, 163)
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    (/home/workspace/lib/analyzer.h, _ZNK8Analyzer6Action7matchesEv, 98)
#                                                                                                              99    (/home/workspace/lib/analyzer.h, _ZNK8Analyzer6Action7matchesEv, 99)
#
#                                                                                                                    e_p  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    23
#                                          _ZN14CheckUnusedVarC2Ev                                             49    91
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    23
#                                                                                                              53    23
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    23
# ...                                                                                                                ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   17
#                                                                                                              162   17
#                                                                                                              163   17
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    34
#                                                                                                              99    34
#
#                                                                                                                    e_f  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    0
#                                          _ZN14CheckUnusedVarC2Ev                                             49    1
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    0
#                                                                                                              53    0
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    0
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   1
#                                                                                                              162   1
#                                                                                                              163   1
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    0
#                                                                                                              99    0
#
#                                                                                                                    n_p  \
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    68
#                                          _ZN14CheckUnusedVarC2Ev                                             49    0
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    68
#                                                                                                              53    68
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    68
# ...                                                                                                                ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   74
#                                                                                                              162   74
#                                                                                                              163   74
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    57
#                                                                                                              99    57
#
#                                                                                                                    n_f
# file                                     function                                                            line
# /home/workspace/lib/checkunusedvar.h     _ZN14CheckUnusedVarD2Ev                                             46    1
#                                          _ZN14CheckUnusedVarC2Ev                                             49    0
#                                          _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger         52    1
#                                                                                                              53    1
#                                          _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger 56    1
# ...                                                                                                               ..
# /home/workspace/lib/templatesimplifier.h _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                 161   0
#                                                                                                              162   0
#                                                                                                              163   0
# /home/workspace/lib/analyzer.h           _ZNK8Analyzer6Action7matchesEv                                      98    1
#                                                                                                              99    1
#
# [43652 rows x 5 columns]

# %% [markdown]
# # Compute suspiciousness scores

# %%
def ochiai(e_f, e_p, n_f, n_p):
    return e_f / np.sqrt(e_p + e_f) / np.sqrt(e_f + n_f) if e_f else 0.0


def op2(e_f, e_p, n_f, n_p):
    return e_f - e_p / (e_p + n_p + 1)

spectra["Sop2"] = spectra.apply(
    lambda row: op2(row.e_f, row.e_p, row.n_f, row.n_p), axis=1
)
spectra["Sochiai"] = spectra.apply(
    lambda row: ochiai(row.e_f, row.e_p, row.n_f, row.n_p), axis=1
)
spectra["Rop2"] = spectra.Sop2.rank(ascending=False, method="max")
spectra["Rochiai"] = spectra.Sochiai.rank(ascending=False, method="max")

# %% [markdown]
# # Line level SBFL

# %%
for fault_meth in fault_meth2idx:
    fault_idxs_of_meth = fault_meth2idx[fault_meth]
    print("fault meth:", fault_meth)
    for fault_idx in fault_idxs_of_meth:
        print("fault idx:", tuple(fault_idx))
    print("SBFL score of faulty method:")
    display(spectra.loc[fault_idxs_of_meth].reset_index(drop=True))

print("Top 5 SBFL scores:")
print("Op2:")
display(
    spectra.sort_values("Sop2", ascending=False).head(5).reset_index(drop=True)
)
print("Ochiai:")
display(
    spectra.sort_values("Sochiai", ascending=False)
    .head(5)
    .reset_index(drop=True)
)
# Out:
# fault meth: ('/home/workspace/lib/symboldatabase.cpp', '_ZNK8Variable12declEndTokenEv')
# fault idx: ('/home/workspace/lib/symboldatabase.cpp', '_ZNK8Variable12declEndTokenEv', 1957)
# fault idx: ('/home/workspace/lib/symboldatabase.cpp', '_ZNK8Variable12declEndTokenEv', 1958)
# SBFL score of faulty method:
#                                                                             line  \
# 0  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv, 1957)
# 1  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv, 1958)
#
#    e_p  e_f  n_p  n_f      Sop2  Sochiai    Rop2  Rochiai
# 0  54   1    37   0    0.413043  0.13484  6681.0  6681.0
# 1  54   1    37   0    0.413043  0.13484  6681.0  6681.0
# Top 5 SBFL scores:
# Op2:
#                                                                                                                                                                line  \
# 0  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE, 822)
# 1  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv, 135)
# 2  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE, 667)
# 3  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12assignAllVarERNSt7__debug6vectorINS_5UsageESaIS2_EEE, 618)
# 4  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12assignAllVarERNSt7__debug6vectorINS_5UsageESaIS2_EEE, 617)
#
#    e_p  e_f  n_p  n_f  Sop2  Sochiai   Rop2  Rochiai
# 0  0    1    91   0    1.0   1.0      159.0  159.0
# 1  0    1    91   0    1.0   1.0      159.0  159.0
# 2  0    1    91   0    1.0   1.0      159.0  159.0
# 3  0    1    91   0    1.0   1.0      159.0  159.0
# 4  0    1    91   0    1.0   1.0      159.0  159.0
# Ochiai:
#                                                                                                                                                                line  \
# 0  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope, 548)
# 1  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE, 728)
# 2  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE, 856)
# 3  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE, 852)
# 4  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE, 851)
#
#    e_p  e_f  n_p  n_f  Sop2  Sochiai   Rop2  Rochiai
# 0  0    1    91   0    1.0   1.0      159.0  159.0
# 1  0    1    91   0    1.0   1.0      159.0  159.0
# 2  0    1    91   0    1.0   1.0      159.0  159.0
# 3  0    1    91   0    1.0   1.0      159.0  159.0
# 4  0    1    91   0    1.0   1.0      159.0  159.0

# %% [markdown]
# # Method level SBFL

# %%
spectra["file"] = spectra.index.map(lambda x: x[0])
spectra["func"] = spectra.index.map(lambda x: x[1])
spectra["line"] = spectra.index.map(lambda x: x[2])
# (file, func) is meth
spectra["meth"] = spectra.apply(lambda row: (row.file, row.func), axis=1)
spectra.reset_index(drop=True, inplace=True)
display(spectra)
# Out:
#        line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0      46    23   0    68   1   -0.250000  0.000000  39264.0  43652.0
# 1      49    91   1    0    0    0.010870  0.104257  12055.0  12055.0
# 2      52    23   0    68   1   -0.250000  0.000000  39264.0  43652.0
# 3      53    23   0    68   1   -0.250000  0.000000  39264.0  43652.0
# 4      56    23   0    68   1   -0.250000  0.000000  39264.0  43652.0
# ...    ..    ..  ..    ..  ..         ...       ...      ...      ...
# 43647  161   17   1    74   0    0.815217  0.235702  2009.0   2009.0
# 43648  162   17   1    74   0    0.815217  0.235702  2009.0   2009.0
# 43649  163   17   1    74   0    0.815217  0.235702  2009.0   2009.0
# 43650  98    34   0    57   1   -0.369565  0.000000  42641.0  43652.0
# 43651  99    34   0    57   1   -0.369565  0.000000  42641.0  43652.0
#
#                                            file  \
# 0      /home/workspace/lib/checkunusedvar.h
# 1      /home/workspace/lib/checkunusedvar.h
# 2      /home/workspace/lib/checkunusedvar.h
# 3      /home/workspace/lib/checkunusedvar.h
# 4      /home/workspace/lib/checkunusedvar.h
# ...                                     ...
# 43647  /home/workspace/lib/templatesimplifier.h
# 43648  /home/workspace/lib/templatesimplifier.h
# 43649  /home/workspace/lib/templatesimplifier.h
# 43650  /home/workspace/lib/analyzer.h
# 43651  /home/workspace/lib/analyzer.h
#
#                                                                       func  \
# 0      _ZN14CheckUnusedVarD2Ev
# 1      _ZN14CheckUnusedVarC2Ev
# 2      _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger
# 3      _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger
# 4      _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger
# ...                                                                    ...
# 43647  _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token
# 43648  _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token
# 43649  _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token
# 43650  _ZNK8Analyzer6Action7matchesEv
# 43651  _ZNK8Analyzer6Action7matchesEv
#
#                                                                                                               meth
# 0      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarD2Ev)
# 1      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2Ev)
# 2      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger)
# 3      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger)
# 4      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVar9runChecksEPK9TokenizerPK8SettingsP11ErrorLogger)
# ...                                                                                                            ...
# 43647  (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token)
# 43648  (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token)
# 43649  (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token)
# 43650  (/home/workspace/lib/analyzer.h, _ZNK8Analyzer6Action7matchesEv)
# 43651  (/home/workspace/lib/analyzer.h, _ZNK8Analyzer6Action7matchesEv)
#
# [43652 rows x 12 columns]

# %% [markdown]
# ## Max aggregation

# %%
print("[Op2]")
spectra_max_op2 = spectra.copy().sort_values(
    ["Sop2", "meth", "line"], ascending=False
)
spectra_max_op2.drop_duplicates(subset="meth", keep="first", inplace=True)
spectra_max_op2 = spectra_max_op2[
    ["meth", "line", "e_p", "e_f", "n_p", "n_f", "Sop2"]
]
spectra_max_op2["Rop2"] = spectra_max_op2.Sop2.rank(
    ascending=False, method="max"
)
print("Faulty method:")
display(
    spectra_max_op2.loc[spectra_max_op2.meth.isin(fault_meths)].reset_index(
        drop=True
    )
)
print("Top 20 methods:")
display(spectra_max_op2.head(20).reset_index(drop=True))
print()
print("[Ochiai]")
spectra_max_ochiai = spectra.copy().sort_values(
    ["Sochiai", "meth", "line"], ascending=False
)
spectra_max_ochiai.drop_duplicates(subset="meth", keep="first", inplace=True)
spectra_max_ochiai = spectra_max_ochiai[
    ["meth", "line", "e_p", "e_f", "n_p", "n_f", "Sochiai"]
]
spectra_max_ochiai["Rochiai"] = spectra_max_ochiai.Sochiai.rank(
    ascending=False, method="max"
)
print("Faulty method:")
display(
    spectra_max_ochiai.loc[
        spectra_max_ochiai.meth.isin(fault_meths)
    ].reset_index(drop=True)
)
print("Top 20 methods:")
display(spectra_max_ochiai.head(20).reset_index(drop=True))
# Out:
# [Op2]
# Faulty method:
#                                                                       meth  \
# 0  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
#
#    line  e_p  e_f  n_p  n_f      Sop2   Rop2
# 0  1959  29   1    62   0    0.684783  402.0
# Top 20 methods:
#                                                                                                                                                                                                                                          meth  \
# 0   (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 1   (/home/workspace/lib/symboldatabase.cpp, _ZN8Function11returnsVoidEPKS_b)
# 2   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 3   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass14uninitVarErrorEPK5TokenbN8Function4TypeERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEESC_bb)
# 4   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 5   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12assignAllVarERNSt7__debug6vectorINS_5UsageESaIS2_EEE)
# 6   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 7   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 8   (/home/workspace/lib/checkclass.cpp, _ZL21getAllVariableMembersPK5ScopeRNSt7__debug6vectorIPK8VariableSaIS6_EEE)
# 9   (/home/workspace/lib/checkclass.cpp, _ZL20isVariableCopyNeededRK8Variable)
# 10  (/home/workspace/lib/valueflow.cpp, _ZZL28valueFlowLifetimeConstructorP5TokenPK4TypeP9TokenListP11ErrorLoggerPK8SettingsENKUlR13LifetimeStoreE_clESC_)
# 11  (/home/workspace/lib/tokenize.cpp, _ZN9Tokenizer20removeMacroInVarDeclEv)
# 12  (/home/workspace/lib/tokenize.cpp, _ZN9Tokenizer15simplifyTypedefEv)
# 13  (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
# 14  (/home/workspace/lib/symboldatabase.cpp, _ZN5Scope15getVariableListEPK8SettingsPK5TokenS5_)
# 15  (/home/workspace/lib/symboldatabase.cpp, _ZN14SymbolDatabase33createSymbolDatabaseFindAllScopesEv)
# 16  (/home/workspace/lib/symboldatabase.cpp, _ZN14SymbolDatabase19findFunctionInScopeEPK5TokenPK5ScopeRKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 17  (/home/workspace/lib/symboldatabase.cpp, _ZN14SymbolDatabase16addClassFunctionEPP5ScopePPK5TokenS5_)
# 18  (/home/workspace/lib/checkclass.h, _ZN10CheckClass5UsageC2EPK8Variable)
# 19  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass9assignVarERNSt7__debug6vectorINS_5UsageESaIS2_EEEi)
#
#     line  e_p  e_f  n_p  n_f     Sop2  Rop2
# 0   2539  0    1    91   0    1.00000  10.0
# 1   2713  0    1    91   0    1.00000  10.0
# 2   945   0    1    91   0    1.00000  10.0
# 3   977   0    1    91   0    1.00000  10.0
# 4   269   0    1    91   0    1.00000  10.0
# 5   618   0    1    91   0    1.00000  10.0
# 6   565   0    1    91   0    1.00000  10.0
# 7   538   0    1    91   0    1.00000  10.0
# 8   578   0    1    91   0    1.00000  10.0
# 9   79    0    1    91   0    1.00000  10.0
# 10  3677  1    1    90   0    0.98913  25.0
# 11  5867  1    1    90   0    0.98913  25.0
# 12  1638  1    1    90   0    0.98913  25.0
# 13  2085  1    1    90   0    0.98913  25.0
# 14  4260  1    1    90   0    0.98913  25.0
# 15  578   1    1    90   0    0.98913  25.0
# 16  5608  1    1    90   0    0.98913  25.0
# 17  2871  1    1    90   0    0.98913  25.0
# 18  312   1    1    90   0    0.98913  25.0
# 19  599   1    1    90   0    0.98913  25.0
# [Ochiai]
# Faulty method:
#                                                                       meth  \
# 0  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
#
#    line  e_p  e_f  n_p  n_f   Sochiai  Rochiai
# 0  1959  29   1    62   0    0.182574  402.0
# Top 20 methods:
#                                                                                                                                                                                                                                          meth  \
# 0   (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 1   (/home/workspace/lib/symboldatabase.cpp, _ZN8Function11returnsVoidEPKS_b)
# 2   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 3   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass14uninitVarErrorEPK5TokenbN8Function4TypeERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEESC_bb)
# 4   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 5   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12assignAllVarERNSt7__debug6vectorINS_5UsageESaIS2_EEE)
# 6   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 7   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 8   (/home/workspace/lib/checkclass.cpp, _ZL21getAllVariableMembersPK5ScopeRNSt7__debug6vectorIPK8VariableSaIS6_EEE)
# 9   (/home/workspace/lib/checkclass.cpp, _ZL20isVariableCopyNeededRK8Variable)
# 10  (/home/workspace/lib/valueflow.cpp, _ZZL28valueFlowLifetimeConstructorP5TokenPK4TypeP9TokenListP11ErrorLoggerPK8SettingsENKUlR13LifetimeStoreE_clESC_)
# 11  (/home/workspace/lib/tokenize.cpp, _ZN9Tokenizer20removeMacroInVarDeclEv)
# 12  (/home/workspace/lib/tokenize.cpp, _ZN9Tokenizer15simplifyTypedefEv)
# 13  (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
# 14  (/home/workspace/lib/symboldatabase.cpp, _ZN5Scope15getVariableListEPK8SettingsPK5TokenS5_)
# 15  (/home/workspace/lib/symboldatabase.cpp, _ZN14SymbolDatabase33createSymbolDatabaseFindAllScopesEv)
# 16  (/home/workspace/lib/symboldatabase.cpp, _ZN14SymbolDatabase19findFunctionInScopeEPK5TokenPK5ScopeRKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 17  (/home/workspace/lib/symboldatabase.cpp, _ZN14SymbolDatabase16addClassFunctionEPP5ScopePPK5TokenS5_)
# 18  (/home/workspace/lib/checkclass.h, _ZN10CheckClass5UsageC2EPK8Variable)
# 19  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass9assignVarERNSt7__debug6vectorINS_5UsageESaIS2_EEEi)
#
#     line  e_p  e_f  n_p  n_f   Sochiai  Rochiai
# 0   2539  0    1    91   0    1.000000  10.0
# 1   2713  0    1    91   0    1.000000  10.0
# 2   945   0    1    91   0    1.000000  10.0
# 3   977   0    1    91   0    1.000000  10.0
# 4   269   0    1    91   0    1.000000  10.0
# 5   618   0    1    91   0    1.000000  10.0
# 6   565   0    1    91   0    1.000000  10.0
# 7   538   0    1    91   0    1.000000  10.0
# 8   578   0    1    91   0    1.000000  10.0
# 9   79    0    1    91   0    1.000000  10.0
# 10  3677  1    1    90   0    0.707107  25.0
# 11  5867  1    1    90   0    0.707107  25.0
# 12  1638  1    1    90   0    0.707107  25.0
# 13  2085  1    1    90   0    0.707107  25.0
# 14  4260  1    1    90   0    0.707107  25.0
# 15  578   1    1    90   0    0.707107  25.0
# 16  5608  1    1    90   0    0.707107  25.0
# 17  2871  1    1    90   0    0.707107  25.0
# 18  312   1    1    90   0    0.707107  25.0
# 19  599   1    1    90   0    0.707107  25.0

# %% [markdown]
# ## Line2Method voting (weight: sbfl score / dense rank)

# %%
print("[Op2]")
ballot_op2 = {}
spectra_max_op2 = spectra.copy().sort_values(
    ["Sop2", "meth", "line"], ascending=False
)
spectra_max_op2["Rop2D"] = spectra_max_op2.Sop2.rank(
    ascending=False, method="dense"
)
spectra_max_op2["vote"] = spectra_max_op2.Sop2 / spectra_max_op2.Rop2D
for row in spectra_max_op2.itertuples():
    if row.meth not in ballot_op2:
        ballot_op2[row.meth] = row.vote
    else:
        ballot_op2[row.meth] += row.vote
L2M_op2 = pd.DataFrame(
    {"meth": list(ballot_op2.keys()), "vote": list(ballot_op2.values())}
)
L2M_op2["rank"] = L2M_op2.vote.rank(ascending=False, method="max")
L2M_op2.sort_values("rank", inplace=True)
L2M_op2.reset_index(drop=True, inplace=True)
for fault_meth in fault_meths:
    print("Faulty method:")
    display(L2M_op2.loc[L2M_op2.meth == fault_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_op2.loc[spectra_max_op2.meth == fault_meth].reset_index(
            drop=True
        )
    )
print("Top 5 methods:")
display(L2M_op2.head(5).reset_index(drop=True))
for idx, top_meth in enumerate(L2M_op2.head(5).meth.tolist(), 1):
    print(f"Top {idx}:")
    display(L2M_op2.loc[L2M_op2.meth == top_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_op2.loc[spectra_max_op2.meth == top_meth].reset_index(
            drop=True
        )
    )
print()
print("[Ochiai]")
ballot_ochiai = {}
spectra_max_ochiai = spectra.copy().sort_values(
    ["Sochiai", "meth", "line"], ascending=False
)
spectra_max_ochiai["RochiaiD"] = spectra_max_ochiai.Sochiai.rank(
    ascending=False, method="dense"
)
spectra_max_ochiai["vote"] = (
    spectra_max_ochiai.Sochiai / spectra_max_ochiai.RochiaiD
)
for row in spectra_max_ochiai.itertuples():
    if row.meth not in ballot_ochiai:
        ballot_ochiai[row.meth] = row.vote
    else:
        ballot_ochiai[row.meth] += row.vote
L2M_ochiai = pd.DataFrame(
    {"meth": list(ballot_ochiai.keys()), "vote": list(ballot_ochiai.values())}
)
L2M_ochiai["rank"] = L2M_ochiai.vote.rank(ascending=False, method="max")
L2M_ochiai.sort_values("rank", inplace=True)
L2M_ochiai.reset_index(drop=True, inplace=True)
for fault_meth in fault_meths:
    print("Faulty method:")
    display(
        L2M_ochiai.loc[L2M_ochiai.meth == fault_meth].reset_index(drop=True)
    )
    print("Voters:")
    display(
        spectra_max_ochiai.loc[
            spectra_max_ochiai.meth == fault_meth
        ].reset_index(drop=True)
    )
print("Top 5 methods:")
display(L2M_ochiai.head(5).reset_index(drop=True))
for idx, top_meth in enumerate(L2M_ochiai.head(5).meth.tolist(), 1):
    print(f"Top {idx}:")
    display(L2M_ochiai.loc[L2M_ochiai.meth == top_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_ochiai.loc[spectra_max_ochiai.meth == top_meth].reset_index(
            drop=True
        )
    )
# Out:
# [Op2]
# Faulty method:
#                                                                       meth  \
# 0  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
#
#        vote   rank
# 0  0.067885  424.0
# Voters:
#    line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai  \
# 0  1959  29   1    62   0    0.684783  0.182574  3951.0  3951.0
# 1  1962  54   1    37   0    0.413043  0.134840  6681.0  6681.0
# 2  1960  54   1    37   0    0.413043  0.134840  6681.0  6681.0
# 3  1958  54   1    37   0    0.413043  0.134840  6681.0  6681.0
# 4  1957  54   1    37   0    0.413043  0.134840  6681.0  6681.0
# 5  1956  54   1    37   0    0.413043  0.134840  6681.0  6681.0
# 6  1954  54   1    37   0    0.413043  0.134840  6681.0  6681.0
#
#                                      file                           func  \
# 0  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
# 1  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
# 2  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
# 3  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
# 4  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
# 5  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
# 6  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
#
#                                                                       meth  \
# 0  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
# 1  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
# 2  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
# 3  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
# 4  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
# 5  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
# 6  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
#
#    Rop2D      vote
# 0  30.0   0.022826
# 1  55.0   0.007510
# 2  55.0   0.007510
# 3  55.0   0.007510
# 4  55.0   0.007510
# 5  55.0   0.007510
# 6  55.0   0.007510
# Top 5 methods:
#                                                                                                                                                                                                                                         meth  \
# 0  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 1  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 2  (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
# 3  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 4  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
#
#          vote  rank
# 0  104.272826  1.0
# 1  49.209637   2.0
# 2  18.332833   3.0
# 3  16.000000   4.0
# 4  14.720440   5.0
# Top 1:
#                                                                                                                                                           meth  \
# 0  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
#
#          vote  rank
# 0  104.272826  1.0
# Voters:
#      line  e_p  e_f  n_p  n_f      Sop2   Sochiai   Rop2  Rochiai  \
# 0    945   0    1    91   0    1.000000  1.000000  159.0  159.0
# 1    943   0    1    91   0    1.000000  1.000000  159.0  159.0
# 2    938   0    1    91   0    1.000000  1.000000  159.0  159.0
# 3    937   0    1    91   0    1.000000  1.000000  159.0  159.0
# 4    935   0    1    91   0    1.000000  1.000000  159.0  159.0
# ..   ...  ..   ..    ..  ..         ...       ...    ...    ...
# 139  658   4    1    87   0    0.956522  0.447214  529.0  529.0
# 140  657   4    1    87   0    0.956522  0.447214  529.0  529.0
# 141  656   4    1    87   0    0.956522  0.447214  529.0  529.0
# 142  654   4    1    87   0    0.956522  0.447214  529.0  529.0
# 143  652   4    1    87   0    0.956522  0.447214  529.0  529.0
#
#                                    file  \
# 0    /home/workspace/lib/checkclass.cpp
# 1    /home/workspace/lib/checkclass.cpp
# 2    /home/workspace/lib/checkclass.cpp
# 3    /home/workspace/lib/checkclass.cpp
# 4    /home/workspace/lib/checkclass.cpp
# ..                                  ...
# 139  /home/workspace/lib/checkclass.cpp
# 140  /home/workspace/lib/checkclass.cpp
# 141  /home/workspace/lib/checkclass.cpp
# 142  /home/workspace/lib/checkclass.cpp
# 143  /home/workspace/lib/checkclass.cpp
#
#                                                                                                                       func  \
# 0    _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 1    _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 2    _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 3    _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 4    _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# ..                                                                                                                     ...
# 139  _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 140  _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 141  _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 142  _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 143  _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
#
#                                                                                                                                                             meth  \
# 0    (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 1    (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 2    (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 3    (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 4    (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# ..                                                                                                                                                           ...
# 139  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 140  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 141  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 142  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 143  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
#
#      Rop2D      vote
# 0    1.0    1.000000
# 1    1.0    1.000000
# 2    1.0    1.000000
# 3    1.0    1.000000
# 4    1.0    1.000000
# ..   ...         ...
# 139  5.0    0.191304
# 140  5.0    0.191304
# 141  5.0    0.191304
# 142  5.0    0.191304
# 143  5.0    0.191304
#
# [144 rows x 14 columns]
# Top 2:
#                                                                     meth  \
# 0  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
#
#         vote  rank
# 0  49.209637  2.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0   269   0    1    91   0    1.000000  1.000000  159.0    159.0
# 1   268   0    1    91   0    1.000000  1.000000  159.0    159.0
# 2   266   0    1    91   0    1.000000  1.000000  159.0    159.0
# 3   264   0    1    91   0    1.000000  1.000000  159.0    159.0
# 4   258   0    1    91   0    1.000000  1.000000  159.0    159.0
# ..  ...  ..   ..    ..  ..         ...       ...    ...      ...
# 87  119   14   1    77   0    0.847826  0.258199  1547.0   1547.0
# 88  118   14   1    77   0    0.847826  0.258199  1547.0   1547.0
# 89  117   14   1    77   0    0.847826  0.258199  1547.0   1547.0
# 90  115   14   1    77   0    0.847826  0.258199  1547.0   1547.0
# 91  154   1    0    90   1   -0.010870  0.000000  23123.0  43652.0
#
#                                   file                             func  \
# 0   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 1   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 2   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 3   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 4   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# ..                                 ...                              ...
# 87  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 88  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 89  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 90  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 91  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
#
#                                                                      meth  \
# 0   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 1   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 2   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 3   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 4   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# ..                                                                    ...
# 87  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 88  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 89  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 90  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 91  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
#
#     Rop2D      vote
# 0   1.0    1.000000
# 1   1.0    1.000000
# 2   1.0    1.000000
# 3   1.0    1.000000
# 4   1.0    1.000000
# ..  ...         ...
# 87  15.0   0.056522
# 88  15.0   0.056522
# 89  15.0   0.056522
# 90  15.0   0.056522
# 91  82.0  -0.000133
#
# [92 rows x 14 columns]
# Top 3:
#                                                                                                                                                                                                                                         meth  \
# 0  (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
#
#         vote  rank
# 0  18.332833  3.0
# Voters:
#      line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0    2085  1    1    90   0    0.989130  0.707107  269.0    269.0
# 1    2084  1    1    90   0    0.989130  0.707107  269.0    269.0
# 2    2083  1    1    90   0    0.989130  0.707107  269.0    269.0
# 3    2082  1    1    90   0    0.989130  0.707107  269.0    269.0
# 4    2081  1    1    90   0    0.989130  0.707107  269.0    269.0
# ..    ... ..   ..    ..  ..         ...       ...    ...      ...
# 455  1599  14   0    77   1   -0.152174  0.000000  36476.0  43652.0
# 456  1598  14   0    77   1   -0.152174  0.000000  36476.0  43652.0
# 457  1597  14   0    77   1   -0.152174  0.000000  36476.0  43652.0
# 458  1596  14   0    77   1   -0.152174  0.000000  36476.0  43652.0
# 459  1595  14   0    77   1   -0.152174  0.000000  36476.0  43652.0
#
#                                            file  \
# 0    /home/workspace/lib/templatesimplifier.cpp
# 1    /home/workspace/lib/templatesimplifier.cpp
# 2    /home/workspace/lib/templatesimplifier.cpp
# 3    /home/workspace/lib/templatesimplifier.cpp
# 4    /home/workspace/lib/templatesimplifier.cpp
# ..                                          ...
# 455  /home/workspace/lib/templatesimplifier.cpp
# 456  /home/workspace/lib/templatesimplifier.cpp
# 457  /home/workspace/lib/templatesimplifier.cpp
# 458  /home/workspace/lib/templatesimplifier.cpp
# 459  /home/workspace/lib/templatesimplifier.cpp
#
#                                                                                                                                                                                             func  \
# 0    _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_
# 1    _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_
# 2    _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_
# 3    _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_
# 4    _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_
# ..                                                                                                                                                                                           ...
# 455  _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_
# 456  _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_
# 457  _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_
# 458  _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_
# 459  _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_
#
#                                                                                                                                                                                                                                           meth  \
# 0    (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
# 1    (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
# 2    (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
# 3    (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
# 4    (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
# ..                                                                                                                                                                                                                                         ...
# 455  (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
# 456  (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
# 457  (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
# 458  (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
# 459  (/home/workspace/lib/templatesimplifier.cpp, _ZZN18TemplateSimplifier14expandTemplateERKNS_12TokenAndNameES2_RKNSt7__debug6vectorIPK5TokenSaIS7_EEERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEbEN16newInstantiationC2EPS5_SJ_)
#
#      Rop2D      vote
# 0    2.0    0.494565
# 1    2.0    0.494565
# 2    2.0    0.494565
# 3    2.0    0.494565
# 4    2.0    0.494565
# ..   ...         ...
# 455  95.0  -0.001602
# 456  95.0  -0.001602
# 457  95.0  -0.001602
# 458  95.0  -0.001602
# 459  95.0  -0.001602
#
# [460 rows x 14 columns]
# Top 4:
#                                                                          meth  \
# 0  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
#
#    vote  rank
# 0  16.0  4.0
# Voters:
#     line  e_p  e_f  n_p  n_f  Sop2  Sochiai   Rop2  Rochiai  \
# 0   565   0    1    91   0    1.0   1.0      159.0  159.0
# 1   558   0    1    91   0    1.0   1.0      159.0  159.0
# 2   557   0    1    91   0    1.0   1.0      159.0  159.0
# 3   556   0    1    91   0    1.0   1.0      159.0  159.0
# 4   555   0    1    91   0    1.0   1.0      159.0  159.0
# 5   554   0    1    91   0    1.0   1.0      159.0  159.0
# 6   553   0    1    91   0    1.0   1.0      159.0  159.0
# 7   551   0    1    91   0    1.0   1.0      159.0  159.0
# 8   550   0    1    91   0    1.0   1.0      159.0  159.0
# 9   549   0    1    91   0    1.0   1.0      159.0  159.0
# 10  548   0    1    91   0    1.0   1.0      159.0  159.0
# 11  546   0    1    91   0    1.0   1.0      159.0  159.0
# 12  545   0    1    91   0    1.0   1.0      159.0  159.0
# 13  544   0    1    91   0    1.0   1.0      159.0  159.0
# 14  543   0    1    91   0    1.0   1.0      159.0  159.0
# 15  541   0    1    91   0    1.0   1.0      159.0  159.0
#
#                                   file                                  func  \
# 0   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 1   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 2   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 3   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 4   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 5   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 6   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 7   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 8   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 9   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 10  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 11  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 12  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 13  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 14  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 15  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
#
#                                                                           meth  \
# 0   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 1   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 2   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 3   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 4   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 5   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 6   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 7   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 8   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 9   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 10  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 11  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 12  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 13  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 14  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 15  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
#
#     Rop2D  vote
# 0   1.0    1.0
# 1   1.0    1.0
# 2   1.0    1.0
# 3   1.0    1.0
# 4   1.0    1.0
# 5   1.0    1.0
# 6   1.0    1.0
# 7   1.0    1.0
# 8   1.0    1.0
# 9   1.0    1.0
# 10  1.0    1.0
# 11  1.0    1.0
# 12  1.0    1.0
# 13  1.0    1.0
# 14  1.0    1.0
# 15  1.0    1.0
# Top 5:
#                                                                                                                                            meth  \
# 0  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
#
#        vote  rank
# 0  14.72044  5.0
# Voters:
#      line  e_p  e_f  n_p  n_f      Sop2  Sochiai     Rop2  Rochiai  \
# 0    2539  0    1    91   0    1.000000  1.0      159.0    159.0
# 1    2538  0    1    91   0    1.000000  1.0      159.0    159.0
# 2    2537  0    1    91   0    1.000000  1.0      159.0    159.0
# 3    2526  0    1    91   0    1.000000  1.0      159.0    159.0
# 4    2525  0    1    91   0    1.000000  1.0      159.0    159.0
# ..    ... ..   ..    ..  ..         ...  ...        ...      ...
# 113  2583  2    0    89   1   -0.021739  0.0      27203.0  43652.0
# 114  2582  2    0    89   1   -0.021739  0.0      27203.0  43652.0
# 115  2477  2    0    89   1   -0.021739  0.0      27203.0  43652.0
# 116  2464  3    0    88   1   -0.032609  0.0      29267.0  43652.0
# 117  2662  7    0    84   1   -0.076087  0.0      32974.0  43652.0
#
#                                        file  \
# 0    /home/workspace/lib/symboldatabase.cpp
# 1    /home/workspace/lib/symboldatabase.cpp
# 2    /home/workspace/lib/symboldatabase.cpp
# 3    /home/workspace/lib/symboldatabase.cpp
# 4    /home/workspace/lib/symboldatabase.cpp
# ..                                      ...
# 113  /home/workspace/lib/symboldatabase.cpp
# 114  /home/workspace/lib/symboldatabase.cpp
# 115  /home/workspace/lib/symboldatabase.cpp
# 116  /home/workspace/lib/symboldatabase.cpp
# 117  /home/workspace/lib/symboldatabase.cpp
#
#                                                                                                    func  \
# 0    _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 1    _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 2    _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 3    _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 4    _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# ..                                                                                                  ...
# 113  _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 114  _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 115  _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 116  _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 117  _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
#
#                                                                                                                                              meth  \
# 0    (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 1    (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 2    (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 3    (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 4    (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# ..                                                                                                                                            ...
# 113  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 114  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 115  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 116  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 117  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
#
#      Rop2D      vote
# 0    1.0    1.000000
# 1    1.0    1.000000
# 2    1.0    1.000000
# 3    1.0    1.000000
# 4    1.0    1.000000
# ..   ...         ...
# 113  83.0  -0.000262
# 114  83.0  -0.000262
# 115  83.0  -0.000262
# 116  84.0  -0.000388
# 117  88.0  -0.000865
#
# [118 rows x 14 columns]
# [Ochiai]
# Faulty method:
#                                                                       meth  \
# 0  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
#
#        vote   rank
# 0  0.020796  460.0
# Voters:
#    line  e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai  \
# 0  1959  29   1    62   0    0.684783  0.182574  3951.0  3951.0
# 1  1962  54   1    37   0    0.413043  0.134840  6681.0  6681.0
# 2  1960  54   1    37   0    0.413043  0.134840  6681.0  6681.0
# 3  1958  54   1    37   0    0.413043  0.134840  6681.0  6681.0
# 4  1957  54   1    37   0    0.413043  0.134840  6681.0  6681.0
# 5  1956  54   1    37   0    0.413043  0.134840  6681.0  6681.0
# 6  1954  54   1    37   0    0.413043  0.134840  6681.0  6681.0
#
#                                      file                           func  \
# 0  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
# 1  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
# 2  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
# 3  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
# 4  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
# 5  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
# 6  /home/workspace/lib/symboldatabase.cpp  _ZNK8Variable12declEndTokenEv
#
#                                                                       meth  \
# 0  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
# 1  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
# 2  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
# 3  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
# 4  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
# 5  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
# 6  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Variable12declEndTokenEv)
#
#    RochiaiD      vote
# 0  30.0      0.006086
# 1  55.0      0.002452
# 2  55.0      0.002452
# 3  55.0      0.002452
# 4  55.0      0.002452
# 5  55.0      0.002452
# 6  55.0      0.002452
# Top 5 methods:
#                                                                                                                                                           meth  \
# 0  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 1  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 2  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 3  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 4  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
#
#         vote  rank
# 0  96.406986  1.0
# 1  42.577899  2.0
# 2  16.000000  3.0
# 3  14.000000  4.0
# 4  10.855883  5.0
# Top 1:
#                                                                                                                                                           meth  \
# 0  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
#
#         vote  rank
# 0  96.406986  1.0
# Voters:
#      line  e_p  e_f  n_p  n_f      Sop2   Sochiai   Rop2  Rochiai  \
# 0    945   0    1    91   0    1.000000  1.000000  159.0  159.0
# 1    943   0    1    91   0    1.000000  1.000000  159.0  159.0
# 2    938   0    1    91   0    1.000000  1.000000  159.0  159.0
# 3    937   0    1    91   0    1.000000  1.000000  159.0  159.0
# 4    935   0    1    91   0    1.000000  1.000000  159.0  159.0
# ..   ...  ..   ..    ..  ..         ...       ...    ...    ...
# 139  658   4    1    87   0    0.956522  0.447214  529.0  529.0
# 140  657   4    1    87   0    0.956522  0.447214  529.0  529.0
# 141  656   4    1    87   0    0.956522  0.447214  529.0  529.0
# 142  654   4    1    87   0    0.956522  0.447214  529.0  529.0
# 143  652   4    1    87   0    0.956522  0.447214  529.0  529.0
#
#                                    file  \
# 0    /home/workspace/lib/checkclass.cpp
# 1    /home/workspace/lib/checkclass.cpp
# 2    /home/workspace/lib/checkclass.cpp
# 3    /home/workspace/lib/checkclass.cpp
# 4    /home/workspace/lib/checkclass.cpp
# ..                                  ...
# 139  /home/workspace/lib/checkclass.cpp
# 140  /home/workspace/lib/checkclass.cpp
# 141  /home/workspace/lib/checkclass.cpp
# 142  /home/workspace/lib/checkclass.cpp
# 143  /home/workspace/lib/checkclass.cpp
#
#                                                                                                                       func  \
# 0    _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 1    _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 2    _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 3    _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 4    _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# ..                                                                                                                     ...
# 139  _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 140  _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 141  _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 142  _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
# 143  _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE
#
#                                                                                                                                                             meth  \
# 0    (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 1    (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 2    (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 3    (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 4    (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# ..                                                                                                                                                           ...
# 139  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 140  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 141  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 142  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
# 143  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass17initializeVarListERK8FunctionRNSt7__debug4listIPS1_SaIS5_EEEPK5ScopeRNS3_6vectorINS_5UsageESaISD_EEE)
#
#      RochiaiD      vote
# 0    1.0       1.000000
# 1    1.0       1.000000
# 2    1.0       1.000000
# 3    1.0       1.000000
# 4    1.0       1.000000
# ..   ...            ...
# 139  5.0       0.089443
# 140  5.0       0.089443
# 141  5.0       0.089443
# 142  5.0       0.089443
# 143  5.0       0.089443
#
# [144 rows x 14 columns]
# Top 2:
#                                                                     meth  \
# 0  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
#
#         vote  rank
# 0  42.577899  2.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0   269   0    1    91   0    1.000000  1.000000  159.0    159.0
# 1   268   0    1    91   0    1.000000  1.000000  159.0    159.0
# 2   266   0    1    91   0    1.000000  1.000000  159.0    159.0
# 3   264   0    1    91   0    1.000000  1.000000  159.0    159.0
# 4   258   0    1    91   0    1.000000  1.000000  159.0    159.0
# ..  ...  ..   ..    ..  ..         ...       ...    ...      ...
# 87  119   14   1    77   0    0.847826  0.258199  1547.0   1547.0
# 88  118   14   1    77   0    0.847826  0.258199  1547.0   1547.0
# 89  117   14   1    77   0    0.847826  0.258199  1547.0   1547.0
# 90  115   14   1    77   0    0.847826  0.258199  1547.0   1547.0
# 91  154   1    0    90   1   -0.010870  0.000000  23123.0  43652.0
#
#                                   file                             func  \
# 0   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 1   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 2   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 3   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 4   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# ..                                 ...                              ...
# 87  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 88  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 89  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 90  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
# 91  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass12constructorsEv
#
#                                                                      meth  \
# 0   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 1   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 2   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 3   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 4   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# ..                                                                    ...
# 87  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 88  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 89  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 90  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
# 91  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass12constructorsEv)
#
#     RochiaiD      vote
# 0   1.0       1.000000
# 1   1.0       1.000000
# 2   1.0       1.000000
# 3   1.0       1.000000
# 4   1.0       1.000000
# ..  ...            ...
# 87  15.0      0.017213
# 88  15.0      0.017213
# 89  15.0      0.017213
# 90  15.0      0.017213
# 91  82.0      0.000000
#
# [92 rows x 14 columns]
# Top 3:
#                                                                          meth  \
# 0  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
#
#    vote  rank
# 0  16.0  3.0
# Voters:
#     line  e_p  e_f  n_p  n_f  Sop2  Sochiai   Rop2  Rochiai  \
# 0   565   0    1    91   0    1.0   1.0      159.0  159.0
# 1   558   0    1    91   0    1.0   1.0      159.0  159.0
# 2   557   0    1    91   0    1.0   1.0      159.0  159.0
# 3   556   0    1    91   0    1.0   1.0      159.0  159.0
# 4   555   0    1    91   0    1.0   1.0      159.0  159.0
# 5   554   0    1    91   0    1.0   1.0      159.0  159.0
# 6   553   0    1    91   0    1.0   1.0      159.0  159.0
# 7   551   0    1    91   0    1.0   1.0      159.0  159.0
# 8   550   0    1    91   0    1.0   1.0      159.0  159.0
# 9   549   0    1    91   0    1.0   1.0      159.0  159.0
# 10  548   0    1    91   0    1.0   1.0      159.0  159.0
# 11  546   0    1    91   0    1.0   1.0      159.0  159.0
# 12  545   0    1    91   0    1.0   1.0      159.0  159.0
# 13  544   0    1    91   0    1.0   1.0      159.0  159.0
# 14  543   0    1    91   0    1.0   1.0      159.0  159.0
# 15  541   0    1    91   0    1.0   1.0      159.0  159.0
#
#                                   file                                  func  \
# 0   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 1   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 2   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 3   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 4   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 5   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 6   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 7   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 8   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 9   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 10  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 11  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 12  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 13  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 14  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
# 15  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotMoveEPK5Scope
#
#                                                                           meth  \
# 0   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 1   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 2   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 3   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 4   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 5   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 6   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 7   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 8   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 9   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 10  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 11  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 12  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 13  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 14  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
# 15  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotMoveEPK5Scope)
#
#     RochiaiD  vote
# 0   1.0       1.0
# 1   1.0       1.0
# 2   1.0       1.0
# 3   1.0       1.0
# 4   1.0       1.0
# 5   1.0       1.0
# 6   1.0       1.0
# 7   1.0       1.0
# 8   1.0       1.0
# 9   1.0       1.0
# 10  1.0       1.0
# 11  1.0       1.0
# 12  1.0       1.0
# 13  1.0       1.0
# 14  1.0       1.0
# 15  1.0       1.0
# Top 4:
#                                                                          meth  \
# 0  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
#
#    vote  rank
# 0  14.0  4.0
# Voters:
#     line  e_p  e_f  n_p  n_f  Sop2  Sochiai   Rop2  Rochiai  \
# 0   538   0    1    91   0    1.0   1.0      159.0  159.0
# 1   532   0    1    91   0    1.0   1.0      159.0  159.0
# 2   531   0    1    91   0    1.0   1.0      159.0  159.0
# 3   530   0    1    91   0    1.0   1.0      159.0  159.0
# 4   529   0    1    91   0    1.0   1.0      159.0  159.0
# 5   528   0    1    91   0    1.0   1.0      159.0  159.0
# 6   527   0    1    91   0    1.0   1.0      159.0  159.0
# 7   526   0    1    91   0    1.0   1.0      159.0  159.0
# 8   525   0    1    91   0    1.0   1.0      159.0  159.0
# 9   524   0    1    91   0    1.0   1.0      159.0  159.0
# 10  522   0    1    91   0    1.0   1.0      159.0  159.0
# 11  521   0    1    91   0    1.0   1.0      159.0  159.0
# 12  520   0    1    91   0    1.0   1.0      159.0  159.0
# 13  518   0    1    91   0    1.0   1.0      159.0  159.0
#
#                                   file                                  func  \
# 0   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 1   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 2   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 3   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 4   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 5   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 6   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 7   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 8   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 9   /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 10  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 11  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 12  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
# 13  /home/workspace/lib/checkclass.cpp  _ZN10CheckClass10canNotCopyEPK5Scope
#
#                                                                           meth  \
# 0   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 1   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 2   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 3   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 4   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 5   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 6   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 7   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 8   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 9   (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 10  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 11  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 12  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
# 13  (/home/workspace/lib/checkclass.cpp, _ZN10CheckClass10canNotCopyEPK5Scope)
#
#     RochiaiD  vote
# 0   1.0       1.0
# 1   1.0       1.0
# 2   1.0       1.0
# 3   1.0       1.0
# 4   1.0       1.0
# 5   1.0       1.0
# 6   1.0       1.0
# 7   1.0       1.0
# 8   1.0       1.0
# 9   1.0       1.0
# 10  1.0       1.0
# 11  1.0       1.0
# 12  1.0       1.0
# 13  1.0       1.0
# Top 5:
#                                                                                                                                            meth  \
# 0  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
#
#         vote  rank
# 0  10.855883  5.0
# Voters:
#      line  e_p  e_f  n_p  n_f      Sop2  Sochiai     Rop2  Rochiai  \
# 0    2539  0    1    91   0    1.000000  1.0      159.0    159.0
# 1    2538  0    1    91   0    1.000000  1.0      159.0    159.0
# 2    2537  0    1    91   0    1.000000  1.0      159.0    159.0
# 3    2526  0    1    91   0    1.000000  1.0      159.0    159.0
# 4    2525  0    1    91   0    1.000000  1.0      159.0    159.0
# ..    ... ..   ..    ..  ..         ...  ...        ...      ...
# 113  2552  1    0    90   1   -0.010870  0.0      23123.0  43652.0
# 114  2551  1    0    90   1   -0.010870  0.0      23123.0  43652.0
# 115  2477  2    0    89   1   -0.021739  0.0      27203.0  43652.0
# 116  2464  3    0    88   1   -0.032609  0.0      29267.0  43652.0
# 117  2455  1    0    90   1   -0.010870  0.0      23123.0  43652.0
#
#                                        file  \
# 0    /home/workspace/lib/symboldatabase.cpp
# 1    /home/workspace/lib/symboldatabase.cpp
# 2    /home/workspace/lib/symboldatabase.cpp
# 3    /home/workspace/lib/symboldatabase.cpp
# 4    /home/workspace/lib/symboldatabase.cpp
# ..                                      ...
# 113  /home/workspace/lib/symboldatabase.cpp
# 114  /home/workspace/lib/symboldatabase.cpp
# 115  /home/workspace/lib/symboldatabase.cpp
# 116  /home/workspace/lib/symboldatabase.cpp
# 117  /home/workspace/lib/symboldatabase.cpp
#
#                                                                                                    func  \
# 0    _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 1    _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 2    _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 3    _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 4    _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# ..                                                                                                  ...
# 113  _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 114  _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 115  _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 116  _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
# 117  _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi
#
#                                                                                                                                              meth  \
# 0    (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 1    (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 2    (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 3    (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 4    (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# ..                                                                                                                                            ...
# 113  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 114  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 115  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 116  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 117  (/home/workspace/lib/symboldatabase.cpp, _ZNK8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
#
#      RochiaiD  vote
# 0    1.0       1.0
# 1    1.0       1.0
# 2    1.0       1.0
# 3    1.0       1.0
# 4    1.0       1.0
# ..   ...       ...
# 113  82.0      0.0
# 114  82.0      0.0
# 115  82.0      0.0
# 116  82.0      0.0
# 117  82.0      0.0
#
# [118 rows x 14 columns]

# %% [markdown]
# # 감상
#
# 단순히 passing test에 의해서 한 번도 실행되지 않고 failing test에 의해서 실행되는 method가 너무 많다 (sbfl max agg top max rank: 10)
