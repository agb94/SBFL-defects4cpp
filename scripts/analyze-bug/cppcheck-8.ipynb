# %%
import os
import pandas as pd
import numpy as np
pd.set_option("display.max_colwidth", 2)

os.chdir("/home/coinse/Workspace/SBFL")

# %% [markdown]
# # Load bug info

# %%
from scripts.util import load_bug_data, find_covmat_func, find_covmat_idx
from functools import reduce
from typing import Set

pid, vid = "cppcheck", 8

bug = load_bug_data(pid, vid)

print(f"{bug.buggy_files=}")
print(f"{bug.buggy_lines=}")
print("bug.coverage_df=")
display(bug.coverage_df)
print(f"{bug.failing_tests=}")
print(f"{bug.failing_tests_GT=}")
print("bug.functions={", end="")
for func in list(bug.functions)[:5]:
    print(f"{func},", end=" ")
print(", ...}")
print(f"{bug.id=}")
print(f"{bug.num_test_cases=}")
print(f"{bug.passing_tests=}")
print(f"{bug.path_to_cov_df=}")
print(f"{bug.path_to_patch=}")
print(f"{bug.path_to_test_results=}")
print("bug.source_files=", end="")
for src in list(bug.source_files)[:5]:
    print(f"{src},", end=" ")
print(", ...}")

fault_idxs = sorted(bug.buggy_lines)
# fault_idx2meth = {}
fault_meth2idx = {}
err_msg = ""
for fault_idx in fault_idxs:
    succ_func, ret_func = find_covmat_func(
        pid, bug.coverage_df, fault_idx, debug=False
    )
    if succ_func:
        succ_idx, ret_idx = find_covmat_idx(
            pid, bug.coverage_df, fault_idx, debug=False
        )
        if succ_idx:
            if ret_func in fault_meth2idx:
                fault_meth2idx[ret_func].add(ret_idx)
            else:
                fault_meth2idx[ret_func] = {ret_idx}
        else:
            print(f"{ret_idx}")
            if ret_func not in fault_meth2idx:
                fault_meth2idx[ret_func] = set()
    else:
        print(f"{ret_func}")
# fault_meths: Set = reduce(
#     lambda x, y: x | set([y]), fault_idx2meth.values(), set()
# )
# fault_meth2idx = {
#     v: {idx for idx in fault_idx2meth if fault_idx2meth[idx] == v}
#     for v in fault_meths
# }
fault_meths = set(fault_meth2idx.keys())
for meth in fault_meth2idx:
    print(f"{meth=}: {fault_meth2idx[meth]}")
# print(f"{fault_meths=}")
# Out:
# bug.buggy_files={'lib/astutils.cpp'}
# bug.buggy_lines={('lib/astutils.cpp', 1580), ('lib/astutils.cpp', 1581)}
# bug.coverage_df=
#                                                                                                                          39  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   14
#                                                                                                                    167   14
#                                                                                                                    168   14
#
#                                                                                                                          22  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          71  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    2
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    1
#                                                                                                                    52    1
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          64  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          55  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   3
#                                                                                                                    167   3
#                                                                                                                    168   3
#
#                                                                                                                          6  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          73  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    2
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    1
#                                                                                                                    52    1
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          82  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    2
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    1
#                                                                                                                    52    1
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          36  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          9  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          ...  \
# file                                       function                                                                line  ...
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    ...
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    ...
#                                                                                                                    48    ...
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    ...
#                                                                                                                    52    ...
# ...                                                                                                                      ...
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   ...
#                                            _Z41__static_initialization_and_destruction_0ii                         938   ...
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   ...
#                                                                                                                    167   ...
#                                                                                                                    168   ...
#
#                                                                                                                          53  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   3
#                                                                                                                    167   3
#                                                                                                                    168   3
#
#                                                                                                                          57  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          14  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   8
#                                                                                                                    167   8
#                                                                                                                    168   8
#
#                                                                                                                          13  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          59  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   3
#                                                                                                                    167   3
#                                                                                                                    168   3
#
#                                                                                                                          16  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          70  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    2
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    1
#                                                                                                                    52    1
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                          49  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
#                                                                                                                            38  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   1227
#                                                                                                                    167   1227
#                                                                                                                    168   1227
#
#                                                                                                                          31
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   3
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
# [39697 rows x 84 columns]
# bug.failing_tests={'32'}
# bug.failing_tests_GT={'32'}
# bug.functions={('/home/workspace/lib/checkio.cpp', '_ZN7CheckIO17checkFormatStringEPK5TokenS2_S2_bb'), ('/home/workspace/lib/checktype.cpp', '_ZN9CheckType27checkFloatToIntegerOverflowEv'), ('/home/workspace/lib/checkclass.cpp', '_ZN10CheckClass31copyConstructorShallowCopyErrorEPK5TokenRKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE'), ('/home/workspace/lib/symboldatabase.cpp', '_ZNK14SymbolDatabase15findScopeByNameERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE'), ('/home/workspace/lib/tokenize.cpp', '_ZN12_GLOBAL__N_110usingMatchEPK5TokenRKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEPPS0_SA_RKNSt7__debug4listINS_10ScopeInfo3ESaISF_EEE'), , ...}
# bug.id='cppcheck-8'
# bug.num_test_cases=84
# bug.passing_tests={'68', '63', '56', '50', '12', '45', '30', '64', '62', '4', '14', '11', '82', '40', '79', '26', '24', '46', '60', '41', '17', '78', '35', '84', '3', '36', '83', '2', '38', '54', '33', '1', '29', '55', '77', '48', '25', '59', '49', '5', '76', '18', '7', '74', '81', '13', '37', '70', '27', '9', '31', '10', '23', '80', '34', '21', '20', '52', '61', '67', '42', '72', '43', '73', '15', '58', '65', '28', '66', '69', '44', '75', '71', '53', '19', '47', '39', '8', '16', '51', '22', '6', '57'}
# bug.path_to_cov_df='/home/coinse/Workspace/defects4cpp/coverage/cppcheck_8_buggy/coverage_df.pkl'
# bug.path_to_patch='/home/coinse/Workspace/defects4cpp/defects4cpp/taxonomy/cppcheck/patch/0008-buggy.patch'
# bug.path_to_test_results='/home/coinse/Workspace/defects4cpp/coverage/cppcheck_8_buggy/test_results.json'
# bug.source_files=/home/workspace/lib/checkunusedvar.cpp, /usr/include/c++/7/debug/safe_unordered_base.h, /home/workspace/lib/programmemory.cpp, /home/workspace/lib/checkstl.cpp, /home/workspace/lib/checknullpointer.cpp, , ...}
# meth=('/home/workspace/lib/astutils.cpp', '_Z18isLikelyStreamReadbPK5Token'): {('/home/workspace/lib/astutils.cpp', '_Z18isLikelyStreamReadbPK5Token', 1580), ('/home/workspace/lib/astutils.cpp', '_Z18isLikelyStreamReadbPK5Token', 1581)}

# %% [markdown]
# # Get spectra

# %%
covmat = bug.coverage_df
pass_tcs = bug.passing_tests
fail_tcs = bug.failing_tests

covmat_bool = covmat.astype(bool)
P = len(pass_tcs)
F = len(fail_tcs)
e_p = covmat_bool[pass_tcs].sum(axis=1)
e_f = covmat_bool[fail_tcs].sum(axis=1)
n_p = P - e_p
n_f = F - e_f
spectra = pd.DataFrame(
    {
        "line": covmat.index.to_list(),
        "e_p": e_p,
        "e_f": e_f,
        "n_p": n_p,
        "n_f": n_f,
    }
)

display(spectra)
# Out:
#                                                                                                                                                                                                                                                line  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarD2Ev, 44)
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2Ev, 47)
#                                                                                                                    48    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2Ev, 48)
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger, 51)
#                                                                                                                    52    (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger, 52)
# ...                                                                                                                                                                                                                          ...
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   (/home/workspace/lib/checkbufferoverrun.cpp, _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb, 935)
#                                            _Z41__static_initialization_and_destruction_0ii                         938   (/home/workspace/lib/checkbufferoverrun.cpp, _Z41__static_initialization_and_destruction_0ii, 938)
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token, 166)
#                                                                                                                    167   (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token, 167)
#                                                                                                                    168   (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token, 168)
#
#                                                                                                                          e_p  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    18
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    83
#                                                                                                                    48    83
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    18
#                                                                                                                    52    18
# ...                                                                                                                      ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   2
#                                            _Z41__static_initialization_and_destruction_0ii                         938   83
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   16
#                                                                                                                    167   16
#                                                                                                                    168   16
#
#                                                                                                                          e_f  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    0
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    1
#                                                                                                                    48    1
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    0
#                                                                                                                    52    0
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   0
#                                            _Z41__static_initialization_and_destruction_0ii                         938   1
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   1
#                                                                                                                    167   1
#                                                                                                                    168   1
#
#                                                                                                                          n_p  \
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    65
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    0
#                                                                                                                    48    0
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    65
#                                                                                                                    52    65
# ...                                                                                                                      ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   81
#                                            _Z41__static_initialization_and_destruction_0ii                         938   0
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   67
#                                                                                                                    167   67
#                                                                                                                    168   67
#
#                                                                                                                          n_f
# file                                       function                                                                line
# /home/workspace/lib/checkunusedvar.h       _ZN14CheckUnusedVarD2Ev                                                 44    1
#                                            _ZN14CheckUnusedVarC2Ev                                                 47    0
#                                                                                                                    48    0
#                                            _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger             51    1
#                                                                                                                    52    1
# ...                                                                                                                     ..
# /home/workspace/lib/checkbufferoverrun.cpp _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb 935   1
#                                            _Z41__static_initialization_and_destruction_0ii                         938   0
# /home/workspace/lib/templatesimplifier.h   _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token                     166   0
#                                                                                                                    167   0
#                                                                                                                    168   0
#
# [39697 rows x 5 columns]

# %% [markdown]
# # Compute suspiciousness scores

# %%
def ochiai(e_f, e_p, n_f, n_p):
    return e_f / np.sqrt(e_p + e_f) / np.sqrt(e_f + n_f) if e_f else 0.0


def op2(e_f, e_p, n_f, n_p):
    return e_f - e_p / (e_p + n_p + 1)

spectra["Sop2"] = spectra.apply(
    lambda row: op2(row.e_f, row.e_p, row.n_f, row.n_p), axis=1
)
spectra["Sochiai"] = spectra.apply(
    lambda row: ochiai(row.e_f, row.e_p, row.n_f, row.n_p), axis=1
)
spectra["Rop2"] = spectra.Sop2.rank(ascending=False, method="max")
spectra["Rochiai"] = spectra.Sochiai.rank(ascending=False, method="max")

# %% [markdown]
# # Line level SBFL

# %%
for fault_meth in fault_meth2idx:
    fault_idxs_of_meth = fault_meth2idx[fault_meth]
    print("fault meth:", fault_meth)
    for fault_idx in fault_idxs_of_meth:
        print("fault idx:", tuple(fault_idx))
    print("SBFL score of faulty method:")
    display(spectra.loc[fault_idxs_of_meth].reset_index(drop=True))

print("Top 5 SBFL scores:")
print("Op2:")
display(
    spectra.sort_values("Sop2", ascending=False).head(5).reset_index(drop=True)
)
print("Ochiai:")
display(
    spectra.sort_values("Sochiai", ascending=False)
    .head(5)
    .reset_index(drop=True)
)
# Out:
# fault meth: ('/home/workspace/lib/astutils.cpp', '_Z18isLikelyStreamReadbPK5Token')
# fault idx: ('/home/workspace/lib/astutils.cpp', '_Z18isLikelyStreamReadbPK5Token', 1580)
# fault idx: ('/home/workspace/lib/astutils.cpp', '_Z18isLikelyStreamReadbPK5Token', 1581)
# SBFL score of faulty method:
#                                                                         line  \
# 0  (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token, 1580)
# 1  (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token, 1581)
#
#    e_p  e_f  n_p  n_f      Sop2   Sochiai    Rop2  Rochiai
# 0  4    1    79   0    0.952381  0.447214  1987.0  1987.0
# 1  34   1    49   0    0.595238  0.169031  8548.0  8548.0
# Top 5 SBFL scores:
# Op2:
#                                                                                                                                line  \
# 0  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther25checkCastIntToCharAndBackEv, 111)
# 1  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkConstVariableEv, 1347)
# 2  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkConstVariableEv, 1340)
# 3  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkConstVariableEv, 1336)
# 4  (/home/workspace/lib/astutils.cpp, _ZN11FwdAnalysis14checkRecursiveEPK5TokenS2_S2_RKNSt7__debug3setIiSt4lessIiESaIiEEEbbi, 1996)
#
#    e_p  e_f  n_p  n_f  Sop2  Sochiai   Rop2  Rochiai
# 0  0    1    83   0    1.0   1.0      608.0  608.0
# 1  0    1    83   0    1.0   1.0      608.0  608.0
# 2  0    1    83   0    1.0   1.0      608.0  608.0
# 3  0    1    83   0    1.0   1.0      608.0  608.0
# 4  0    1    83   0    1.0   1.0      608.0  608.0
# Ochiai:
#                                                                                                                                line  \
# 0  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther25checkCastIntToCharAndBackEv, 111)
# 1  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkConstVariableEv, 1347)
# 2  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkConstVariableEv, 1340)
# 3  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkConstVariableEv, 1336)
# 4  (/home/workspace/lib/astutils.cpp, _ZN11FwdAnalysis14checkRecursiveEPK5TokenS2_S2_RKNSt7__debug3setIiSt4lessIiESaIiEEEbbi, 1996)
#
#    e_p  e_f  n_p  n_f  Sop2  Sochiai   Rop2  Rochiai
# 0  0    1    83   0    1.0   1.0      608.0  608.0
# 1  0    1    83   0    1.0   1.0      608.0  608.0
# 2  0    1    83   0    1.0   1.0      608.0  608.0
# 3  0    1    83   0    1.0   1.0      608.0  608.0
# 4  0    1    83   0    1.0   1.0      608.0  608.0

# %% [markdown]
# # Method level SBFL

# %%
spectra["file"] = spectra.index.map(lambda x: x[0])
spectra["func"] = spectra.index.map(lambda x: x[1])
spectra["line"] = spectra.index.map(lambda x: x[2])
# (file, func) is meth
spectra["meth"] = spectra.apply(lambda row: (row.file, row.func), axis=1)
spectra.reset_index(drop=True, inplace=True)
display(spectra)
# Out:
#        line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0      44    18   0    65   1   -0.214286  0.000000  37275.0  39697.0
# 1      47    83   1    0    0    0.011905  0.109109  16391.0  16391.0
# 2      48    83   1    0    0    0.011905  0.109109  16391.0  16391.0
# 3      51    18   0    65   1   -0.214286  0.000000  37275.0  39697.0
# 4      52    18   0    65   1   -0.214286  0.000000  37275.0  39697.0
# ...    ..    ..  ..    ..  ..         ...       ...      ...      ...
# 39692  935   2    0    81   1   -0.023810  0.000000  29812.0  39697.0
# 39693  938   83   1    0    0    0.011905  0.109109  16391.0  16391.0
# 39694  166   16   1    67   0    0.809524  0.242536  4806.0   4806.0
# 39695  167   16   1    67   0    0.809524  0.242536  4806.0   4806.0
# 39696  168   16   1    67   0    0.809524  0.242536  4806.0   4806.0
#
#                                              file  \
# 0      /home/workspace/lib/checkunusedvar.h
# 1      /home/workspace/lib/checkunusedvar.h
# 2      /home/workspace/lib/checkunusedvar.h
# 3      /home/workspace/lib/checkunusedvar.h
# 4      /home/workspace/lib/checkunusedvar.h
# ...                                     ...
# 39692  /home/workspace/lib/checkbufferoverrun.cpp
# 39693  /home/workspace/lib/checkbufferoverrun.cpp
# 39694  /home/workspace/lib/templatesimplifier.h
# 39695  /home/workspace/lib/templatesimplifier.h
# 39696  /home/workspace/lib/templatesimplifier.h
#
#                                                                           func  \
# 0      _ZN14CheckUnusedVarD2Ev
# 1      _ZN14CheckUnusedVarC2Ev
# 2      _ZN14CheckUnusedVarC2Ev
# 3      _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger
# 4      _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger
# ...                                                            ...
# 39692  _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb
# 39693  _Z41__static_initialization_and_destruction_0ii
# 39694  _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token
# 39695  _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token
# 39696  _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token
#
#                                                                                                                         meth
# 0      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarD2Ev)
# 1      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2Ev)
# 2      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2Ev)
# 3      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger)
# 4      (/home/workspace/lib/checkunusedvar.h, _ZN14CheckUnusedVarC2EPK9TokenizerPK8SettingsP11ErrorLogger)
# ...                                                                                                    ...
# 39692  (/home/workspace/lib/checkbufferoverrun.cpp, _ZN18CheckBufferOverrun16objectIndexErrorEPK5TokenPKN9ValueFlow5ValueEb)
# 39693  (/home/workspace/lib/checkbufferoverrun.cpp, _Z41__static_initialization_and_destruction_0ii)
# 39694  (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token)
# 39695  (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token)
# 39696  (/home/workspace/lib/templatesimplifier.h, _ZN18TemplateSimplifier12TokenAndName5tokenEP5Token)
#
# [39697 rows x 12 columns]

# %% [markdown]
# ## Max aggregation

# %%
print("[Op2]")
spectra_max_op2 = spectra.copy().sort_values(
    ["Sop2", "meth", "line"], ascending=False
)
spectra_max_op2.drop_duplicates(subset="meth", keep="first", inplace=True)
spectra_max_op2 = spectra_max_op2[
    ["meth", "line", "e_p", "e_f", "n_p", "n_f", "Sop2"]
]
spectra_max_op2["Rop2"] = spectra_max_op2.Sop2.rank(
    ascending=False, method="max"
)
print("Faulty method:")
display(
    spectra_max_op2.loc[spectra_max_op2.meth.isin(fault_meths)].reset_index(
        drop=True
    )
)
print("Top 20 methods:")
display(spectra_max_op2.head(20).reset_index(drop=True))
print()
print("[Ochiai]")
spectra_max_ochiai = spectra.copy().sort_values(
    ["Sochiai", "meth", "line"], ascending=False
)
spectra_max_ochiai.drop_duplicates(subset="meth", keep="first", inplace=True)
spectra_max_ochiai = spectra_max_ochiai[
    ["meth", "line", "e_p", "e_f", "n_p", "n_f", "Sochiai"]
]
spectra_max_ochiai["Rochiai"] = spectra_max_ochiai.Sochiai.rank(
    ascending=False, method="max"
)
print("Faulty method:")
display(
    spectra_max_ochiai.loc[
        spectra_max_ochiai.meth.isin(fault_meths)
    ].reset_index(drop=True)
)
print("Top 20 methods:")
display(spectra_max_ochiai.head(20).reset_index(drop=True))
# Out:
# [Op2]
# Faulty method:
#                                                                   meth  line  \
# 0  (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)  1580
#
#    e_p  e_f  n_p  n_f      Sop2   Rop2
# 0  4    1    79   0    0.952381  265.0
# Top 20 methods:
#                                                                                                                                                                     meth  \
# 0   (/home/workspace/lib/valueflow.cpp, _ZZNK25ValueFlowConditionHandler14afterConditionEP9TokenListP14SymbolDatabaseP11ErrorLoggerPK8SettingsENKUlPK8VariableE0_clESB_)
# 1   (/home/workspace/lib/valueflow.cpp, _ZZL13setTokenValueP5TokenRKN9ValueFlow5ValueEPK8SettingsENKUlPKS_E_clES9_)
# 2   (/home/workspace/lib/valueflow.cpp, _Z19getLifetimeVariablePK5Token)
# 3   (/home/workspace/lib/token.cpp, _ZZN5Token8addValueERKN9ValueFlow5ValueEENKUlS3_E_clES3_)
# 4   (/home/workspace/lib/symboldatabase.cpp, _ZN9ValueType15fromLibraryTypeERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEPK8Settings)
# 5   (/home/workspace/lib/symboldatabase.cpp, _ZN8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 6   (/home/workspace/lib/programmemory.cpp, _Z7executePK5TokenP13ProgramMemoryPxPb)
# 7   (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# 8   (/home/workspace/lib/checkuninitvar.cpp, _ZNK14CheckUninitVar18isFunctionParUsageEPK5TokenbNS_5AllocEi)
# 9   (/home/workspace/lib/checkother.cpp, _ZZN10CheckOther24checkRedundantAssignmentEvENKUlPK5TokenE_clES2_)
# 10  (/home/workspace/lib/checkother.cpp, _ZZN10CheckOther20checkEvaluationOrderEvENKUlPK5TokenE_clES2_)
# 11  (/home/workspace/lib/checkother.cpp, _ZZN10CheckOther18checkKnownArgumentEvENKUliE_clEi)
# 12  (/home/workspace/lib/checkother.cpp, _ZZN10CheckOther18checkConstVariableEvENKUlPK5TokenE_clES2_)
# 13  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther46isMovedParameterAllowedForInconclusiveFunctionEPK5Token)
# 14  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther42checkComparisonFunctionIsAlwaysTrueOrFalseEv)
# 15  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 16  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther30checkNanInArithmeticExpressionEv)
# 17  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther27checkSuspiciousCaseInSwitchEv)
# 18  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther27checkSignOfUnsignedVariableEv)
# 19  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther26warningOldStylePointerCastEv)
#
#     line  e_p  e_f  n_p  n_f  Sop2  Rop2
# 0   4183  0    1    83   0    1.0   82.0
# 1   748   0    1    83   0    1.0   82.0
# 2   2939  0    1    83   0    1.0   82.0
# 3   1975  0    1    83   0    1.0   82.0
# 4   6163  0    1    83   0    1.0   82.0
# 5   2345  0    1    83   0    1.0   82.0
# 6   473   0    1    83   0    1.0   82.0
# 7   402   0    1    83   0    1.0   82.0
# 8   1171  0    1    83   0    1.0   82.0
# 9   508   0    1    83   0    1.0   82.0
# 10  2732  0    1    83   0    1.0   82.0
# 11  3064  0    1    83   0    1.0   82.0
# 12  1379  0    1    83   0    1.0   82.0
# 13  2798  0    1    83   0    1.0   82.0
# 14  2199  0    1    83   0    1.0   82.0
# 15  671   0    1    83   0    1.0   82.0
# 16  1688  0    1    83   0    1.0   82.0
# 17  736   0    1    83   0    1.0   82.0
# 18  2260  0    1    83   0    1.0   82.0
# 19  298   0    1    83   0    1.0   82.0
# [Ochiai]
# Faulty method:
#                                                                   meth  line  \
# 0  (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)  1580
#
#    e_p  e_f  n_p  n_f   Sochiai  Rochiai
# 0  4    1    79   0    0.447214  265.0
# Top 20 methods:
#                                                                                                                                                                     meth  \
# 0   (/home/workspace/lib/valueflow.cpp, _ZZNK25ValueFlowConditionHandler14afterConditionEP9TokenListP14SymbolDatabaseP11ErrorLoggerPK8SettingsENKUlPK8VariableE0_clESB_)
# 1   (/home/workspace/lib/valueflow.cpp, _ZZL13setTokenValueP5TokenRKN9ValueFlow5ValueEPK8SettingsENKUlPKS_E_clES9_)
# 2   (/home/workspace/lib/valueflow.cpp, _Z19getLifetimeVariablePK5Token)
# 3   (/home/workspace/lib/token.cpp, _ZZN5Token8addValueERKN9ValueFlow5ValueEENKUlS3_E_clES3_)
# 4   (/home/workspace/lib/symboldatabase.cpp, _ZN9ValueType15fromLibraryTypeERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEPK8Settings)
# 5   (/home/workspace/lib/symboldatabase.cpp, _ZN8Function9argsMatchEPK5ScopePK5TokenS5_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEi)
# 6   (/home/workspace/lib/programmemory.cpp, _Z7executePK5TokenP13ProgramMemoryPxPb)
# 7   (/home/workspace/lib/forwardanalyzer.cpp, _ZN16ForwardTraversal11updateRangeEP5TokenPKS0_)
# 8   (/home/workspace/lib/checkuninitvar.cpp, _ZNK14CheckUninitVar18isFunctionParUsageEPK5TokenbNS_5AllocEi)
# 9   (/home/workspace/lib/checkother.cpp, _ZZN10CheckOther24checkRedundantAssignmentEvENKUlPK5TokenE_clES2_)
# 10  (/home/workspace/lib/checkother.cpp, _ZZN10CheckOther20checkEvaluationOrderEvENKUlPK5TokenE_clES2_)
# 11  (/home/workspace/lib/checkother.cpp, _ZZN10CheckOther18checkKnownArgumentEvENKUliE_clEi)
# 12  (/home/workspace/lib/checkother.cpp, _ZZN10CheckOther18checkConstVariableEvENKUlPK5TokenE_clES2_)
# 13  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther46isMovedParameterAllowedForInconclusiveFunctionEPK5Token)
# 14  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther42checkComparisonFunctionIsAlwaysTrueOrFalseEv)
# 15  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 16  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther30checkNanInArithmeticExpressionEv)
# 17  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther27checkSuspiciousCaseInSwitchEv)
# 18  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther27checkSignOfUnsignedVariableEv)
# 19  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther26warningOldStylePointerCastEv)
#
#     line  e_p  e_f  n_p  n_f  Sochiai  Rochiai
# 0   4183  0    1    83   0    1.0      82.0
# 1   748   0    1    83   0    1.0      82.0
# 2   2939  0    1    83   0    1.0      82.0
# 3   1975  0    1    83   0    1.0      82.0
# 4   6163  0    1    83   0    1.0      82.0
# 5   2345  0    1    83   0    1.0      82.0
# 6   473   0    1    83   0    1.0      82.0
# 7   402   0    1    83   0    1.0      82.0
# 8   1171  0    1    83   0    1.0      82.0
# 9   508   0    1    83   0    1.0      82.0
# 10  2732  0    1    83   0    1.0      82.0
# 11  3064  0    1    83   0    1.0      82.0
# 12  1379  0    1    83   0    1.0      82.0
# 13  2798  0    1    83   0    1.0      82.0
# 14  2199  0    1    83   0    1.0      82.0
# 15  671   0    1    83   0    1.0      82.0
# 16  1688  0    1    83   0    1.0      82.0
# 17  736   0    1    83   0    1.0      82.0
# 18  2260  0    1    83   0    1.0      82.0
# 19  298   0    1    83   0    1.0      82.0

# %% [markdown]
# ## Line2Method voting (weight: sbfl score / dense rank)

# %%
print("[Op2]")
ballot_op2 = {}
spectra_max_op2 = spectra.copy().sort_values(
    ["Sop2", "meth", "line"], ascending=False
)
spectra_max_op2["Rop2D"] = spectra_max_op2.Sop2.rank(
    ascending=False, method="dense"
)
spectra_max_op2["vote"] = spectra_max_op2.Sop2 / spectra_max_op2.Rop2D
for row in spectra_max_op2.itertuples():
    if row.meth not in ballot_op2:
        ballot_op2[row.meth] = row.vote
    else:
        ballot_op2[row.meth] += row.vote
L2M_op2 = pd.DataFrame(
    {"meth": list(ballot_op2.keys()), "vote": list(ballot_op2.values())}
)
L2M_op2["rank"] = L2M_op2.vote.rank(ascending=False, method="max")
L2M_op2.sort_values("rank", inplace=True)
L2M_op2.reset_index(drop=True, inplace=True)
for fault_meth in fault_meths:
    print("Faulty method:")
    display(L2M_op2.loc[L2M_op2.meth == fault_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_op2.loc[spectra_max_op2.meth == fault_meth].reset_index(
            drop=True
        )
    )
print("Top 5 methods:")
display(L2M_op2.head(5).reset_index(drop=True))
for idx, top_meth in enumerate(L2M_op2.head(5).meth.tolist(), 1):
    print(f"Top {idx}:")
    display(L2M_op2.loc[L2M_op2.meth == top_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_op2.loc[spectra_max_op2.meth == top_meth].reset_index(
            drop=True
        )
    )
print()
print("[Ochiai]")
ballot_ochiai = {}
spectra_max_ochiai = spectra.copy().sort_values(
    ["Sochiai", "meth", "line"], ascending=False
)
spectra_max_ochiai["RochiaiD"] = spectra_max_ochiai.Sochiai.rank(
    ascending=False, method="dense"
)
spectra_max_ochiai["vote"] = (
    spectra_max_ochiai.Sochiai / spectra_max_ochiai.RochiaiD
)
for row in spectra_max_ochiai.itertuples():
    if row.meth not in ballot_ochiai:
        ballot_ochiai[row.meth] = row.vote
    else:
        ballot_ochiai[row.meth] += row.vote
L2M_ochiai = pd.DataFrame(
    {"meth": list(ballot_ochiai.keys()), "vote": list(ballot_ochiai.values())}
)
L2M_ochiai["rank"] = L2M_ochiai.vote.rank(ascending=False, method="max")
L2M_ochiai.sort_values("rank", inplace=True)
L2M_ochiai.reset_index(drop=True, inplace=True)
for fault_meth in fault_meths:
    print("Faulty method:")
    display(
        L2M_ochiai.loc[L2M_ochiai.meth == fault_meth].reset_index(drop=True)
    )
    print("Voters:")
    display(
        spectra_max_ochiai.loc[
            spectra_max_ochiai.meth == fault_meth
        ].reset_index(drop=True)
    )
print("Top 5 methods:")
display(L2M_ochiai.head(5).reset_index(drop=True))
for idx, top_meth in enumerate(L2M_ochiai.head(5).meth.tolist(), 1):
    print(f"Top {idx}:")
    display(L2M_ochiai.loc[L2M_ochiai.meth == top_meth].reset_index(drop=True))
    print("Voters:")
    display(
        spectra_max_ochiai.loc[spectra_max_ochiai.meth == top_meth].reset_index(
            drop=True
        )
    )
# Out:
# [Op2]
# Faulty method:
#                                                                   meth  \
# 0  (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
#
#        vote   rank
# 0  0.542278  362.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0   1580  4    1    79   0    0.952381  0.447214  1987.0   1987.0
# 1   1582  14   1    69   0    0.833333  0.258199  4343.0   4343.0
# 2   1587  15   1    68   0    0.821429  0.250000  4582.0   4582.0
# 3   1585  15   1    68   0    0.821429  0.250000  4582.0   4582.0
# 4   1576  17   1    66   0    0.797619  0.235702  5061.0   5061.0
# 5   1570  27   1    56   0    0.678571  0.188982  7691.0   7691.0
# 6   1584  31   1    52   0    0.630952  0.176777  8240.0   8240.0
# 7   1583  31   1    52   0    0.630952  0.176777  8240.0   8240.0
# 8   1581  34   1    49   0    0.595238  0.169031  8548.0   8548.0
# 9   1579  34   1    49   0    0.595238  0.169031  8548.0   8548.0
# 10  1578  34   1    49   0    0.595238  0.169031  8548.0   8548.0
# 11  1575  37   1    46   0    0.559524  0.162221  8950.0   8950.0
# 12  1573  54   1    29   0    0.357143  0.134840  11543.0  11543.0
# 13  1572  54   1    29   0    0.357143  0.134840  11543.0  11543.0
# 14  1569  65   1    18   0    0.226190  0.123091  12965.0  12965.0
# 15  1567  65   1    18   0    0.226190  0.123091  12965.0  12965.0
#
#                                 file                             func  \
# 0   /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 1   /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 2   /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 3   /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 4   /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 5   /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 6   /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 7   /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 8   /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 9   /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 10  /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 11  /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 12  /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 13  /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 14  /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
# 15  /home/workspace/lib/astutils.cpp  _Z18isLikelyStreamReadbPK5Token
#
#                                                                    meth  \
# 0   (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 1   (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 2   (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 3   (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 4   (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 5   (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 6   (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 7   (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 8   (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 9   (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 10  (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 11  (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 12  (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 13  (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 14  (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
# 15  (/home/workspace/lib/astutils.cpp, _Z18isLikelyStreamReadbPK5Token)
#
#     Rop2D      vote
# 0   5.0    0.190476
# 1   15.0   0.055556
# 2   16.0   0.051339
# 3   16.0   0.051339
# 4   18.0   0.044312
# 5   28.0   0.024235
# 6   32.0   0.019717
# 7   32.0   0.019717
# 8   35.0   0.017007
# 9   35.0   0.017007
# 10  35.0   0.017007
# 11  38.0   0.014724
# 12  55.0   0.006494
# 13  55.0   0.006494
# 14  66.0   0.003427
# 15  66.0   0.003427
# Top 5 methods:
#                                                                                            meth  \
# 0  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)
# 1  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 2  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 3  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 4  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther15checkInnerScopeEPK5TokenPK8VariableRb)
#
#         vote  rank
# 0  39.856679  1.0
# 1  37.125660  2.0
# 2  36.933774  3.0
# 3  28.000000  4.0
# 4  25.402673  5.0
# Top 1:
#                                                                meth  \
# 0  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)
#
#         vote  rank
# 0  39.856679  1.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2  Sochiai     Rop2  Rochiai  \
# 0   1218  0    1    83   0    1.000000  1.0      608.0    608.0
# 1   1215  0    1    83   0    1.000000  1.0      608.0    608.0
# 2   1211  0    1    83   0    1.000000  1.0      608.0    608.0
# 3   1206  0    1    83   0    1.000000  1.0      608.0    608.0
# 4   1205  0    1    83   0    1.000000  1.0      608.0    608.0
# 5   1204  0    1    83   0    1.000000  1.0      608.0    608.0
# 6   1203  0    1    83   0    1.000000  1.0      608.0    608.0
# 7   1202  0    1    83   0    1.000000  1.0      608.0    608.0
# 8   1201  0    1    83   0    1.000000  1.0      608.0    608.0
# 9   1199  0    1    83   0    1.000000  1.0      608.0    608.0
# 10  1197  0    1    83   0    1.000000  1.0      608.0    608.0
# 11  1193  0    1    83   0    1.000000  1.0      608.0    608.0
# 12  1192  0    1    83   0    1.000000  1.0      608.0    608.0
# 13  1191  0    1    83   0    1.000000  1.0      608.0    608.0
# 14  1189  0    1    83   0    1.000000  1.0      608.0    608.0
# 15  1188  0    1    83   0    1.000000  1.0      608.0    608.0
# 16  1186  0    1    83   0    1.000000  1.0      608.0    608.0
# 17  1185  0    1    83   0    1.000000  1.0      608.0    608.0
# 18  1184  0    1    83   0    1.000000  1.0      608.0    608.0
# 19  1182  0    1    83   0    1.000000  1.0      608.0    608.0
# 20  1180  0    1    83   0    1.000000  1.0      608.0    608.0
# 21  1179  0    1    83   0    1.000000  1.0      608.0    608.0
# 22  1178  0    1    83   0    1.000000  1.0      608.0    608.0
# 23  1177  0    1    83   0    1.000000  1.0      608.0    608.0
# 24  1176  0    1    83   0    1.000000  1.0      608.0    608.0
# 25  1175  0    1    83   0    1.000000  1.0      608.0    608.0
# 26  1173  0    1    83   0    1.000000  1.0      608.0    608.0
# 27  1172  0    1    83   0    1.000000  1.0      608.0    608.0
# 28  1170  0    1    83   0    1.000000  1.0      608.0    608.0
# 29  1157  0    1    83   0    1.000000  1.0      608.0    608.0
# 30  1156  0    1    83   0    1.000000  1.0      608.0    608.0
# 31  1155  0    1    83   0    1.000000  1.0      608.0    608.0
# 32  1154  0    1    83   0    1.000000  1.0      608.0    608.0
# 33  1153  0    1    83   0    1.000000  1.0      608.0    608.0
# 34  1152  0    1    83   0    1.000000  1.0      608.0    608.0
# 35  1151  0    1    83   0    1.000000  1.0      608.0    608.0
# 36  1210  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 37  1209  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 38  1208  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 39  1200  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 40  1198  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 41  1195  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 42  1174  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 43  1169  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 44  1167  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 45  1166  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 46  1164  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 47  1163  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 48  1162  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 49  1149  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 50  1148  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 51  1144  3    1    80   0    0.964286  0.5      1791.0   1791.0
# 52  1213  3    0    80   1   -0.035714  0.0      31360.0  39697.0
#
#                                   file                        func  \
# 0   /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 1   /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 2   /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 3   /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 4   /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 5   /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 6   /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 7   /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 8   /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 9   /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 10  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 11  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 12  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 13  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 14  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 15  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 16  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 17  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 18  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 19  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 20  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 21  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 22  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 23  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 24  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 25  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 26  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 27  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 28  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 29  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 30  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 31  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 32  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 33  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 34  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 35  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 36  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 37  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 38  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 39  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 40  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 41  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 42  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 43  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 44  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 45  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 46  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 47  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 48  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 49  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 50  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 51  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
# 52  /home/workspace/lib/checkother.cpp  _ZL10canBeConstPK8Variable
#
#                                                                 meth  Rop2D  \
# 0   (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 1   (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 2   (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 3   (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 4   (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 5   (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 6   (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 7   (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 8   (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 9   (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 10  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 11  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 12  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 13  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 14  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 15  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 16  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 17  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 18  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 19  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 20  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 21  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 22  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 23  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 24  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 25  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 26  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 27  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 28  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 29  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 30  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 31  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 32  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 33  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 34  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 35  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  1.0
# 36  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 37  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 38  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 39  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 40  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 41  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 42  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 43  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 44  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 45  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 46  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 47  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 48  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 49  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 50  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 51  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  4.0
# 52  (/home/workspace/lib/checkother.cpp, _ZL10canBeConstPK8Variable)  77.0
#
#         vote
# 0   1.000000
# 1   1.000000
# 2   1.000000
# 3   1.000000
# 4   1.000000
# 5   1.000000
# 6   1.000000
# 7   1.000000
# 8   1.000000
# 9   1.000000
# 10  1.000000
# 11  1.000000
# 12  1.000000
# 13  1.000000
# 14  1.000000
# 15  1.000000
# 16  1.000000
# 17  1.000000
# 18  1.000000
# 19  1.000000
# 20  1.000000
# 21  1.000000
# 22  1.000000
# 23  1.000000
# 24  1.000000
# 25  1.000000
# 26  1.000000
# 27  1.000000
# 28  1.000000
# 29  1.000000
# 30  1.000000
# 31  1.000000
# 32  1.000000
# 33  1.000000
# 34  1.000000
# 35  1.000000
# 36  0.241071
# 37  0.241071
# 38  0.241071
# 39  0.241071
# 40  0.241071
# 41  0.241071
# 42  0.241071
# 43  0.241071
# 44  0.241071
# 45  0.241071
# 46  0.241071
# 47  0.241071
# 48  0.241071
# 49  0.241071
# 50  0.241071
# 51  0.241071
# 52 -0.000464
# Top 2:
#                                                                                         meth  \
# 0  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
#
#        vote  rank
# 0  37.12566  2.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0   671   0    1    83   0    1.000000  1.000000  608.0    608.0
# 1   670   0    1    83   0    1.000000  1.000000  608.0    608.0
# 2   666   0    1    83   0    1.000000  1.000000  608.0    608.0
# 3   665   0    1    83   0    1.000000  1.000000  608.0    608.0
# 4   664   0    1    83   0    1.000000  1.000000  608.0    608.0
# 5   661   0    1    83   0    1.000000  1.000000  608.0    608.0
# 6   660   0    1    83   0    1.000000  1.000000  608.0    608.0
# 7   659   0    1    83   0    1.000000  1.000000  608.0    608.0
# 8   651   0    1    83   0    1.000000  1.000000  608.0    608.0
# 9   650   0    1    83   0    1.000000  1.000000  608.0    608.0
# 10  646   0    1    83   0    1.000000  1.000000  608.0    608.0
# 11  645   0    1    83   0    1.000000  1.000000  608.0    608.0
# 12  641   0    1    83   0    1.000000  1.000000  608.0    608.0
# 13  640   0    1    83   0    1.000000  1.000000  608.0    608.0
# 14  639   0    1    83   0    1.000000  1.000000  608.0    608.0
# 15  636   0    1    83   0    1.000000  1.000000  608.0    608.0
# 16  635   0    1    83   0    1.000000  1.000000  608.0    608.0
# 17  634   0    1    83   0    1.000000  1.000000  608.0    608.0
# 18  626   0    1    83   0    1.000000  1.000000  608.0    608.0
# 19  625   0    1    83   0    1.000000  1.000000  608.0    608.0
# 20  616   0    1    83   0    1.000000  1.000000  608.0    608.0
# 21  613   0    1    83   0    1.000000  1.000000  608.0    608.0
# 22  612   0    1    83   0    1.000000  1.000000  608.0    608.0
# 23  611   0    1    83   0    1.000000  1.000000  608.0    608.0
# 24  610   0    1    83   0    1.000000  1.000000  608.0    608.0
# 25  609   0    1    83   0    1.000000  1.000000  608.0    608.0
# 26  608   0    1    83   0    1.000000  1.000000  608.0    608.0
# 27  607   0    1    83   0    1.000000  1.000000  608.0    608.0
# 28  606   0    1    83   0    1.000000  1.000000  608.0    608.0
# 29  605   0    1    83   0    1.000000  1.000000  608.0    608.0
# 30  692   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 31  691   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 32  690   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 33  685   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 34  684   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 35  683   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 36  658   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 37  633   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 38  632   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 39  624   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 40  601   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 41  600   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 42  598   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 43  597   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 44  594   20   1    63   0    0.761905  0.218218  5827.0   5827.0
# 45  593   20   1    63   0    0.761905  0.218218  5827.0   5827.0
# 46  592   20   1    63   0    0.761905  0.218218  5827.0   5827.0
# 47  588   20   1    63   0    0.761905  0.218218  5827.0   5827.0
# 48  585   22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 49  583   22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 50  586   2    0    81   1   -0.023810  0.000000  29812.0  39697.0
#
#                                   file  \
# 0   /home/workspace/lib/checkother.cpp
# 1   /home/workspace/lib/checkother.cpp
# 2   /home/workspace/lib/checkother.cpp
# 3   /home/workspace/lib/checkother.cpp
# 4   /home/workspace/lib/checkother.cpp
# 5   /home/workspace/lib/checkother.cpp
# 6   /home/workspace/lib/checkother.cpp
# 7   /home/workspace/lib/checkother.cpp
# 8   /home/workspace/lib/checkother.cpp
# 9   /home/workspace/lib/checkother.cpp
# 10  /home/workspace/lib/checkother.cpp
# 11  /home/workspace/lib/checkother.cpp
# 12  /home/workspace/lib/checkother.cpp
# 13  /home/workspace/lib/checkother.cpp
# 14  /home/workspace/lib/checkother.cpp
# 15  /home/workspace/lib/checkother.cpp
# 16  /home/workspace/lib/checkother.cpp
# 17  /home/workspace/lib/checkother.cpp
# 18  /home/workspace/lib/checkother.cpp
# 19  /home/workspace/lib/checkother.cpp
# 20  /home/workspace/lib/checkother.cpp
# 21  /home/workspace/lib/checkother.cpp
# 22  /home/workspace/lib/checkother.cpp
# 23  /home/workspace/lib/checkother.cpp
# 24  /home/workspace/lib/checkother.cpp
# 25  /home/workspace/lib/checkother.cpp
# 26  /home/workspace/lib/checkother.cpp
# 27  /home/workspace/lib/checkother.cpp
# 28  /home/workspace/lib/checkother.cpp
# 29  /home/workspace/lib/checkother.cpp
# 30  /home/workspace/lib/checkother.cpp
# 31  /home/workspace/lib/checkother.cpp
# 32  /home/workspace/lib/checkother.cpp
# 33  /home/workspace/lib/checkother.cpp
# 34  /home/workspace/lib/checkother.cpp
# 35  /home/workspace/lib/checkother.cpp
# 36  /home/workspace/lib/checkother.cpp
# 37  /home/workspace/lib/checkother.cpp
# 38  /home/workspace/lib/checkother.cpp
# 39  /home/workspace/lib/checkother.cpp
# 40  /home/workspace/lib/checkother.cpp
# 41  /home/workspace/lib/checkother.cpp
# 42  /home/workspace/lib/checkother.cpp
# 43  /home/workspace/lib/checkother.cpp
# 44  /home/workspace/lib/checkother.cpp
# 45  /home/workspace/lib/checkother.cpp
# 46  /home/workspace/lib/checkother.cpp
# 47  /home/workspace/lib/checkother.cpp
# 48  /home/workspace/lib/checkother.cpp
# 49  /home/workspace/lib/checkother.cpp
# 50  /home/workspace/lib/checkother.cpp
#
#                                                    func  \
# 0   _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 1   _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 2   _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 3   _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 4   _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 5   _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 6   _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 7   _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 8   _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 9   _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 10  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 11  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 12  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 13  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 14  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 15  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 16  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 17  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 18  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 19  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 20  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 21  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 22  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 23  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 24  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 25  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 26  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 27  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 28  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 29  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 30  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 31  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 32  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 33  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 34  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 35  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 36  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 37  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 38  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 39  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 40  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 41  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 42  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 43  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 44  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 45  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 46  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 47  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 48  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 49  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
# 50  _ZN10CheckOther32checkRedundantAssignmentInSwitchEv
#
#                                                                                          meth  \
# 0   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 1   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 2   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 3   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 4   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 5   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 6   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 7   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 8   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 9   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 10  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 11  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 12  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 13  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 14  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 15  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 16  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 17  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 18  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 19  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 20  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 21  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 22  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 23  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 24  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 25  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 26  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 27  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 28  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 29  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 30  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 31  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 32  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 33  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 34  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 35  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 36  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 37  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 38  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 39  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 40  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 41  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 42  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 43  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 44  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 45  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 46  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 47  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 48  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 49  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 50  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
#
#     Rop2D      vote
# 0   1.0    1.000000
# 1   1.0    1.000000
# 2   1.0    1.000000
# 3   1.0    1.000000
# 4   1.0    1.000000
# 5   1.0    1.000000
# 6   1.0    1.000000
# 7   1.0    1.000000
# 8   1.0    1.000000
# 9   1.0    1.000000
# 10  1.0    1.000000
# 11  1.0    1.000000
# 12  1.0    1.000000
# 13  1.0    1.000000
# 14  1.0    1.000000
# 15  1.0    1.000000
# 16  1.0    1.000000
# 17  1.0    1.000000
# 18  1.0    1.000000
# 19  1.0    1.000000
# 20  1.0    1.000000
# 21  1.0    1.000000
# 22  1.0    1.000000
# 23  1.0    1.000000
# 24  1.0    1.000000
# 25  1.0    1.000000
# 26  1.0    1.000000
# 27  1.0    1.000000
# 28  1.0    1.000000
# 29  1.0    1.000000
# 30  2.0    0.494048
# 31  2.0    0.494048
# 32  2.0    0.494048
# 33  2.0    0.494048
# 34  2.0    0.494048
# 35  2.0    0.494048
# 36  2.0    0.494048
# 37  2.0    0.494048
# 38  2.0    0.494048
# 39  2.0    0.494048
# 40  2.0    0.494048
# 41  2.0    0.494048
# 42  2.0    0.494048
# 43  2.0    0.494048
# 44  21.0   0.036281
# 45  21.0   0.036281
# 46  21.0   0.036281
# 47  21.0   0.036281
# 48  23.0   0.032091
# 49  23.0   0.032091
# 50  76.0  -0.000313
# Top 3:
#                                                                                 meth  \
# 0  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
#
#         vote  rank
# 0  36.933774  3.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0   2087  0    1    83   0    1.000000  1.000000  608.0    608.0
# 1   2085  0    1    83   0    1.000000  1.000000  608.0    608.0
# 2   2078  0    1    83   0    1.000000  1.000000  608.0    608.0
# 3   2076  0    1    83   0    1.000000  1.000000  608.0    608.0
# 4   2070  0    1    83   0    1.000000  1.000000  608.0    608.0
# ..   ... ..   ..    ..  ..         ...       ...    ...      ...
# 88  1952  22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 89  1951  22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 90  1950  22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 91  1948  22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 92  1953  2    0    81   1   -0.023810  0.000000  29812.0  39697.0
#
#                                   file  \
# 0   /home/workspace/lib/checkother.cpp
# 1   /home/workspace/lib/checkother.cpp
# 2   /home/workspace/lib/checkother.cpp
# 3   /home/workspace/lib/checkother.cpp
# 4   /home/workspace/lib/checkother.cpp
# ..                                 ...
# 88  /home/workspace/lib/checkother.cpp
# 89  /home/workspace/lib/checkother.cpp
# 90  /home/workspace/lib/checkother.cpp
# 91  /home/workspace/lib/checkother.cpp
# 92  /home/workspace/lib/checkother.cpp
#
#                                            func  \
# 0   _ZN10CheckOther24checkDuplicateExpressionEv
# 1   _ZN10CheckOther24checkDuplicateExpressionEv
# 2   _ZN10CheckOther24checkDuplicateExpressionEv
# 3   _ZN10CheckOther24checkDuplicateExpressionEv
# 4   _ZN10CheckOther24checkDuplicateExpressionEv
# ..                                          ...
# 88  _ZN10CheckOther24checkDuplicateExpressionEv
# 89  _ZN10CheckOther24checkDuplicateExpressionEv
# 90  _ZN10CheckOther24checkDuplicateExpressionEv
# 91  _ZN10CheckOther24checkDuplicateExpressionEv
# 92  _ZN10CheckOther24checkDuplicateExpressionEv
#
#                                                                                  meth  \
# 0   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 1   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 2   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 3   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 4   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# ..                                                                                ...
# 88  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 89  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 90  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 91  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 92  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
#
#     Rop2D      vote
# 0   1.0    1.000000
# 1   1.0    1.000000
# 2   1.0    1.000000
# 3   1.0    1.000000
# 4   1.0    1.000000
# ..  ...         ...
# 88  23.0   0.032091
# 89  23.0   0.032091
# 90  23.0   0.032091
# 91  23.0   0.032091
# 92  76.0  -0.000313
#
# [93 rows x 14 columns]
# Top 4:
#                                                                  meth  vote  \
# 0  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  28.0
#
#    rank
# 0  4.0
# Voters:
#     line  e_p  e_f  n_p  n_f  Sop2  Sochiai   Rop2  Rochiai  \
# 0   1048  0    1    83   0    1.0   1.0      608.0  608.0
# 1   1047  0    1    83   0    1.0   1.0      608.0  608.0
# 2   1046  0    1    83   0    1.0   1.0      608.0  608.0
# 3   1044  0    1    83   0    1.0   1.0      608.0  608.0
# 4   1043  0    1    83   0    1.0   1.0      608.0  608.0
# 5   1041  0    1    83   0    1.0   1.0      608.0  608.0
# 6   1040  0    1    83   0    1.0   1.0      608.0  608.0
# 7   1039  0    1    83   0    1.0   1.0      608.0  608.0
# 8   1038  0    1    83   0    1.0   1.0      608.0  608.0
# 9   1037  0    1    83   0    1.0   1.0      608.0  608.0
# 10  1036  0    1    83   0    1.0   1.0      608.0  608.0
# 11  1033  0    1    83   0    1.0   1.0      608.0  608.0
# 12  1032  0    1    83   0    1.0   1.0      608.0  608.0
# 13  1031  0    1    83   0    1.0   1.0      608.0  608.0
# 14  1030  0    1    83   0    1.0   1.0      608.0  608.0
# 15  1029  0    1    83   0    1.0   1.0      608.0  608.0
# 16  1027  0    1    83   0    1.0   1.0      608.0  608.0
# 17  1026  0    1    83   0    1.0   1.0      608.0  608.0
# 18  1025  0    1    83   0    1.0   1.0      608.0  608.0
# 19  1024  0    1    83   0    1.0   1.0      608.0  608.0
# 20  1023  0    1    83   0    1.0   1.0      608.0  608.0
# 21  1022  0    1    83   0    1.0   1.0      608.0  608.0
# 22  1021  0    1    83   0    1.0   1.0      608.0  608.0
# 23  1020  0    1    83   0    1.0   1.0      608.0  608.0
# 24  1019  0    1    83   0    1.0   1.0      608.0  608.0
# 25  1018  0    1    83   0    1.0   1.0      608.0  608.0
# 26  1017  0    1    83   0    1.0   1.0      608.0  608.0
# 27  1015  0    1    83   0    1.0   1.0      608.0  608.0
#
#                                 file                            func  \
# 0   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 1   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 2   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 3   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 4   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 5   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 6   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 7   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 8   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 9   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 10  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 11  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 12  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 13  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 14  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 15  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 16  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 17  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 18  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 19  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 20  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 21  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 22  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 23  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 24  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 25  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 26  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 27  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
#
#                                                                   meth  Rop2D  \
# 0   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 1   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 2   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 3   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 4   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 5   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 6   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 7   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 8   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 9   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 10  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 11  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 12  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 13  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 14  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 15  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 16  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 17  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 18  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 19  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 20  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 21  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 22  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 23  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 24  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 25  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 26  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
# 27  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  1.0
#
#     vote
# 0   1.0
# 1   1.0
# 2   1.0
# 3   1.0
# 4   1.0
# 5   1.0
# 6   1.0
# 7   1.0
# 8   1.0
# 9   1.0
# 10  1.0
# 11  1.0
# 12  1.0
# 13  1.0
# 14  1.0
# 15  1.0
# 16  1.0
# 17  1.0
# 18  1.0
# 19  1.0
# 20  1.0
# 21  1.0
# 22  1.0
# 23  1.0
# 24  1.0
# 25  1.0
# 26  1.0
# 27  1.0
# Top 5:
#                                                                                            meth  \
# 0  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther15checkInnerScopeEPK5TokenPK8VariableRb)
#
#         vote  rank
# 0  25.402673  5.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0   1031  0    1    83   0    1.000000  1.000000  608.0    608.0
# 1   1026  0    1    83   0    1.000000  1.000000  608.0    608.0
# 2   1023  0    1    83   0    1.000000  1.000000  608.0    608.0
# 3   1017  0    1    83   0    1.000000  1.000000  608.0    608.0
# 4   1005  0    1    83   0    1.000000  1.000000  608.0    608.0
# 5   992   0    1    83   0    1.000000  1.000000  608.0    608.0
# 6   990   0    1    83   0    1.000000  1.000000  608.0    608.0
# 7   987   0    1    83   0    1.000000  1.000000  608.0    608.0
# 8   976   0    1    83   0    1.000000  1.000000  608.0    608.0
# 9   974   0    1    83   0    1.000000  1.000000  608.0    608.0
# 10  973   0    1    83   0    1.000000  1.000000  608.0    608.0
# 11  972   0    1    83   0    1.000000  1.000000  608.0    608.0
# 12  971   0    1    83   0    1.000000  1.000000  608.0    608.0
# 13  970   0    1    83   0    1.000000  1.000000  608.0    608.0
# 14  963   0    1    83   0    1.000000  1.000000  608.0    608.0
# 15  1030  1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 16  1029  1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 17  1020  1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 18  1006  1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 19  1004  1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 20  1003  1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 21  1001  1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 22  1000  1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 23  999   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 24  998   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 25  997   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 26  996   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 27  995   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 28  966   1    1    82   0    0.988095  0.707107  1154.0   1154.0
# 29  968   2    1    81   0    0.976190  0.577350  1453.0   1453.0
# 30  1014  3    1    80   0    0.964286  0.500000  1791.0   1791.0
# 31  1035  4    1    79   0    0.952381  0.447214  1987.0   1987.0
# 32  969   4    1    79   0    0.952381  0.447214  1987.0   1987.0
# 33  967   6    1    77   0    0.928571  0.377964  2338.0   2338.0
# 34  1028  7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 35  1025  7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 36  1022  7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 37  1019  7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 38  1016  7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 39  1013  7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 40  994   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 41  991   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 42  989   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 43  986   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 44  984   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 45  983   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 46  982   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 47  965   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 48  962   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 49  961   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 50  960   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 51  959   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 52  958   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 53  957   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 54  955   7    1    76   0    0.916667  0.353553  2622.0   2622.0
# 55  1008  1    0    82   1   -0.011905  0.000000  25066.0  39697.0
# 56  1007  1    0    82   1   -0.011905  0.000000  25066.0  39697.0
#
#                                   file  \
# 0   /home/workspace/lib/checkother.cpp
# 1   /home/workspace/lib/checkother.cpp
# 2   /home/workspace/lib/checkother.cpp
# 3   /home/workspace/lib/checkother.cpp
# ...
# 42  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 43  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 44  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 45  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 46  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 47  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 48  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 49  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
# 50  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther32checkRedundantAssignmentInSwitchEv)
#
#     RochiaiD      vote
# 0   1.0       1.000000
# 1   1.0       1.000000
# 2   1.0       1.000000
# 3   1.0       1.000000
# 4   1.0       1.000000
# 5   1.0       1.000000
# 6   1.0       1.000000
# 7   1.0       1.000000
# 8   1.0       1.000000
# 9   1.0       1.000000
# 10  1.0       1.000000
# 11  1.0       1.000000
# 12  1.0       1.000000
# 13  1.0       1.000000
# 14  1.0       1.000000
# 15  1.0       1.000000
# 16  1.0       1.000000
# 17  1.0       1.000000
# 18  1.0       1.000000
# 19  1.0       1.000000
# 20  1.0       1.000000
# 21  1.0       1.000000
# 22  1.0       1.000000
# 23  1.0       1.000000
# 24  1.0       1.000000
# 25  1.0       1.000000
# 26  1.0       1.000000
# 27  1.0       1.000000
# 28  1.0       1.000000
# 29  1.0       1.000000
# 30  2.0       0.353553
# 31  2.0       0.353553
# 32  2.0       0.353553
# 33  2.0       0.353553
# 34  2.0       0.353553
# 35  2.0       0.353553
# 36  2.0       0.353553
# 37  2.0       0.353553
# 38  2.0       0.353553
# 39  2.0       0.353553
# 40  2.0       0.353553
# 41  2.0       0.353553
# 42  2.0       0.353553
# 43  2.0       0.353553
# 44  21.0      0.010391
# 45  21.0      0.010391
# 46  21.0      0.010391
# 47  21.0      0.010391
# 48  23.0      0.009066
# 49  23.0      0.009066
# 50  75.0      0.000000
# Top 3:
#                                                                                 meth  \
# 0  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
#
#         vote  rank
# 0  32.489976  3.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0   2087  0    1    83   0    1.000000  1.000000  608.0    608.0
# 1   2085  0    1    83   0    1.000000  1.000000  608.0    608.0
# 2   2078  0    1    83   0    1.000000  1.000000  608.0    608.0
# 3   2076  0    1    83   0    1.000000  1.000000  608.0    608.0
# 4   2070  0    1    83   0    1.000000  1.000000  608.0    608.0
# ..   ... ..   ..    ..  ..         ...       ...    ...      ...
# 88  1952  22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 89  1951  22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 90  1950  22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 91  1948  22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 92  1953  2    0    81   1   -0.023810  0.000000  29812.0  39697.0
#
#                                   file  \
# 0   /home/workspace/lib/checkother.cpp
# 1   /home/workspace/lib/checkother.cpp
# 2   /home/workspace/lib/checkother.cpp
# 3   /home/workspace/lib/checkother.cpp
# 4   /home/workspace/lib/checkother.cpp
# ..                                 ...
# 88  /home/workspace/lib/checkother.cpp
# 89  /home/workspace/lib/checkother.cpp
# 90  /home/workspace/lib/checkother.cpp
# 91  /home/workspace/lib/checkother.cpp
# 92  /home/workspace/lib/checkother.cpp
#
#                                            func  \
# 0   _ZN10CheckOther24checkDuplicateExpressionEv
# 1   _ZN10CheckOther24checkDuplicateExpressionEv
# 2   _ZN10CheckOther24checkDuplicateExpressionEv
# 3   _ZN10CheckOther24checkDuplicateExpressionEv
# 4   _ZN10CheckOther24checkDuplicateExpressionEv
# ..                                          ...
# 88  _ZN10CheckOther24checkDuplicateExpressionEv
# 89  _ZN10CheckOther24checkDuplicateExpressionEv
# 90  _ZN10CheckOther24checkDuplicateExpressionEv
# 91  _ZN10CheckOther24checkDuplicateExpressionEv
# 92  _ZN10CheckOther24checkDuplicateExpressionEv
#
#                                                                                  meth  \
# 0   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 1   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 2   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 3   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 4   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# ..                                                                                ...
# 88  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 89  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 90  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 91  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
# 92  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther24checkDuplicateExpressionEv)
#
#     RochiaiD      vote
# 0   1.0       1.000000
# 1   1.0       1.000000
# 2   1.0       1.000000
# 3   1.0       1.000000
# 4   1.0       1.000000
# ..  ...            ...
# 88  23.0      0.009066
# 89  23.0      0.009066
# 90  23.0      0.009066
# 91  23.0      0.009066
# 92  75.0      0.000000
#
# [93 rows x 14 columns]
# Top 4:
#                                                                  meth  vote  \
# 0  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)  28.0
#
#    rank
# 0  4.0
# Voters:
#     line  e_p  e_f  n_p  n_f  Sop2  Sochiai   Rop2  Rochiai  \
# 0   1048  0    1    83   0    1.0   1.0      608.0  608.0
# 1   1047  0    1    83   0    1.0   1.0      608.0  608.0
# 2   1046  0    1    83   0    1.0   1.0      608.0  608.0
# 3   1044  0    1    83   0    1.0   1.0      608.0  608.0
# 4   1043  0    1    83   0    1.0   1.0      608.0  608.0
# 5   1041  0    1    83   0    1.0   1.0      608.0  608.0
# 6   1040  0    1    83   0    1.0   1.0      608.0  608.0
# 7   1039  0    1    83   0    1.0   1.0      608.0  608.0
# 8   1038  0    1    83   0    1.0   1.0      608.0  608.0
# 9   1037  0    1    83   0    1.0   1.0      608.0  608.0
# 10  1036  0    1    83   0    1.0   1.0      608.0  608.0
# 11  1033  0    1    83   0    1.0   1.0      608.0  608.0
# 12  1032  0    1    83   0    1.0   1.0      608.0  608.0
# 13  1031  0    1    83   0    1.0   1.0      608.0  608.0
# 14  1030  0    1    83   0    1.0   1.0      608.0  608.0
# 15  1029  0    1    83   0    1.0   1.0      608.0  608.0
# 16  1027  0    1    83   0    1.0   1.0      608.0  608.0
# 17  1026  0    1    83   0    1.0   1.0      608.0  608.0
# 18  1025  0    1    83   0    1.0   1.0      608.0  608.0
# 19  1024  0    1    83   0    1.0   1.0      608.0  608.0
# 20  1023  0    1    83   0    1.0   1.0      608.0  608.0
# 21  1022  0    1    83   0    1.0   1.0      608.0  608.0
# 22  1021  0    1    83   0    1.0   1.0      608.0  608.0
# 23  1020  0    1    83   0    1.0   1.0      608.0  608.0
# 24  1019  0    1    83   0    1.0   1.0      608.0  608.0
# 25  1018  0    1    83   0    1.0   1.0      608.0  608.0
# 26  1017  0    1    83   0    1.0   1.0      608.0  608.0
# 27  1015  0    1    83   0    1.0   1.0      608.0  608.0
#
#                                 file                            func  \
# 0   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 1   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 2   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 3   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 4   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 5   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 6   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 7   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 8   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 9   /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 10  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 11  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 12  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 13  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 14  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 15  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 16  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 17  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 18  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 19  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 20  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 21  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 22  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 23  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 24  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 25  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 26  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
# 27  /home/workspace/lib/astutils.cpp  _Z18isUniqueExpressionPK5Token
#
#                                                                   meth  \
# 0   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 1   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 2   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 3   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 4   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 5   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 6   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 7   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 8   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 9   (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 10  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 11  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 12  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 13  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 14  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 15  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 16  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 17  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 18  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 19  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 20  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 21  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 22  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 23  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 24  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 25  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 26  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
# 27  (/home/workspace/lib/astutils.cpp, _Z18isUniqueExpressionPK5Token)
#
#     RochiaiD  vote
# 0   1.0       1.0
# 1   1.0       1.0
# 2   1.0       1.0
# 3   1.0       1.0
# 4   1.0       1.0
# 5   1.0       1.0
# 6   1.0       1.0
# 7   1.0       1.0
# 8   1.0       1.0
# 9   1.0       1.0
# 10  1.0       1.0
# 11  1.0       1.0
# 12  1.0       1.0
# 13  1.0       1.0
# 14  1.0       1.0
# 15  1.0       1.0
# 16  1.0       1.0
# 17  1.0       1.0
# 18  1.0       1.0
# 19  1.0       1.0
# 20  1.0       1.0
# 21  1.0       1.0
# 22  1.0       1.0
# 23  1.0       1.0
# 24  1.0       1.0
# 25  1.0       1.0
# 26  1.0       1.0
# 27  1.0       1.0
# Top 5:
#                                                                           meth  \
# 0  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkVariableScopeEv)
#
#         vote  rank
# 0  22.084882  5.0
# Voters:
#     line  e_p  e_f  n_p  n_f      Sop2   Sochiai     Rop2  Rochiai  \
# 0   951   0    1    83   0    1.000000  1.000000  608.0    608.0
# 1   942   0    1    83   0    1.000000  1.000000  608.0    608.0
# 2   941   0    1    83   0    1.000000  1.000000  608.0    608.0
# 3   940   0    1    83   0    1.000000  1.000000  608.0    608.0
# 4   939   0    1    83   0    1.000000  1.000000  608.0    608.0
# ..  ...  ..   ..    ..  ..         ...       ...    ...      ...
# 56  876   21   1    62   0    0.750000  0.213201  6169.0   6169.0
# 57  873   22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 58  870   22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 59  868   22   1    61   0    0.738095  0.208514  6445.0   6445.0
# 60  874   2    0    81   1   -0.023810  0.000000  29812.0  39697.0
#
#                                   file                                   func  \
# 0   /home/workspace/lib/checkother.cpp  _ZN10CheckOther18checkVariableScopeEv
# 1   /home/workspace/lib/checkother.cpp  _ZN10CheckOther18checkVariableScopeEv
# 2   /home/workspace/lib/checkother.cpp  _ZN10CheckOther18checkVariableScopeEv
# 3   /home/workspace/lib/checkother.cpp  _ZN10CheckOther18checkVariableScopeEv
# 4   /home/workspace/lib/checkother.cpp  _ZN10CheckOther18checkVariableScopeEv
# ..                                 ...                                    ...
# 56  /home/workspace/lib/checkother.cpp  _ZN10CheckOther18checkVariableScopeEv
# 57  /home/workspace/lib/checkother.cpp  _ZN10CheckOther18checkVariableScopeEv
# 58  /home/workspace/lib/checkother.cpp  _ZN10CheckOther18checkVariableScopeEv
# 59  /home/workspace/lib/checkother.cpp  _ZN10CheckOther18checkVariableScopeEv
# 60  /home/workspace/lib/checkother.cpp  _ZN10CheckOther18checkVariableScopeEv
#
#                                                                            meth  \
# 0   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkVariableScopeEv)
# 1   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkVariableScopeEv)
# 2   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkVariableScopeEv)
# 3   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkVariableScopeEv)
# 4   (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkVariableScopeEv)
# ..                                                                          ...
# 56  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkVariableScopeEv)
# 57  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkVariableScopeEv)
# 58  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkVariableScopeEv)
# 59  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkVariableScopeEv)
# 60  (/home/workspace/lib/checkother.cpp, _ZN10CheckOther18checkVariableScopeEv)
#
#     RochiaiD      vote
# 0   1.0       1.000000
# 1   1.0       1.000000
# 2   1.0       1.000000
# 3   1.0       1.000000
# 4   1.0       1.000000
# ..  ...            ...
# 56  22.0      0.009691
# 57  23.0      0.009066
# 58  23.0      0.009066
# 59  23.0      0.009066
# 60  75.0      0.000000
#
# [61 rows x 14 columns]

# %% [markdown]
# # 감상
#
# 단순히 passing test에 의해서 한 번도 실행되지 않고 failing test에 의해서 실행되는 method가 너무 많다 (sbfl max agg top max rank: 82)
